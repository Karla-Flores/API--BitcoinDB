# %%
# Dependencies and Setp up
import json
import requests
import pandas as pd
import numpy as np
import datetime as dt

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json
from pandas.io.json import json_normalize 
import datetime as dt


# API keys
from api_keys import YOUR_API_KEY_

# %%
# url = 'https://pro-api.coinmarketcap.com/'
url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'1000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': YOUR_API_KEY_,
}

# %%
session = Session()
session.headers.update(headers)


try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)

# %%
len(data['data'])
# Out:
# 1000

# %%
type(data)
# Out:
# dict

# %%
c = data['data'][0]
c
# Out:
# {'id': 1,
#  'name': 'Bitcoin',
#  'symbol': 'BTC',
#  'slug': 'bitcoin',
#  'num_market_pairs': 8253,
#  'date_added': '2013-04-28T00:00:00.000Z',
#  'tags': ['mineable',
#   'pow',
#   'sha-256',
#   'store-of-value',
#   'state-channel',
#   'coinbase-ventures-portfolio',
#   'three-arrows-capital-portfolio',
#   'polychain-capital-portfolio',
#   'binance-labs-portfolio',
#   'blockchain-capital-portfolio',
#   'boostvc-portfolio',
#   'cms-holdings-portfolio',
#   'dcg-portfolio',
#   'dragonfly-capital-portfolio',
#   'electric-capital-portfolio',
#   'fabric-ventures-portfolio',
#   'framework-ventures-portfolio',
#   'galaxy-digital-portfolio',
#   'huobi-capital-portfolio',
#   'alameda-research-portfolio',
#   'a16z-portfolio',
#   '1confirmation-portfolio',
#   'winklevoss-capital-portfolio',
#   'usv-portfolio',
#   'placeholder-ventures-portfolio',
#   'pantera-capital-portfolio',
#   'multicoin-capital-portfolio',
#   'paradigm-portfolio'],
#  'max_supply': 21000000,
#  'circulating_supply': 18896700,
#  'total_supply': 18896700,
#  'platform': None,
#  'cmc_rank': 1,
#  'last_updated': '2021-12-10T04:19:02.000Z',
#  'quote': {'USD': {'price': 48429.54990774255,
#    'volume_24h': 29973349260.943462,
#    'volume_change_24h': 5.416,
#    'percent_change_1h': -0.16001442,
#    'percent_change_24h': -2.52991421,
#    'percent_change_7d': -14.47839879,
#    'percent_change_30d': -27.09785073,
#    'percent_change_60d': -14.44514837,
#    'percent_change_90d': 7.05096774,
#    'market_cap': 915158675741.6387,
#    'market_cap_dominance': 40.3323,
#    'fully_diluted_market_cap': 1017020548062.59,
#    'last_updated': '2021-12-10T04:19:02.000Z'}}}

# %%
df= pd.DataFrame (data['data'])
df['tradable']=''
df.head()
# Out:
#      id          name symbol          slug  num_market_pairs  \
# 0     1       Bitcoin    BTC       bitcoin              8253
# 1  1027      Ethereum    ETH      ethereum              4621
# 2  1839  Binance Coin    BNB  binance-coin               555
# 3   825        Tether   USDT        tether             20363
# 4  5426        Solana    SOL        solana               197
#
#                  date_added  \
# 0  2013-04-28T00:00:00.000Z
# 1  2015-08-07T00:00:00.000Z
# 2  2017-07-25T00:00:00.000Z
# 3  2015-02-25T00:00:00.000Z
# 4  2020-04-10T00:00:00.000Z
#
#                                                 tags   max_supply  \
# 0  [mineable, pow, sha-256, store-of-value, state...   21000000.0
# 1  [mineable, pow, smart-contracts, ethereum-ecos...          NaN
# 2  [marketplace, centralized-exchange, payments, ...  166801148.0
# 3  [payments, stablecoin, asset-backed-stablecoin...          NaN
# 4  [pos, platform, solana-ecosystem, cms-holdings...          NaN
#
#    circulating_supply  total_supply  \
# 0        1.889670e+07  1.889670e+07
# 1        1.186764e+08  1.186764e+08
# 2        1.668011e+08  1.668011e+08
# 3        7.615630e+10  7.935200e+10
# 4        3.073473e+08  5.108116e+08
#
#                                             platform  cmc_rank  \
# 0                                               None         1
# 1                                               None         2
# 2                                               None         3
# 3  {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...         4
# 4                                               None         5
#
#                last_updated  \
# 0  2021-12-10T04:19:02.000Z
# 1  2021-12-10T04:19:02.000Z
# 2  2021-12-10T04:18:27.000Z
# 3  2021-12-10T04:18:27.000Z
# 4  2021-12-10T04:19:05.000Z
#
#                                                quote tradable
# 0  {'USD': {'price': 48429.54990774255, 'volume_2...
# 1  {'USD': {'price': 4150.713528688832, 'volume_2...
# 2  {'USD': {'price': 579.035025019835, 'volume_24...
# 3  {'USD': {'price': 1.0008674711046064, 'volume_...
# 4  {'USD': {'price': 179.44463058371528, 'volume_...

# %%
name = df['name']
name
# Out:
# 0                 Bitcoin
# 1                Ethereum
# 2            Binance Coin
# 3                  Tether
# 4                  Solana
#               ...
# 995                  Eden
# 996                 88mph
# 997      Tachyon Protocol
# 998                  Swop
# 999    Robonomics.network
# Name: name, Length: 1000, dtype: object

# %%
c=df['quote']
type(c)
# Out:
# pandas.core.series.Series

# %%
c[0]['USD']
# Out:
# {'price': 48429.54990774255,
#  'volume_24h': 29973349260.943462,
#  'volume_change_24h': 5.416,
#  'percent_change_1h': -0.16001442,
#  'percent_change_24h': -2.52991421,
#  'percent_change_7d': -14.47839879,
#  'percent_change_30d': -27.09785073,
#  'percent_change_60d': -14.44514837,
#  'percent_change_90d': 7.05096774,
#  'market_cap': 915158675741.6387,
#  'market_cap_dominance': 40.3323,
#  'fully_diluted_market_cap': 1017020548062.59,
#  'last_updated': '2021-12-10T04:19:02.000Z'}

# %%
df_ =pd.DataFrame(c[0])
df_
# Out:
#                                                USD
# fully_diluted_market_cap               1.01702e+12
# last_updated              2021-12-10T04:19:02.000Z
# market_cap                             9.15159e+11
# market_cap_dominance                       40.3323
# percent_change_1h                        -0.160014
# percent_change_24h                        -2.52991
# percent_change_30d                        -27.0979
# percent_change_60d                        -14.4451
# percent_change_7d                         -14.4784
# percent_change_90d                         7.05097
# price                                      48429.5
# volume_24h                             2.99733e+10
# volume_change_24h                            5.416

# %%
d=[]
for i in c:
    d.append(i['USD'])

# %%
df_c =pd.DataFrame(d)
df_c['name']=name
df_c = df_c[['name','price','volume_24h','volume_change_24h','percent_change_1h','percent_change_24h','percent_change_7d','percent_change_30d','percent_change_60d','market_cap','market_cap_dominance','fully_diluted_market_cap','last_updated']]
df_c.head()
# Out:
#            name         price    volume_24h  volume_change_24h  \
# 0       Bitcoin  48429.549908  2.997335e+10             5.4160
# 1      Ethereum   4150.713529  2.402692e+10            27.7424
# 2  Binance Coin    579.035025  2.031917e+09           -13.6297
# 3        Tether      1.000867  6.961329e+10             0.3636
# 4        Solana    179.444631  1.941783e+09            -8.3928
#
#    percent_change_1h  percent_change_24h  percent_change_7d  \
# 0          -0.160014           -2.529914         -14.478399
# 1          -0.192770           -5.080277          -8.264504
# 2          -0.202836           -4.136059          -5.896663
# 3          -0.054190           -0.005632          -0.003194
# 4          -1.007376           -5.723305         -22.269773
#
#    percent_change_30d  percent_change_60d    market_cap  market_cap_dominance  \
# 0          -27.097851          -14.445148  9.151587e+11               40.3323
# 1          -11.484106           17.620373  4.925916e+11               21.6574
# 2           -7.419825           38.728528  9.658371e+10                4.2524
# 3            0.045256            0.033173  7.622237e+10                3.3522
# 4          -23.913363           17.923241  5.515182e+10                2.4282
#
#    fully_diluted_market_cap              last_updated
# 0              1.017021e+12  2021-12-10T04:19:02.000Z
# 1              4.925916e+11  2021-12-10T04:19:02.000Z
# 2              9.658371e+10  2021-12-10T04:18:27.000Z
# 3              7.942083e+10  2021-12-10T04:18:27.000Z
# 4              9.166239e+10  2021-12-10T04:19:05.000Z

# %%
df =df.merge(df_c, on='name', how='inner')
df.head()
# Out:
#      id          name symbol          slug  num_market_pairs  \
# 0     1       Bitcoin    BTC       bitcoin              8253
# 1  1027      Ethereum    ETH      ethereum              4621
# 2  1839  Binance Coin    BNB  binance-coin               555
# 3   825        Tether   USDT        tether             20363
# 4  5426        Solana    SOL        solana               197
#
#                  date_added  \
# 0  2013-04-28T00:00:00.000Z
# 1  2015-08-07T00:00:00.000Z
# 2  2017-07-25T00:00:00.000Z
# 3  2015-02-25T00:00:00.000Z
# 4  2020-04-10T00:00:00.000Z
#
#                                                 tags   max_supply  \
# 0  [mineable, pow, sha-256, store-of-value, state...   21000000.0
# 1  [mineable, pow, smart-contracts, ethereum-ecos...          NaN
# 2  [marketplace, centralized-exchange, payments, ...  166801148.0
# 3  [payments, stablecoin, asset-backed-stablecoin...          NaN
# 4  [pos, platform, solana-ecosystem, cms-holdings...          NaN
#
#    circulating_supply  total_supply  ... volume_change_24h  percent_change_1h  \
# 0        1.889670e+07  1.889670e+07  ...            5.4160          -0.160014
# 1        1.186764e+08  1.186764e+08  ...           27.7424          -0.192770
# 2        1.668011e+08  1.668011e+08  ...          -13.6297          -0.202836
# 3        7.615630e+10  7.935200e+10  ...            0.3636          -0.054190
# 4        3.073473e+08  5.108116e+08  ...           -8.3928          -1.007376
#
#   percent_change_24h percent_change_7d percent_change_30d  percent_change_60d  \
# 0          -2.529914        -14.478399         -27.097851          -14.445148
# 1          -5.080277         -8.264504         -11.484106           17.620373
# 2          -4.136059         -5.896663          -7.419825           38.728528
# 3          -0.005632         -0.003194           0.045256            0.033173
# 4          -5.723305        -22.269773         -23.913363           17.923241
#
#      market_cap  market_cap_dominance  fully_diluted_market_cap  \
# 0  9.151587e+11               40.3323              1.017021e+12
# 1  4.925916e+11               21.6574              4.925916e+11
# 2  9.658371e+10                4.2524              9.658371e+10
# 3  7.622237e+10                3.3522              7.942083e+10
# 4  5.515182e+10                2.4282              9.166239e+10
#
#              last_updated_y
# 0  2021-12-10T04:19:02.000Z
# 1  2021-12-10T04:19:02.000Z
# 2  2021-12-10T04:18:27.000Z
# 3  2021-12-10T04:18:27.000Z
# 4  2021-12-10T04:19:05.000Z
#
# [5 rows x 27 columns]

# %%
df = df.drop_duplicates(['name'])
len(df)
# Out:
# 1000

# %%
df = df.dropna(subset=['name'])

# %%
df.reset_index(drop=True, inplace=True)

# %%
df =df.fillna(0)
df.head()
# Out:
#      id          name symbol          slug  num_market_pairs  \
# 0     1       Bitcoin    BTC       bitcoin              8253
# 1  1027      Ethereum    ETH      ethereum              4621
# 2  1839  Binance Coin    BNB  binance-coin               555
# 3   825        Tether   USDT        tether             20363
# 4  5426        Solana    SOL        solana               197
#
#                  date_added  \
# 0  2013-04-28T00:00:00.000Z
# 1  2015-08-07T00:00:00.000Z
# 2  2017-07-25T00:00:00.000Z
# 3  2015-02-25T00:00:00.000Z
# 4  2020-04-10T00:00:00.000Z
#
#                                                 tags   max_supply  \
# 0  [mineable, pow, sha-256, store-of-value, state...   21000000.0
# 1  [mineable, pow, smart-contracts, ethereum-ecos...          0.0
# 2  [marketplace, centralized-exchange, payments, ...  166801148.0
# 3  [payments, stablecoin, asset-backed-stablecoin...          0.0
# 4  [pos, platform, solana-ecosystem, cms-holdings...          0.0
#
#    circulating_supply  total_supply  ... volume_change_24h  percent_change_1h  \
# 0        1.889670e+07  1.889670e+07  ...            5.4160          -0.160014
# 1        1.186764e+08  1.186764e+08  ...           27.7424          -0.192770
# 2        1.668011e+08  1.668011e+08  ...          -13.6297          -0.202836
# 3        7.615630e+10  7.935200e+10  ...            0.3636          -0.054190
# 4        3.073473e+08  5.108116e+08  ...           -8.3928          -1.007376
#
#   percent_change_24h percent_change_7d percent_change_30d  percent_change_60d  \
# 0          -2.529914        -14.478399         -27.097851          -14.445148
# 1          -5.080277         -8.264504         -11.484106           17.620373
# 2          -4.136059         -5.896663          -7.419825           38.728528
# 3          -0.005632         -0.003194           0.045256            0.033173
# 4          -5.723305        -22.269773         -23.913363           17.923241
#
#      market_cap  market_cap_dominance  fully_diluted_market_cap  \
# 0  9.151587e+11               40.3323              1.017021e+12
# 1  4.925916e+11               21.6574              4.925916e+11
# 2  9.658371e+10                4.2524              9.658371e+10
# 3  7.622237e+10                3.3522              7.942083e+10
# 4  5.515182e+10                2.4282              9.166239e+10
#
#              last_updated_y
# 0  2021-12-10T04:19:02.000Z
# 1  2021-12-10T04:19:02.000Z
# 2  2021-12-10T04:18:27.000Z
# 3  2021-12-10T04:18:27.000Z
# 4  2021-12-10T04:19:05.000Z
#
# [5 rows x 27 columns]

# %%
today= dt.datetime.today().strftime("%m-%d-%Y")
today
# Out:
# '12-09-2021'

# %%
df['date']=today
df.head()
# Out:
#      id          name symbol          slug  num_market_pairs  \
# 0     1       Bitcoin    BTC       bitcoin              8253
# 1  1027      Ethereum    ETH      ethereum              4621
# 2  1839  Binance Coin    BNB  binance-coin               555
# 3   825        Tether   USDT        tether             20363
# 4  5426        Solana    SOL        solana               197
#
#                  date_added  \
# 0  2013-04-28T00:00:00.000Z
# 1  2015-08-07T00:00:00.000Z
# 2  2017-07-25T00:00:00.000Z
# 3  2015-02-25T00:00:00.000Z
# 4  2020-04-10T00:00:00.000Z
#
#                                                 tags   max_supply  \
# 0  [mineable, pow, sha-256, store-of-value, state...   21000000.0
# 1  [mineable, pow, smart-contracts, ethereum-ecos...          0.0
# 2  [marketplace, centralized-exchange, payments, ...  166801148.0
# 3  [payments, stablecoin, asset-backed-stablecoin...          0.0
# 4  [pos, platform, solana-ecosystem, cms-holdings...          0.0
#
#    circulating_supply  total_supply  ... percent_change_1h  \
# 0        1.889670e+07  1.889670e+07  ...         -0.160014
# 1        1.186764e+08  1.186764e+08  ...         -0.192770
# 2        1.668011e+08  1.668011e+08  ...         -0.202836
# 3        7.615630e+10  7.935200e+10  ...         -0.054190
# 4        3.073473e+08  5.108116e+08  ...         -1.007376
#
#    percent_change_24h percent_change_7d percent_change_30d percent_change_60d  \
# 0           -2.529914        -14.478399         -27.097851         -14.445148
# 1           -5.080277         -8.264504         -11.484106          17.620373
# 2           -4.136059         -5.896663          -7.419825          38.728528
# 3           -0.005632         -0.003194           0.045256           0.033173
# 4           -5.723305        -22.269773         -23.913363          17.923241
#
#      market_cap  market_cap_dominance  fully_diluted_market_cap  \
# 0  9.151587e+11               40.3323              1.017021e+12
# 1  4.925916e+11               21.6574              4.925916e+11
# 2  9.658371e+10                4.2524              9.658371e+10
# 3  7.622237e+10                3.3522              7.942083e+10
# 4  5.515182e+10                2.4282              9.166239e+10
#
#              last_updated_y        date
# 0  2021-12-10T04:19:02.000Z  12-09-2021
# 1  2021-12-10T04:19:02.000Z  12-09-2021
# 2  2021-12-10T04:18:27.000Z  12-09-2021
# 3  2021-12-10T04:18:27.000Z  12-09-2021
# 4  2021-12-10T04:19:05.000Z  12-09-2021
#
# [5 rows x 28 columns]

# %%
df.dtypes
# Out:
# id                            int64
# name                         object
# symbol                       object
# slug                         object
# num_market_pairs              int64
# date_added                   object
# tags                         object
# max_supply                  float64
# circulating_supply          float64
# total_supply                float64
# platform                     object
# cmc_rank                      int64
# last_updated_x               object
# quote                        object
# tradable                     object
# price                       float64
# volume_24h                  float64
# volume_change_24h           float64
# percent_change_1h           float64
# percent_change_24h          float64
# percent_change_7d           float64
# percent_change_30d          float64
# percent_change_60d          float64
# market_cap                  float64
# market_cap_dominance        float64
# fully_diluted_market_cap    float64
# last_updated_y               object
# date                         object
# dtype: object

# %%
df.to_csv(f'coinmarketcap_{today}.csv', sep=',', index=False)

# %%
data?
