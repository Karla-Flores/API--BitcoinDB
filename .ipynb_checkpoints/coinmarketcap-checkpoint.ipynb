# %%
# Dependencies and Setp up
import json
import requests
import pandas as pd
import numpy as np
import datetime as dt

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json
from pandas.io.json import json_normalize 
import datetime as dt


# API keys
from api_keys import YOUR_API_KEY_

# %%
# url = 'https://pro-api.coinmarketcap.com/'
url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'1000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': YOUR_API_KEY_,
}

# %%
session = Session()
session.headers.update(headers)


try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)

# %%
data['data'][999]
# Out:
# {'id': 8620,
#  'name': 'TOWER',
#  'symbol': 'TOWER',
#  'slug': 'tower-token',
#  'num_market_pairs': 24,
#  'date_added': '2021-03-01T00:00:00.000Z',
#  'tags': ['collectibles-nfts',
#   'gaming',
#   'entertainment',
#   'governance',
#   'metaverse',
#   'animoca-brands-portfolio'],
#  'max_supply': 10000000000,
#  'circulating_supply': 237619986.66069227,
#  'total_supply': 10000000000,
#  'platform': {'id': 1027,
#   'name': 'Ethereum',
#   'symbol': 'ETH',
#   'slug': 'ethereum',
#   'token_address': '0x1c9922314ed1415c95b9fd453c3818fd41867d0b'},
#  'cmc_rank': 1000,
#  'last_updated': '2021-11-12T03:05:06.000Z',
#  'quote': {'USD': {'price': 0.06557320873783762,
#    'volume_24h': 1030821.82027915,
#    'volume_change_24h': -11.4798,
#    'percent_change_1h': -0.65131367,
#    'percent_change_24h': 1.82095044,
#    'percent_change_7d': -20.40306305,
#    'percent_change_30d': 68.10072658,
#    'percent_change_60d': 60.6586295,
#    'percent_change_90d': 4.42496741,
#    'market_cap': 15581504.985583765,
#    'market_cap_dominance': 0.0005,
#    'fully_diluted_market_cap': 655732087.38,
#    'last_updated': '2021-11-12T03:05:06.000Z'}}}

# %%
len(data['data'])
# Out:
# 1000

# %%
type(data)
# Out:
# dict

# %%
c = data['data'][0]
c
# Out:
# {'id': 1,
#  'name': 'Bitcoin',
#  'symbol': 'BTC',
#  'slug': 'bitcoin',
#  'num_market_pairs': 8307,
#  'date_added': '2013-04-28T00:00:00.000Z',
#  'tags': ['mineable',
#   'pow',
#   'sha-256',
#   'store-of-value',
#   'state-channel',
#   'coinbase-ventures-portfolio',
#   'three-arrows-capital-portfolio',
#   'polychain-capital-portfolio',
#   'binance-labs-portfolio',
#   'blockchain-capital-portfolio',
#   'boostvc-portfolio',
#   'cms-holdings-portfolio',
#   'dcg-portfolio',
#   'dragonfly-capital-portfolio',
#   'electric-capital-portfolio',
#   'fabric-ventures-portfolio',
#   'framework-ventures-portfolio',
#   'galaxy-digital-portfolio',
#   'huobi-capital-portfolio',
#   'alameda-research-portfolio',
#   'a16z-portfolio',
#   '1confirmation-portfolio',
#   'winklevoss-capital-portfolio',
#   'usv-portfolio',
#   'placeholder-ventures-portfolio',
#   'pantera-capital-portfolio',
#   'multicoin-capital-portfolio',
#   'paradigm-portfolio'],
#  'max_supply': 21000000,
#  'circulating_supply': 18870687,
#  'total_supply': 18870687,
#  'platform': None,
#  'cmc_rank': 1,
#  'last_updated': '2021-11-12T03:05:02.000Z',
#  'quote': {'USD': {'price': 65032.88210315748,
#    'volume_24h': 36089596893.32686,
#    'volume_change_24h': -27.4697,
#    'percent_change_1h': -0.27642382,
#    'percent_change_24h': 0.73677529,
#    'percent_change_7d': 5.17741037,
#    'percent_change_30d': 15.37096054,
#    'percent_change_60d': 44.69212616,
#    'percent_change_90d': 36.69040907,
#    'market_cap': 1227215162876.5864,
#    'market_cap_dominance': 42.9067,
#    'fully_diluted_market_cap': 1365690524166.31,
#    'last_updated': '2021-11-12T03:05:02.000Z'}}}

# %%
df= pd.DataFrame (data['data'])
df['tradable']=''
df.head()
# Out:
#      id          name symbol          slug  num_market_pairs  \
# 0     1       Bitcoin    BTC       bitcoin              8307
# 1  1027      Ethereum    ETH      ethereum              4535
# 2  1839  Binance Coin    BNB  binance-coin               554
# 3   825        Tether   USDT        tether             19065
# 4  5426        Solana    SOL        solana               180
#
#                  date_added  \
# 0  2013-04-28T00:00:00.000Z
# 1  2015-08-07T00:00:00.000Z
# 2  2017-07-25T00:00:00.000Z
# 3  2015-02-25T00:00:00.000Z
# 4  2020-04-10T00:00:00.000Z
#
#                                                 tags   max_supply  \
# 0  [mineable, pow, sha-256, store-of-value, state...   21000000.0
# 1  [mineable, pow, smart-contracts, ethereum-ecos...          NaN
# 2  [marketplace, centralized-exchange, payments, ...  166801148.0
# 3  [payments, stablecoin, asset-backed-stablecoin...          NaN
# 4  [pos, platform, solana-ecosystem, cms-holdings...          NaN
#
#    circulating_supply  total_supply  \
# 0        1.887069e+07  1.887069e+07
# 1        1.183059e+08  1.183059e+08
# 2        1.668011e+08  1.668011e+08
# 3        7.385989e+10  7.635705e+10
# 4        3.029505e+08  5.087900e+08
#
#                                             platform  cmc_rank  \
# 0                                               None         1
# 1                                               None         2
# 2                                               None         3
# 3  {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...         4
# 4                                               None         5
#
#                last_updated  \
# 0  2021-11-12T03:05:02.000Z
# 1  2021-11-12T03:05:02.000Z
# 2  2021-11-12T03:04:08.000Z
# 3  2021-11-12T03:04:09.000Z
# 4  2021-11-12T03:05:05.000Z
#
#                                                quote tradable
# 0  {'USD': {'price': 65032.88210315748, 'volume_2...
# 1  {'USD': {'price': 4788.498347899757, 'volume_2...
# 2  {'USD': {'price': 631.3125226841674, 'volume_2...
# 3  {'USD': {'price': 1.0014376382306087, 'volume_...
# 4  {'USD': {'price': 236.15100356239873, 'volume_...

# %%
name = df['name']
name
# Out:
# 0           Bitcoin
# 1          Ethereum
# 2      Binance Coin
# 3            Tether
# 4            Solana
#            ...
# 995            VIDY
# 996       CWV Chain
# 997            BIDR
# 998       Venus DOT
# 999           TOWER
# Name: name, Length: 1000, dtype: object

# %%
c=df['quote']
type(c)
# Out:
# pandas.core.series.Series

# %%
c[0]['USD']
# Out:
# {'price': 65032.88210315748,
#  'volume_24h': 36089596893.32686,
#  'volume_change_24h': -27.4697,
#  'percent_change_1h': -0.27642382,
#  'percent_change_24h': 0.73677529,
#  'percent_change_7d': 5.17741037,
#  'percent_change_30d': 15.37096054,
#  'percent_change_60d': 44.69212616,
#  'percent_change_90d': 36.69040907,
#  'market_cap': 1227215162876.5864,
#  'market_cap_dominance': 42.9067,
#  'fully_diluted_market_cap': 1365690524166.31,
#  'last_updated': '2021-11-12T03:05:02.000Z'}

# %%
df_ =pd.DataFrame(c[0])
df_
# Out:
#                                                USD
# fully_diluted_market_cap               1.36569e+12
# last_updated              2021-11-12T03:05:02.000Z
# market_cap                             1.22722e+12
# market_cap_dominance                       42.9067
# percent_change_1h                        -0.276424
# percent_change_24h                        0.736775
# percent_change_30d                          15.371
# percent_change_60d                         44.6921
# percent_change_7d                          5.17741
# percent_change_90d                         36.6904
# price                                      65032.9
# volume_24h                             3.60896e+10
# volume_change_24h                         -27.4697

# %%
d=[]
for i in c:
    d.append(i['USD'])

# %%
df_c =pd.DataFrame(d)
df_c['name']=name
df_c = df_c[['name','price','volume_24h','volume_change_24h','percent_change_1h','percent_change_24h','percent_change_7d','percent_change_30d','percent_change_60d','market_cap','market_cap_dominance','fully_diluted_market_cap','last_updated']]
df_c.head()
# Out:
#            name         price    volume_24h  volume_change_24h  \
# 0       Bitcoin  65032.882103  3.608960e+10           -27.4697
# 1      Ethereum   4788.498348  1.839135e+10           -20.9368
# 2  Binance Coin    631.312523  2.236726e+09           -40.8460
# 3        Tether      1.001438  8.383582e+10           -27.8906
# 4        Solana    236.151004  2.602400e+09           -35.2821
#
#    percent_change_1h  percent_change_24h  percent_change_7d  \
# 0          -0.276424            0.736775           5.177410
# 1          -0.105389            3.759398           6.025718
# 2          -0.476887            2.992796          11.175367
# 3           0.091829            0.063067           0.060538
# 4          -0.446976           -0.043739          -2.642354
#
#    percent_change_30d  percent_change_60d    market_cap  market_cap_dominance  \
# 0           15.370961           44.692126  1.227215e+12               42.9067
# 1           36.385449           45.538877  5.665077e+11               19.8191
# 2           36.676968           57.595929  1.053037e+11                3.6822
# 3            0.170777            0.118469  7.396607e+10                2.5865
# 4           56.875444           49.037199  7.154207e+10                2.5029
#
#    fully_diluted_market_cap              last_updated
# 0              1.365691e+12  2021-11-12T03:05:02.000Z
# 1              5.665077e+11  2021-11-12T03:05:02.000Z
# 2              1.053037e+11  2021-11-12T03:04:08.000Z
# 3              7.646683e+10  2021-11-12T03:04:09.000Z
# 4              1.201513e+11  2021-11-12T03:05:05.000Z

# %%
df =df.merge(df_c, on='name', how='inner')
df.head()
# Out:
#      id          name symbol          slug  num_market_pairs  \
# 0     1       Bitcoin    BTC       bitcoin              8307
# 1  1027      Ethereum    ETH      ethereum              4535
# 2  1839  Binance Coin    BNB  binance-coin               554
# 3   825        Tether   USDT        tether             19065
# 4  5426        Solana    SOL        solana               180
#
#                  date_added  \
# 0  2013-04-28T00:00:00.000Z
# 1  2015-08-07T00:00:00.000Z
# 2  2017-07-25T00:00:00.000Z
# 3  2015-02-25T00:00:00.000Z
# 4  2020-04-10T00:00:00.000Z
#
#                                                 tags   max_supply  \
# 0  [mineable, pow, sha-256, store-of-value, state...   21000000.0
# 1  [mineable, pow, smart-contracts, ethereum-ecos...          NaN
# 2  [marketplace, centralized-exchange, payments, ...  166801148.0
# 3  [payments, stablecoin, asset-backed-stablecoin...          NaN
# 4  [pos, platform, solana-ecosystem, cms-holdings...          NaN
#
#    circulating_supply  total_supply  ... volume_change_24h  percent_change_1h  \
# 0        1.887069e+07  1.887069e+07  ...          -27.4697          -0.276424
# 1        1.183059e+08  1.183059e+08  ...          -20.9368          -0.105389
# 2        1.668011e+08  1.668011e+08  ...          -40.8460          -0.476887
# 3        7.385989e+10  7.635705e+10  ...          -27.8906           0.091829
# 4        3.029505e+08  5.087900e+08  ...          -35.2821          -0.446976
#
#   percent_change_24h percent_change_7d percent_change_30d  percent_change_60d  \
# 0           0.736775          5.177410          15.370961           44.692126
# 1           3.759398          6.025718          36.385449           45.538877
# 2           2.992796         11.175367          36.676968           57.595929
# 3           0.063067          0.060538           0.170777            0.118469
# 4          -0.043739         -2.642354          56.875444           49.037199
#
#      market_cap  market_cap_dominance  fully_diluted_market_cap  \
# 0  1.227215e+12               42.9067              1.365691e+12
# 1  5.665077e+11               19.8191              5.665077e+11
# 2  1.053037e+11                3.6822              1.053037e+11
# 3  7.396607e+10                2.5865              7.646683e+10
# 4  7.154207e+10                2.5029              1.201513e+11
#
#              last_updated_y
# 0  2021-11-12T03:05:02.000Z
# 1  2021-11-12T03:05:02.000Z
# 2  2021-11-12T03:04:08.000Z
# 3  2021-11-12T03:04:09.000Z
# 4  2021-11-12T03:05:05.000Z
#
# [5 rows x 27 columns]

# %%
df = df.drop_duplicates(['name'])
len(df)
# Out:
# 1000

# %%
df = df.dropna(subset=['name'])

# %%
df.reset_index(drop=True, inplace=True)

# %%
df =df.fillna(0)
df.head()
# Out:
#      id          name symbol          slug  num_market_pairs  \
# 0     1       Bitcoin    BTC       bitcoin              8307
# 1  1027      Ethereum    ETH      ethereum              4535
# 2  1839  Binance Coin    BNB  binance-coin               554
# 3   825        Tether   USDT        tether             19065
# 4  5426        Solana    SOL        solana               180
#
#                  date_added  \
# 0  2013-04-28T00:00:00.000Z
# 1  2015-08-07T00:00:00.000Z
# 2  2017-07-25T00:00:00.000Z
# 3  2015-02-25T00:00:00.000Z
# 4  2020-04-10T00:00:00.000Z
#
#                                                 tags   max_supply  \
# 0  [mineable, pow, sha-256, store-of-value, state...   21000000.0
# 1  [mineable, pow, smart-contracts, ethereum-ecos...          0.0
# 2  [marketplace, centralized-exchange, payments, ...  166801148.0
# 3  [payments, stablecoin, asset-backed-stablecoin...          0.0
# 4  [pos, platform, solana-ecosystem, cms-holdings...          0.0
#
#    circulating_supply  total_supply  ... volume_change_24h  percent_change_1h  \
# 0        1.887069e+07  1.887069e+07  ...          -27.4697          -0.276424
# 1        1.183059e+08  1.183059e+08  ...          -20.9368          -0.105389
# 2        1.668011e+08  1.668011e+08  ...          -40.8460          -0.476887
# 3        7.385989e+10  7.635705e+10  ...          -27.8906           0.091829
# 4        3.029505e+08  5.087900e+08  ...          -35.2821          -0.446976
#
#   percent_change_24h percent_change_7d percent_change_30d  percent_change_60d  \
# 0           0.736775          5.177410          15.370961           44.692126
# 1           3.759398          6.025718          36.385449           45.538877
# 2           2.992796         11.175367          36.676968           57.595929
# 3           0.063067          0.060538           0.170777            0.118469
# 4          -0.043739         -2.642354          56.875444           49.037199
#
#      market_cap  market_cap_dominance  fully_diluted_market_cap  \
# 0  1.227215e+12               42.9067              1.365691e+12
# 1  5.665077e+11               19.8191              5.665077e+11
# 2  1.053037e+11                3.6822              1.053037e+11
# 3  7.396607e+10                2.5865              7.646683e+10
# 4  7.154207e+10                2.5029              1.201513e+11
#
#              last_updated_y
# 0  2021-11-12T03:05:02.000Z
# 1  2021-11-12T03:05:02.000Z
# 2  2021-11-12T03:04:08.000Z
# 3  2021-11-12T03:04:09.000Z
# 4  2021-11-12T03:05:05.000Z
#
# [5 rows x 27 columns]

# %%
today= dt.datetime.today().strftime("%m-%d-%Y")
today
# Out:
# '11-11-2021'

# %%
df['date']=today
df.head()
# Out:
#      id          name symbol          slug  num_market_pairs  \
# 0     1       Bitcoin    BTC       bitcoin              8307
# 1  1027      Ethereum    ETH      ethereum              4535
# 2  1839  Binance Coin    BNB  binance-coin               554
# 3   825        Tether   USDT        tether             19065
# 4  5426        Solana    SOL        solana               180
#
#                  date_added  \
# 0  2013-04-28T00:00:00.000Z
# 1  2015-08-07T00:00:00.000Z
# 2  2017-07-25T00:00:00.000Z
# 3  2015-02-25T00:00:00.000Z
# 4  2020-04-10T00:00:00.000Z
#
#                                                 tags   max_supply  \
# 0  [mineable, pow, sha-256, store-of-value, state...   21000000.0
# 1  [mineable, pow, smart-contracts, ethereum-ecos...          0.0
# 2  [marketplace, centralized-exchange, payments, ...  166801148.0
# 3  [payments, stablecoin, asset-backed-stablecoin...          0.0
# 4  [pos, platform, solana-ecosystem, cms-holdings...          0.0
#
#    circulating_supply  total_supply  ... percent_change_1h  \
# 0        1.887069e+07  1.887069e+07  ...         -0.276424
# 1        1.183059e+08  1.183059e+08  ...         -0.105389
# 2        1.668011e+08  1.668011e+08  ...         -0.476887
# 3        7.385989e+10  7.635705e+10  ...          0.091829
# 4        3.029505e+08  5.087900e+08  ...         -0.446976
#
#    percent_change_24h percent_change_7d percent_change_30d percent_change_60d  \
# 0            0.736775          5.177410          15.370961          44.692126
# 1            3.759398          6.025718          36.385449          45.538877
# 2            2.992796         11.175367          36.676968          57.595929
# 3            0.063067          0.060538           0.170777           0.118469
# 4           -0.043739         -2.642354          56.875444          49.037199
#
#      market_cap  market_cap_dominance  fully_diluted_market_cap  \
# 0  1.227215e+12               42.9067              1.365691e+12
# 1  5.665077e+11               19.8191              5.665077e+11
# 2  1.053037e+11                3.6822              1.053037e+11
# 3  7.396607e+10                2.5865              7.646683e+10
# 4  7.154207e+10                2.5029              1.201513e+11
#
#              last_updated_y        date
# 0  2021-11-12T03:05:02.000Z  11-11-2021
# 1  2021-11-12T03:05:02.000Z  11-11-2021
# 2  2021-11-12T03:04:08.000Z  11-11-2021
# 3  2021-11-12T03:04:09.000Z  11-11-2021
# 4  2021-11-12T03:05:05.000Z  11-11-2021
#
# [5 rows x 28 columns]

# %%
df.dtypes
# Out:
# id                            int64
# name                         object
# symbol                       object
# slug                         object
# num_market_pairs              int64
# date_added                   object
# tags                         object
# max_supply                  float64
# circulating_supply          float64
# total_supply                float64
# platform                     object
# cmc_rank                      int64
# last_updated_x               object
# quote                        object
# tradable                     object
# price                       float64
# volume_24h                  float64
# volume_change_24h           float64
# percent_change_1h           float64
# percent_change_24h          float64
# percent_change_7d           float64
# percent_change_30d          float64
# percent_change_60d          float64
# market_cap                  float64
# market_cap_dominance        float64
# fully_diluted_market_cap    float64
# last_updated_y               object
# date                         object
# dtype: object

# %%
df.to_csv(f'coinmarketcap_{today}.csv', sep=',', index=False)

# %%
data?
