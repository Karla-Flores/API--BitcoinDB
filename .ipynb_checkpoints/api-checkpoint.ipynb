# %%
# This library does not brin much information about daily transactions

# %%
from tradingview_ta import TA_Handler, Interval, Exchange

# %%
tesla = TA_Handler(
    symbol="TSLA",
    screener="america",
    exchange="NASDAQ",
    interval=Interval.INTERVAL_1_DAY
)
print(tesla.get_analysis().summary)
# Example output: {"RECOMMENDATION": "BUY", "BUY": 8, "NEUTRAL": 6, "SELL": 3}
# Out:
# {'RECOMMENDATION': 'BUY', 'BUY': 15, 'SELL': 5, 'NEUTRAL': 6}

# %%
tesla = TA_Handler(
    symbol="RSRBTC",
    screener="crypto",
    exchange="BINANCE",
    interval=Interval.INTERVAL_1_MONTH
)
print(tesla.get_analysis().summary)
# Out:
# {'RECOMMENDATION': 'SELL', 'BUY': 3, 'SELL': 6, 'NEUTRAL': 6}

# %% [markdown]
# # https://www.blockchain.com/api

# %% [markdown]
# # 24 Hours Ticker

# %%
# Dependencies and Setp up
import json
import requests
import pandas as pd
import numpy as np
import datetime as dt

# %%
url = 'https://api.blockchain.com/v3/exchange/tickers'

# %%
# Json file
response = requests.get(url).json()

# %%
response
# Out:
# [{'symbol': 'XLM-EUR',
#   'price_24h': 0.31936,
#   'volume_24h': 85053.0068184,
#   'last_trade_price': 0.31579},
#  {'symbol': 'ALGO-BTC',
#   'price_24h': 3.087e-05,
#   'volume_24h': 196.891517,
#   'last_trade_price': 3.037e-05},
#  {'symbol': 'EFI-USDT',
#   'price_24h': 1.187,
#   'volume_24h': 3985.87296117,
#   'last_trade_price': 1.499},
#  {'symbol': 'XLM-BTC',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 5.51e-06},
#  {'symbol': 'USDC-GBP',
#   'price_24h': 0.7447,
#   'volume_24h': 50000.0,
#   'last_trade_price': 0.7447},
#  {'symbol': 'OGN-USDT',
#   'price_24h': 1.0535,
#   'volume_24h': 0.0,
#   'last_trade_price': 1.0535},
#  {'symbol': 'CLOUT-USD',
#   'price_24h': 78.82,
#   'volume_24h': 794.84762773,
#   'last_trade_price': 76.44},
#  {'symbol': 'STX-USDC',
#   'price_24h': 1.941,
#   'volume_24h': 16402.12535599,
#   'last_trade_price': 1.986},
#  {'symbol': 'EOS-USD',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.0},
#  {'symbol': 'BCH-USD',
#   'price_24h': 593.0,
#   'volume_24h': 158.8120227,
#   'last_trade_price': 595.4},
#  {'symbol': 'PAX-USD',
#   'price_24h': 1.0,
#   'volume_24h': 30000.0,
#   'last_trade_price': 1.0001},
#  {'symbol': 'DAI-EUR',
#   'price_24h': 0.8675,
#   'volume_24h': 9994.3089,
#   'last_trade_price': 0.8675},
#  {'symbol': 'USDT-GBP',
#   'price_24h': 0.7419,
#   'volume_24h': 7871.5412,
#   'last_trade_price': 0.7425},
#  {'symbol': 'LINK-USDT',
#   'price_24h': 32.65,
#   'volume_24h': 109.45037471,
#   'last_trade_price': 33.407},
#  {'symbol': 'STX-USD',
#   'price_24h': 1.91,
#   'volume_24h': 42453.66799312,
#   'last_trade_price': 1.986},
#  {'symbol': 'MATIC-USDT',
#   'price_24h': 1.944,
#   'volume_24h': 0.0,
#   'last_trade_price': 1.944},
#  {'symbol': 'WDGLD-USD',
#   'price_24h': 175.36,
#   'volume_24h': 129.32351671,
#   'last_trade_price': 175.86},
#  {'symbol': 'ETH-USD',
#   'price_24h': 4479.67,
#   'volume_24h': 1997.7199212,
#   'last_trade_price': 4490.41},
#  {'symbol': 'LEND-USD',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.4909},
#  {'symbol': 'XLM-PAX',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.06981},
#  {'symbol': 'XRP-EUR',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.22},
#  {'symbol': 'XLM-USD',
#   'price_24h': 0.36843,
#   'volume_24h': 197183.6895225,
#   'last_trade_price': 0.36304},
#  {'symbol': 'LINK-USDC',
#   'price_24h': 32.852,
#   'volume_24h': 15.20670243,
#   'last_trade_price': 32.852},
#  {'symbol': 'DGLD-BTC',
#   'price_24h': 0.002834,
#   'volume_24h': 0.05652057,
#   'last_trade_price': 0.002834},
#  {'symbol': 'BCH-EUR',
#   'price_24h': 515.97,
#   'volume_24h': 35.49015694,
#   'last_trade_price': 515.58},
#  {'symbol': 'BCH-BTC',
#   'price_24h': 0.009769,
#   'volume_24h': 0.5400576,
#   'last_trade_price': 0.009772},
#  {'symbol': 'CLOUT-BTC',
#   'price_24h': 0.00127,
#   'volume_24h': 485.2809721,
#   'last_trade_price': 0.001237},
#  {'symbol': 'BTC-USD',
#   'price_24h': 61086.82,
#   'volume_24h': 324.53368103,
#   'last_trade_price': 61205.26},
#  {'symbol': 'BCH-ETH',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.582678},
#  {'symbol': 'ETH-TRY',
#   'price_24h': 23950.9,
#   'volume_24h': 0.0,
#   'last_trade_price': 23950.9},
#  {'symbol': 'BTC-TRY',
#   'price_24h': 390682.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 390682.0},
#  {'symbol': 'ALGO-USD',
#   'price_24h': 1.8457,
#   'volume_24h': 64759.984649,
#   'last_trade_price': 1.8537},
#  {'symbol': 'ETH-EUR',
#   'price_24h': 3864.21,
#   'volume_24h': 19.53799082,
#   'last_trade_price': 3901.27},
#  {'symbol': 'DOGE-USD',
#   'price_24h': 0.26156,
#   'volume_24h': 31271.0605894,
#   'last_trade_price': 0.26254},
#  {'symbol': 'STX-USDT',
#   'price_24h': 1.922,
#   'volume_24h': 54947.08423936,
#   'last_trade_price': 1.984},
#  {'symbol': 'XRP-USD',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.29},
#  {'symbol': 'XLM-ETH',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.00019195},
#  {'symbol': 'YFI-USD',
#   'price_24h': 34389.41,
#   'volume_24h': 0.0,
#   'last_trade_price': 34389.41},
#  {'symbol': 'BTC-PAX',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 6115.0},
#  {'symbol': 'WBTC-USDC',
#   'price_24h': 60485.35,
#   'volume_24h': 0.0,
#   'last_trade_price': 60485.35},
#  {'symbol': 'MKR-USDT',
#   'price_24h': 2671.2,
#   'volume_24h': 0.0,
#   'last_trade_price': 2671.2},
#  {'symbol': 'UNI-USDT',
#   'price_24h': 27.944,
#   'volume_24h': 0.0,
#   'last_trade_price': 27.944},
#  {'symbol': 'DOT-EUR',
#   'price_24h': 46.22,
#   'volume_24h': 169.28284604,
#   'last_trade_price': 42.28},
#  {'symbol': 'BCH-PAX',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 339.24},
#  {'symbol': 'DAI-USDC',
#   'price_24h': 1.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 1.0},
#  {'symbol': 'UNI-USD',
#   'price_24h': 25.039,
#   'volume_24h': 0.0,
#   'last_trade_price': 25.028},
#  {'symbol': 'ETH-BTC',
#   'price_24h': 0.073714,
#   'volume_24h': 0.23709176,
#   'last_trade_price': 0.073625},
#  {'symbol': 'WDGLD-BTC',
#   'price_24h': 0.002813,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.002813},
#  {'symbol': 'USDC-EUR',
#   'price_24h': 0.8672,
#   'volume_24h': 7.9064,
#   'last_trade_price': 0.8672},
#  {'symbol': 'WBTC-USDT',
#   'price_24h': 58764.45,
#   'volume_24h': 0.0,
#   'last_trade_price': 58202.11},
#  {'symbol': 'MKR-USDC',
#   'price_24h': 2453.35,
#   'volume_24h': 0.0,
#   'last_trade_price': 2453.35},
#  {'symbol': 'LINK-USD',
#   'price_24h': 31.365,
#   'volume_24h': 497.66509356,
#   'last_trade_price': 32.8},
#  {'symbol': 'LTC-USD',
#   'price_24h': 200.25,
#   'volume_24h': 69.79721797,
#   'last_trade_price': 199.33},
#  {'symbol': 'DOGE-USDT',
#   'price_24h': 0.26351,
#   'volume_24h': 4385.7266345,
#   'last_trade_price': 0.26435},
#  {'symbol': 'COMP-USD',
#   'price_24h': 366.3,
#   'volume_24h': 5.44669979,
#   'last_trade_price': 362.42},
#  {'symbol': 'LTC-BTC',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.005827},
#  {'symbol': 'EFI-USD',
#   'price_24h': 1.25,
#   'volume_24h': 152.203,
#   'last_trade_price': 1.38},
#  {'symbol': 'EOS-USDT',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.0},
#  {'symbol': 'DAI-USDT',
#   'price_24h': 1.0001,
#   'volume_24h': 0.0,
#   'last_trade_price': 1.0001},
#  {'symbol': 'BTC-GBP',
#   'price_24h': 45378.73,
#   'volume_24h': 8.75213549,
#   'last_trade_price': 45418.5},
#  {'symbol': 'USDC-USD',
#   'price_24h': 0.9999,
#   'volume_24h': 27274.4305,
#   'last_trade_price': 1.0002},
#  {'symbol': 'MKR-USD',
#   'price_24h': 2523.37,
#   'volume_24h': 0.0,
#   'last_trade_price': 2523.37},
#  {'symbol': 'LTC-TRY',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.0},
#  {'symbol': 'WBTC-USD',
#   'price_24h': 58824.32,
#   'volume_24h': 0.0,
#   'last_trade_price': 58824.32},
#  {'symbol': 'UNI-USDC',
#   'price_24h': 25.714,
#   'volume_24h': 0.0,
#   'last_trade_price': 25.714},
#  {'symbol': 'LTC-EUR',
#   'price_24h': 173.7,
#   'volume_24h': 101.92149824,
#   'last_trade_price': 172.36},
#  {'symbol': 'WDGLD-DGLD',
#   'price_24h': 1.01,
#   'volume_24h': 0.0,
#   'last_trade_price': 1.01},
#  {'symbol': 'DOT-USD',
#   'price_24h': 53.7,
#   'volume_24h': 2686.2274639,
#   'last_trade_price': 51.18},
#  {'symbol': 'USDT-TRY',
#   'price_24h': 8.29,
#   'volume_24h': 0.0,
#   'last_trade_price': 8.29},
#  {'symbol': 'USDT-USD',
#   'price_24h': 1.0009,
#   'volume_24h': 28409.5955,
#   'last_trade_price': 1.001},
#  {'symbol': 'COMP-USDT',
#   'price_24h': 366.77,
#   'volume_24h': 0.0,
#   'last_trade_price': 366.77},
#  {'symbol': 'LEND-USDT',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.4854},
#  {'symbol': 'ETH-GBP',
#   'price_24h': 3330.0,
#   'volume_24h': 27.67043324,
#   'last_trade_price': 3341.19},
#  {'symbol': 'OGN-USD',
#   'price_24h': 0.96,
#   'volume_24h': 491.857595,
#   'last_trade_price': 0.96},
#  {'symbol': 'AAVE-USDT',
#   'price_24h': 328.53,
#   'volume_24h': 75.07311943,
#   'last_trade_price': 344.03},
#  {'symbol': 'ETH-PAX',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 219.41},
#  {'symbol': 'USDC-USDT',
#   'price_24h': 0.9995,
#   'volume_24h': 3373.474,
#   'last_trade_price': 0.999},
#  {'symbol': 'BCH-USDT',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 358.46},
#  {'symbol': 'ALGO-USDT',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.3614},
#  {'symbol': 'ENJ-USD',
#   'price_24h': 2.7929,
#   'volume_24h': 459.8453,
#   'last_trade_price': 2.8947},
#  {'symbol': 'SUSHI-USDC',
#   'price_24h': 12.097,
#   'volume_24h': 0.0,
#   'last_trade_price': 12.097},
#  {'symbol': 'LTC-USDT',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 73.28},
#  {'symbol': 'DAI-GBP',
#   'price_24h': 0.7322,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.7322},
#  {'symbol': 'EFI-USDC',
#   'price_24h': 1.2,
#   'volume_24h': 0.0,
#   'last_trade_price': 1.2},
#  {'symbol': 'BTC-EUR',
#   'price_24h': 52883.46,
#   'volume_24h': 14.7881428,
#   'last_trade_price': 52998.47},
#  {'symbol': 'USDT-EUR',
#   'price_24h': 0.8657,
#   'volume_24h': 213210.1093,
#   'last_trade_price': 0.8664},
#  {'symbol': 'DGLD-USD',
#   'price_24h': 174.26,
#   'volume_24h': 204.4981,
#   'last_trade_price': 177.31},
#  {'symbol': 'EOS-USDC',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.0},
#  {'symbol': 'YFI-USDT',
#   'price_24h': 33886.08,
#   'volume_24h': 0.00552711,
#   'last_trade_price': 34080.64},
#  {'symbol': 'SUSHI-USDT',
#   'price_24h': 13.141,
#   'volume_24h': 0.0,
#   'last_trade_price': 13.141},
#  {'symbol': 'COMP-USDC',
#   'price_24h': 339.89,
#   'volume_24h': 0.0,
#   'last_trade_price': 339.89},
#  {'symbol': 'ENJ-USDT',
#   'price_24h': 2.8651,
#   'volume_24h': 10.030004,
#   'last_trade_price': 2.8752},
#  {'symbol': 'LTC-PAX',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 74.03},
#  {'symbol': 'MATIC-USDC',
#   'price_24h': 1.905,
#   'volume_24h': 0.0,
#   'last_trade_price': 1.905},
#  {'symbol': 'PAX-EUR',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.9444},
#  {'symbol': 'AAVE-USD',
#   'price_24h': 326.41,
#   'volume_24h': 161.8688869,
#   'last_trade_price': 332.53},
#  {'symbol': 'BTC-USDT',
#   'price_24h': 61193.9,
#   'volume_24h': 4.65867507,
#   'last_trade_price': 61329.42},
#  {'symbol': 'DOT-GBP',
#   'price_24h': 40.0,
#   'volume_24h': 504.91492585,
#   'last_trade_price': 37.0},
#  {'symbol': 'ETH-USDT',
#   'price_24h': 4521.11,
#   'volume_24h': 18.40709239,
#   'last_trade_price': 4502.69},
#  {'symbol': 'MATIC-USD',
#   'price_24h': 1.999,
#   'volume_24h': 988.6708093,
#   'last_trade_price': 2.011},
#  {'symbol': 'SUSHI-USD',
#   'price_24h': 12.208,
#   'volume_24h': 40.71453789,
#   'last_trade_price': 13.181},
#  {'symbol': 'DAI-USD',
#   'price_24h': 1.0004,
#   'volume_24h': 26086.7112,
#   'last_trade_price': 0.9945}]

# %%
type(response)
# Out:
# list

# %%
len(response)
# Out:
# 102

# %%
df= pd.DataFrame (response)
df
# Out:
#         symbol    price_24h    volume_24h  last_trade_price
# 0      XLM-EUR     0.319360  85053.006818          0.315790
# 1     ALGO-BTC     0.000031    196.891517          0.000030
# 2     EFI-USDT     1.187000   3985.872961          1.499000
# 3      XLM-BTC     0.000000      0.000000          0.000006
# 4     USDC-GBP     0.744700  50000.000000          0.744700
# ..         ...          ...           ...               ...
# 97     DOT-GBP    40.000000    504.914926         37.000000
# 98    ETH-USDT  4521.110000     18.407092       4502.690000
# 99   MATIC-USD     1.999000    988.670809          2.011000
# 100  SUSHI-USD    12.208000     40.714538         13.181000
# 101    DAI-USD     1.000400  26086.711200          0.994500
#
# [102 rows x 4 columns]

# %% [markdown]
# Timestamp does not work yet! in order to work to machine learning in time we need to add a column with the date

# %%
today= dt.datetime.today().strftime("%m-%d-%Y")
today
# Out:
# '11-05-2021'

# %%
df.to_csv(f'blockchain_{today}.csv', sep=',', index=False)
