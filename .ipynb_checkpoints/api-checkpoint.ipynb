# %%
# This library does not brin much information about daily transactions

# %%
from tradingview_ta import TA_Handler, Interval, Exchange

# %%
tesla = TA_Handler(
    symbol="TSLA",
    screener="america",
    exchange="NASDAQ",
    interval=Interval.INTERVAL_1_DAY
)
print(tesla.get_analysis().summary)
# Example output: {"RECOMMENDATION": "BUY", "BUY": 8, "NEUTRAL": 6, "SELL": 3}
# Out:
# {'RECOMMENDATION': 'BUY', 'BUY': 14, 'SELL': 6, 'NEUTRAL': 6}

# %%
tesla = TA_Handler(
    symbol="RSRBTC",
    screener="crypto",
    exchange="BINANCE",
    interval=Interval.INTERVAL_1_MONTH
)
print(tesla.get_analysis().summary)
# Out:
# {'RECOMMENDATION': 'SELL', 'BUY': 2, 'SELL': 8, 'NEUTRAL': 5}

# %% [markdown]
# # https://www.blockchain.com/api

# %% [markdown]
# # 24 Hours Ticker

# %%
# Dependencies and Setp up
import json
import requests
import pandas as pd
import numpy as np

# %%
url = 'https://api.blockchain.com/v3/exchange/tickers'

# %%
# Json file
response = requests.get(url).json()

# %%
response
# Out:
# [{'symbol': 'XLM-EUR',
#   'price_24h': 0.31513,
#   'volume_24h': 111607.5091383,
#   'last_trade_price': 0.326},
#  {'symbol': 'ALGO-BTC',
#   'price_24h': 3.019e-05,
#   'volume_24h': 0.0,
#   'last_trade_price': 3.019e-05},
#  {'symbol': 'EFI-USDT',
#   'price_24h': 0.825,
#   'volume_24h': 22.61630462,
#   'last_trade_price': 0.825},
#  {'symbol': 'XLM-BTC',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 5.51e-06},
#  {'symbol': 'USDC-GBP',
#   'price_24h': 0.745,
#   'volume_24h': 13293.1616,
#   'last_trade_price': 0.751},
#  {'symbol': 'CLOUT-USD',
#   'price_24h': 76.0,
#   'volume_24h': 1582.71060032,
#   'last_trade_price': 80.0},
#  {'symbol': 'OGN-USDT',
#   'price_24h': 0.857,
#   'volume_24h': 73.1,
#   'last_trade_price': 1.0017},
#  {'symbol': 'STX-USDC',
#   'price_24h': 1.909,
#   'volume_24h': 11428.34899807,
#   'last_trade_price': 1.956},
#  {'symbol': 'EOS-USD',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.0},
#  {'symbol': 'PAX-USD',
#   'price_24h': 0.9999,
#   'volume_24h': 495.0,
#   'last_trade_price': 0.9999},
#  {'symbol': 'BCH-USD',
#   'price_24h': 588.0,
#   'volume_24h': 35.68835955,
#   'last_trade_price': 602.0},
#  {'symbol': 'DAI-EUR',
#   'price_24h': 0.8629,
#   'volume_24h': 100.0,
#   'last_trade_price': 0.8629},
#  {'symbol': 'USDT-GBP',
#   'price_24h': 0.7326,
#   'volume_24h': 101653.8104,
#   'last_trade_price': 0.7357},
#  {'symbol': 'LINK-USDT',
#   'price_24h': 29.249,
#   'volume_24h': 0.0,
#   'last_trade_price': 29.249},
#  {'symbol': 'STX-USD',
#   'price_24h': 1.907,
#   'volume_24h': 55441.01565371,
#   'last_trade_price': 1.95},
#  {'symbol': 'MATIC-USDT',
#   'price_24h': 1.993,
#   'volume_24h': 2496.09425747,
#   'last_trade_price': 2.015},
#  {'symbol': 'WDGLD-USD',
#   'price_24h': 175.26,
#   'volume_24h': 38.7005393,
#   'last_trade_price': 174.65},
#  {'symbol': 'ETH-USD',
#   'price_24h': 4307.31,
#   'volume_24h': 3243.67990864,
#   'last_trade_price': 4503.94},
#  {'symbol': 'LEND-USD',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.4909},
#  {'symbol': 'XLM-PAX',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.06981},
#  {'symbol': 'XRP-EUR',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.22},
#  {'symbol': 'XLM-USD',
#   'price_24h': 0.3658,
#   'volume_24h': 577180.6594987,
#   'last_trade_price': 0.37735},
#  {'symbol': 'LINK-USDC',
#   'price_24h': 29.333,
#   'volume_24h': 0.0,
#   'last_trade_price': 29.333},
#  {'symbol': 'DGLD-BTC',
#   'price_24h': 0.002879,
#   'volume_24h': 61.97656045,
#   'last_trade_price': 0.002751},
#  {'symbol': 'BCH-EUR',
#   'price_24h': 505.33,
#   'volume_24h': 96.68896967,
#   'last_trade_price': 521.0},
#  {'symbol': 'BCH-BTC',
#   'price_24h': 0.009454,
#   'volume_24h': 0.03946943,
#   'last_trade_price': 0.009454},
#  {'symbol': 'CLOUT-BTC',
#   'price_24h': 0.001247,
#   'volume_24h': 32.15132621,
#   'last_trade_price': 0.001254},
#  {'symbol': 'BTC-USD',
#   'price_24h': 60651.02,
#   'volume_24h': 449.37134971,
#   'last_trade_price': 63145.43},
#  {'symbol': 'BCH-ETH',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.582678},
#  {'symbol': 'ETH-TRY',
#   'price_24h': 23950.9,
#   'volume_24h': 0.0,
#   'last_trade_price': 23950.9},
#  {'symbol': 'BTC-TRY',
#   'price_24h': 390682.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 390682.0},
#  {'symbol': 'ALGO-USD',
#   'price_24h': 1.8256,
#   'volume_24h': 229096.877885,
#   'last_trade_price': 1.8739},
#  {'symbol': 'ETH-EUR',
#   'price_24h': 3725.83,
#   'volume_24h': 46.77437893,
#   'last_trade_price': 3890.34},
#  {'symbol': 'DOGE-USD',
#   'price_24h': 0.27759,
#   'volume_24h': 42162.8471331,
#   'last_trade_price': 0.26953},
#  {'symbol': 'STX-USDT',
#   'price_24h': 1.921,
#   'volume_24h': 42877.32440374,
#   'last_trade_price': 1.957},
#  {'symbol': 'XRP-USD',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.29},
#  {'symbol': 'XLM-ETH',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.00019195},
#  {'symbol': 'YFI-USD',
#   'price_24h': 34736.42,
#   'volume_24h': 0.01429964,
#   'last_trade_price': 34389.41},
#  {'symbol': 'BTC-PAX',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 6115.0},
#  {'symbol': 'WBTC-USDC',
#   'price_24h': 58591.82,
#   'volume_24h': 0.00015603,
#   'last_trade_price': 61091.11},
#  {'symbol': 'MKR-USDT',
#   'price_24h': 2520.0,
#   'volume_24h': 0.00762436,
#   'last_trade_price': 2671.2},
#  {'symbol': 'UNI-USDT',
#   'price_24h': 26.322,
#   'volume_24h': 0.0,
#   'last_trade_price': 26.626},
#  {'symbol': 'DOT-EUR',
#   'price_24h': 43.0,
#   'volume_24h': 288.01746898,
#   'last_trade_price': 42.91},
#  {'symbol': 'BCH-PAX',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 339.24},
#  {'symbol': 'DAI-USDC',
#   'price_24h': 1.0001,
#   'volume_24h': 0.0,
#   'last_trade_price': 1.0003},
#  {'symbol': 'UNI-USD',
#   'price_24h': 25.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 25.0},
#  {'symbol': 'ETH-BTC',
#   'price_24h': 0.070801,
#   'volume_24h': 2.38540545,
#   'last_trade_price': 0.071252},
#  {'symbol': 'WDGLD-BTC',
#   'price_24h': 0.002863,
#   'volume_24h': 37.73491157,
#   'last_trade_price': 0.002751},
#  {'symbol': 'USDC-EUR',
#   'price_24h': 0.8624,
#   'volume_24h': 356.9492,
#   'last_trade_price': 0.8635},
#  {'symbol': 'WBTC-USDT',
#   'price_24h': 58764.45,
#   'volume_24h': 0.0,
#   'last_trade_price': 58202.11},
#  {'symbol': 'MKR-USDC',
#   'price_24h': 2453.35,
#   'volume_24h': 0.0,
#   'last_trade_price': 2453.35},
#  {'symbol': 'LTC-USD',
#   'price_24h': 192.78,
#   'volume_24h': 267.74023665,
#   'last_trade_price': 202.09},
#  {'symbol': 'LINK-USD',
#   'price_24h': 33.607,
#   'volume_24h': 3.53183259,
#   'last_trade_price': 32.148},
#  {'symbol': 'DOGE-USDT',
#   'price_24h': 0.27874,
#   'volume_24h': 2392.6158249,
#   'last_trade_price': 0.27},
#  {'symbol': 'COMP-USD',
#   'price_24h': 371.0,
#   'volume_24h': 0.65,
#   'last_trade_price': 371.0},
#  {'symbol': 'LTC-BTC',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.005827},
#  {'symbol': 'EFI-USD',
#   'price_24h': 0.89,
#   'volume_24h': 387.5112017,
#   'last_trade_price': 0.889},
#  {'symbol': 'EOS-USDT',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.0},
#  {'symbol': 'DAI-USDT',
#   'price_24h': 1.034,
#   'volume_24h': 5.0051,
#   'last_trade_price': 1.034},
#  {'symbol': 'BTC-GBP',
#   'price_24h': 44331.29,
#   'volume_24h': 14.49825112,
#   'last_trade_price': 46597.07},
#  {'symbol': 'USDC-USD',
#   'price_24h': 1.0001,
#   'volume_24h': 116395.0987,
#   'last_trade_price': 1.002},
#  {'symbol': 'MKR-USD',
#   'price_24h': 2523.37,
#   'volume_24h': 0.00393,
#   'last_trade_price': 2523.37},
#  {'symbol': 'LTC-TRY',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.0},
#  {'symbol': 'WBTC-USD',
#   'price_24h': 58824.32,
#   'volume_24h': 0.0,
#   'last_trade_price': 58824.32},
#  {'symbol': 'UNI-USDC',
#   'price_24h': 27.0,
#   'volume_24h': 12.99047809,
#   'last_trade_price': 25.714},
#  {'symbol': 'LTC-EUR',
#   'price_24h': 170.2,
#   'volume_24h': 132.13620088,
#   'last_trade_price': 174.26},
#  {'symbol': 'WDGLD-DGLD',
#   'price_24h': 1.01,
#   'volume_24h': 0.0,
#   'last_trade_price': 1.01},
#  {'symbol': 'DOT-USD',
#   'price_24h': 50.1,
#   'volume_24h': 4280.37918912,
#   'last_trade_price': 51.73},
#  {'symbol': 'USDT-TRY',
#   'price_24h': 8.29,
#   'volume_24h': 0.0,
#   'last_trade_price': 8.29},
#  {'symbol': 'USDT-USD',
#   'price_24h': 1.0008,
#   'volume_24h': 465986.3874,
#   'last_trade_price': 1.0007},
#  {'symbol': 'COMP-USDT',
#   'price_24h': 372.48,
#   'volume_24h': 0.01801801,
#   'last_trade_price': 372.48},
#  {'symbol': 'LEND-USDT',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.4854},
#  {'symbol': 'ETH-GBP',
#   'price_24h': 3141.95,
#   'volume_24h': 71.70322855,
#   'last_trade_price': 3314.77},
#  {'symbol': 'OGN-USD',
#   'price_24h': 1.135,
#   'volume_24h': 2661.55458,
#   'last_trade_price': 1.1959},
#  {'symbol': 'AAVE-USDT',
#   'price_24h': 321.73,
#   'volume_24h': 8.33333333,
#   'last_trade_price': 321.73},
#  {'symbol': 'ETH-PAX',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 219.41},
#  {'symbol': 'USDC-USDT',
#   'price_24h': 0.9994,
#   'volume_24h': 4641.9369,
#   'last_trade_price': 0.9991},
#  {'symbol': 'BCH-USDT',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 358.46},
#  {'symbol': 'ALGO-USDT',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.3614},
#  {'symbol': 'ENJ-USD',
#   'price_24h': 2.7374,
#   'volume_24h': 157.739583,
#   'last_trade_price': 2.6976},
#  {'symbol': 'SUSHI-USDC',
#   'price_24h': 12.097,
#   'volume_24h': 0.0,
#   'last_trade_price': 12.097},
#  {'symbol': 'LTC-USDT',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 73.28},
#  {'symbol': 'DAI-GBP',
#   'price_24h': 0.7322,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.7322},
#  {'symbol': 'EFI-USDC',
#   'price_24h': 0.817,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.817},
#  {'symbol': 'BTC-EUR',
#   'price_24h': 52280.57,
#   'volume_24h': 26.06925278,
#   'last_trade_price': 54550.55},
#  {'symbol': 'USDT-EUR',
#   'price_24h': 0.8627,
#   'volume_24h': 124050.968,
#   'last_trade_price': 0.8647},
#  {'symbol': 'DGLD-USD',
#   'price_24h': 175.61,
#   'volume_24h': 62.0396768,
#   'last_trade_price': 174.73},
#  {'symbol': 'EOS-USDC',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.0},
#  {'symbol': 'YFI-USDT',
#   'price_24h': 34552.05,
#   'volume_24h': 0.09852073,
#   'last_trade_price': 34552.05},
#  {'symbol': 'SUSHI-USDT',
#   'price_24h': 12.211,
#   'volume_24h': 0.0,
#   'last_trade_price': 12.211},
#  {'symbol': 'ENJ-USDT',
#   'price_24h': 2.718,
#   'volume_24h': 10.000005,
#   'last_trade_price': 2.8},
#  {'symbol': 'COMP-USDC',
#   'price_24h': 339.89,
#   'volume_24h': 0.0,
#   'last_trade_price': 339.89},
#  {'symbol': 'LTC-PAX',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 74.03},
#  {'symbol': 'MATIC-USDC',
#   'price_24h': 1.905,
#   'volume_24h': 0.0,
#   'last_trade_price': 1.905},
#  {'symbol': 'PAX-EUR',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.9444},
#  {'symbol': 'AAVE-USD',
#   'price_24h': 321.89,
#   'volume_24h': 9.43851141,
#   'last_trade_price': 321.15},
#  {'symbol': 'DOT-GBP',
#   'price_24h': 36.8,
#   'volume_24h': 235.21982275,
#   'last_trade_price': 36.05},
#  {'symbol': 'BTC-USDT',
#   'price_24h': 60600.0,
#   'volume_24h': 5.25781548,
#   'last_trade_price': 63379.8},
#  {'symbol': 'ETH-USDT',
#   'price_24h': 4349.35,
#   'volume_24h': 49.9838888,
#   'last_trade_price': 4516.84},
#  {'symbol': 'MATIC-USD',
#   'price_24h': 1.95,
#   'volume_24h': 32.92145125,
#   'last_trade_price': 1.894},
#  {'symbol': 'SUSHI-USD',
#   'price_24h': 12.285,
#   'volume_24h': 1497.96925449,
#   'last_trade_price': 12.558},
#  {'symbol': 'DAI-USD',
#   'price_24h': 1.0008,
#   'volume_24h': 8.3335,
#   'last_trade_price': 1.0008}]

# %%
type(response)
# Out:
# list

# %%
len(response)
# Out:
# 102

# %%
df= pd.DataFrame (response)
df
# Out:
#         symbol    price_24h     volume_24h  last_trade_price
# 0      XLM-EUR      0.31513  111607.509138          0.326000
# 1     ALGO-BTC      0.00003       0.000000          0.000030
# 2     EFI-USDT      0.82500      22.616305          0.825000
# 3      XLM-BTC      0.00000       0.000000          0.000006
# 4     USDC-GBP      0.74500   13293.161600          0.751000
# ..         ...          ...            ...               ...
# 97    BTC-USDT  60600.00000       5.257815      63379.800000
# 98    ETH-USDT   4349.35000      49.983889       4516.840000
# 99   MATIC-USD      1.95000      32.921451          1.894000
# 100  SUSHI-USD     12.28500    1497.969254         12.558000
# 101    DAI-USD      1.00080       8.333500          1.000800
#
# [102 rows x 4 columns]

# %% [markdown]
# Timestamp does not work yet! in order to work to machine learning in time we need to add a column with the date

# %%
# 11-01-2011
c = 1635816455

# %%
# type(c)

# %%
# df2 = pd.to_datetime(c)
# df2

# %%
df
# Out:
#         symbol    price_24h     volume_24h  last_trade_price
# 0      XLM-EUR      0.31513  111607.509138          0.326000
# 1     ALGO-BTC      0.00003       0.000000          0.000030
# 2     EFI-USDT      0.82500      22.616305          0.825000
# 3      XLM-BTC      0.00000       0.000000          0.000006
# 4     USDC-GBP      0.74500   13293.161600          0.751000
# ..         ...          ...            ...               ...
# 97    BTC-USDT  60600.00000       5.257815      63379.800000
# 98    ETH-USDT   4349.35000      49.983889       4516.840000
# 99   MATIC-USD      1.95000      32.921451          1.894000
# 100  SUSHI-USD     12.28500    1497.969254         12.558000
# 101    DAI-USD      1.00080       8.333500          1.000800
#
# [102 rows x 4 columns]

# %%
df.rename(columns={'symbol':'symbol',
                   'price_24h':'price_24_11-01-2011',
                   'volume_24h':'volume_24h_11-01-2011',
                  'last_trade_price': 'last_trade_price_11-01-2011'},
         inplace=True, errors='raise')
df
# Out:
#         symbol  price_24_11-01-2011  volume_24h_11-01-2011  \
# 0      XLM-EUR              0.31513          111607.509138
# 1     ALGO-BTC              0.00003               0.000000
# 2     EFI-USDT              0.82500              22.616305
# 3      XLM-BTC              0.00000               0.000000
# 4     USDC-GBP              0.74500           13293.161600
# ..         ...                  ...                    ...
# 97    BTC-USDT          60600.00000               5.257815
# 98    ETH-USDT           4349.35000              49.983889
# 99   MATIC-USD              1.95000              32.921451
# 100  SUSHI-USD             12.28500            1497.969254
# 101    DAI-USD              1.00080               8.333500
#
#      last_trade_price_11-01-2011
# 0                       0.326000
# 1                       0.000030
# 2                       0.825000
# 3                       0.000006
# 4                       0.751000
# ..                           ...
# 97                  63379.800000
# 98                   4516.840000
# 99                      1.894000
# 100                    12.558000
# 101                     1.000800
#
# [102 rows x 4 columns]

# %%
# out
df.to_csv('11_01_2011.csv')

# %% [markdown]
# # BTC-USD - Each entry in bids and asks arrays is a price level, along with its price (px), quantity (qty) and number of orders (num) attributes -

# %%
# Dependencies and Setp up
import json
import requests
import pandas as pd
import numpy as np
import time

from datetime import datetime
from pprint import pprint

# %%
url_ = 'https://api.blockchain.com/v3/exchange/l2/BTC-USD'

# %%
# Json file
response = requests.get(url_).json()

# %%
response
# Out:
# {'symbol': 'BTC-USD',
#  'bids': [{'px': 63136.48, 'qty': 0.63354811, 'num': 1},
#   {'px': 63136.0, 'qty': 0.52, 'num': 1},
#   {'px': 63121.74, 'qty': 0.23757711, 'num': 1},
#   {'px': 63117.9, 'qty': 0.06, 'num': 1},
#   {'px': 63114.96, 'qty': 0.47514164, 'num': 1},
#   {'px': 63106.45, 'qty': 0.08333333, 'num': 1},
#   {'px': 63096.95, 'qty': 0.335, 'num': 1},
#   {'px': 63086.84, 'qty': 0.338, 'num': 1},
#   {'px': 63078.11, 'qty': 1.3282706, 'num': 1},
#   {'px': 63074.33, 'qty': 0.79183645, 'num': 1},
#   {'px': 63071.97, 'qty': 0.181, 'num': 1},
#   {'px': 63057.71, 'qty': 0.2, 'num': 1},
#   {'px': 63044.89, 'qty': 0.008, 'num': 1},
#   {'px': 63036.11, 'qty': 0.22047154, 'num': 1},
#   {'px': 63036.1, 'qty': 0.15841463, 'num': 1},
#   {'px': 63026.01, 'qty': 0.00071779, 'num': 1},
#   {'px': 63017.49, 'qty': 0.1, 'num': 1},
#   {'px': 63014.17, 'qty': 1.58295339, 'num': 1},
#   {'px': 63011.19, 'qty': 0.15836729, 'num': 1},
#   {'px': 62996.4, 'qty': 0.00071813, 'num': 1},
#   {'px': 62990.96, 'qty': 0.209, 'num': 1},
#   {'px': 62950.03, 'qty': 0.11666666, 'num': 1},
#   {'px': 62937.23, 'qty': 0.0005, 'num': 1},
#   {'px': 62886.89, 'qty': 0.13333333, 'num': 1},
#   {'px': 62807.51, 'qty': 0.05, 'num': 1},
#   {'px': 62135.73, 'qty': 0.00050511, 'num': 1},
#   {'px': 62000.0, 'qty': 0.1, 'num': 1},
#   {'px': 61974.85, 'qty': 0.01226424, 'num': 1},
#   {'px': 61902.0, 'qty': 0.00160564, 'num': 1},
#   {'px': 61864.84, 'qty': 0.1, 'num': 1},
#   {'px': 61500.0, 'qty': 0.035, 'num': 1},
#   {'px': 61350.0, 'qty': 0.02058837, 'num': 1},
#   {'px': 61000.0, 'qty': 0.00053987, 'num': 1},
#   {'px': 60876.0, 'qty': 0.059, 'num': 1},
#   {'px': 60775.0, 'qty': 0.05736152, 'num': 1},
#   {'px': 60700.0, 'qty': 0.247, 'num': 1},
#   {'px': 60500.0, 'qty': 0.00357289, 'num': 1},
#   {'px': 60355.73, 'qty': 0.0074079, 'num': 1},
#   {'px': 60301.01, 'qty': 0.00062143, 'num': 1},
#   {'px': 60224.58, 'qty': 0.00815462, 'num': 1},
#   {'px': 60200.0, 'qty': 0.56452651, 'num': 1},
#   {'px': 60192.0, 'qty': 0.05906089, 'num': 1},
#   {'px': 60180.02, 'qty': 0.01291803, 'num': 1},
#   {'px': 60121.0, 'qty': 0.00737, 'num': 1},
#   {'px': 60100.0, 'qty': 0.00442709, 'num': 2},
#   {'px': 60050.0, 'qty': 0.02355713, 'num': 1},
#   {'px': 60006.0, 'qty': 0.00761, 'num': 1},
#   {'px': 60000.0, 'qty': 0.7200538, 'num': 4},
#   {'px': 59950.0, 'qty': 0.0005, 'num': 1},
#   {'px': 59900.0, 'qty': 0.0668593, 'num': 1},
#   {'px': 59870.0, 'qty': 0.0005, 'num': 1},
#   {'px': 59777.0, 'qty': 0.046, 'num': 1},
#   {'px': 59750.0, 'qty': 0.0005, 'num': 1},
#   {'px': 59400.0, 'qty': 1.32233196, 'num': 1},
#   {'px': 59250.0, 'qty': 0.0089845, 'num': 1},
#   {'px': 59100.0, 'qty': 0.00107933, 'num': 1},
#   {'px': 59000.0, 'qty': 0.00071608, 'num': 1},
#   {'px': 58990.57, 'qty': 0.00063311, 'num': 1},
#   {'px': 58550.0, 'qty': 0.00053, 'num': 1},
#   {'px': 58500.0, 'qty': 0.00123391, 'num': 1},
#   {'px': 58200.0, 'qty': 0.00408246, 'num': 1},
#   {'px': 58125.0, 'qty': 0.00371889, 'num': 1},
#   {'px': 58088.0, 'qty': 0.001, 'num': 1},
#   {'px': 58000.0, 'qty': 0.11270218, 'num': 4},
#   {'px': 57898.43, 'qty': 0.19933921, 'num': 1},
#   {'px': 57600.0, 'qty': 0.0013143, 'num': 2},
#   {'px': 57584.0, 'qty': 0.0005, 'num': 1},
#   {'px': 57567.0, 'qty': 0.09, 'num': 1},
#   {'px': 57500.0, 'qty': 0.15, 'num': 1},
#   {'px': 57300.0, 'qty': 0.001, 'num': 1},
#   {'px': 57006.99, 'qty': 0.00241497, 'num': 1},
#   {'px': 57000.0, 'qty': 0.41003069, 'num': 5},
#   {'px': 56900.0, 'qty': 0.00055345, 'num': 1},
#   {'px': 56805.0, 'qty': 1.1276582, 'num': 1},
#   {'px': 56600.0, 'qty': 0.00763815, 'num': 1},
#   {'px': 56500.0, 'qty': 0.09828026, 'num': 2},
#   {'px': 56200.0, 'qty': 0.010361, 'num': 2},
#   {'px': 56121.0, 'qty': 0.00307, 'num': 1},
#   {'px': 56030.0, 'qty': 0.0015059, 'num': 1},
#   {'px': 56000.0, 'qty': 0.0147893, 'num': 4},
#   {'px': 55651.0, 'qty': 0.00694941, 'num': 1},
#   {'px': 55555.0, 'qty': 0.02, 'num': 1},
#   {'px': 55500.0, 'qty': 0.005, 'num': 1},
#   {'px': 55200.0, 'qty': 0.00091226, 'num': 1},
#   {'px': 55100.0, 'qty': 0.00100044, 'num': 1},
#   {'px': 55051.0, 'qty': 0.004, 'num': 1},
#   {'px': 55001.09, 'qty': 0.00107617, 'num': 1},
#   {'px': 55000.0, 'qty': 0.00770617, 'num': 3},
#   {'px': 54600.0, 'qty': 0.0007, 'num': 1},
#   {'px': 54545.0, 'qty': 0.01014989, 'num': 1},
#   {'px': 54222.0, 'qty': 0.01011945, 'num': 1},
#   {'px': 54200.0, 'qty': 0.0015, 'num': 1},
#   {'px': 54000.0, 'qty': 0.02509966, 'num': 5},
#   {'px': 53500.0, 'qty': 0.0012, 'num': 1},
#   {'px': 53400.0, 'qty': 0.02827895, 'num': 2},
#   {'px': 52500.0, 'qty': 0.0025, 'num': 1},
#   {'px': 52200.0, 'qty': 0.005, 'num': 1},
#   {'px': 52100.0, 'qty': 0.10338596, 'num': 2},
#   {'px': 52000.0, 'qty': 0.0408841, 'num': 2},
#   {'px': 51755.0, 'qty': 0.01240825, 'num': 1},
#   {'px': 51600.0, 'qty': 0.00051, 'num': 1},
#   {'px': 51557.6, 'qty': 0.4, 'num': 1},
#   {'px': 51500.0, 'qty': 0.001812, 'num': 2},
#   {'px': 51100.0, 'qty': 0.1, 'num': 1},
#   {'px': 50285.0, 'qty': 0.00082, 'num': 1},
#   {'px': 50200.0, 'qty': 0.00051, 'num': 1},
#   {'px': 50100.0, 'qty': 0.1, 'num': 1},
#   {'px': 50002.0, 'qty': 0.20005, 'num': 1},
#   {'px': 50000.0, 'qty': 0.4278676, 'num': 7},
#   {'px': 49952.0, 'qty': 0.000835, 'num': 1},
#   {'px': 49900.0, 'qty': 0.00054693, 'num': 1},
#   {'px': 49700.0, 'qty': 0.005, 'num': 1},
#   {'px': 49672.17, 'qty': 0.01867843, 'num': 1},
#   {'px': 49621.0, 'qty': 0.00084, 'num': 1},
#   {'px': 49293.0, 'qty': 0.00084, 'num': 1},
#   {'px': 49100.0, 'qty': 0.1, 'num': 1},
#   {'px': 49000.0, 'qty': 0.00552697, 'num': 1},
#   {'px': 48966.0, 'qty': 0.00084, 'num': 1},
#   {'px': 48889.0, 'qty': 1.47833731, 'num': 1},
#   {'px': 48642.0, 'qty': 0.00085, 'num': 1},
#   {'px': 48300.0, 'qty': 0.005, 'num': 1},
#   {'px': 48100.0, 'qty': 0.10267201, 'num': 2},
#   {'px': 48000.0, 'qty': 0.06927595, 'num': 4},
#   {'px': 47700.0, 'qty': 0.00051, 'num': 1},
#   {'px': 47500.0, 'qty': 0.001, 'num': 1},
#   {'px': 47100.0, 'qty': 0.1, 'num': 1},
#   {'px': 47000.0, 'qty': 0.044, 'num': 1},
#   {'px': 46900.0, 'qty': 0.005, 'num': 1},
#   {'px': 46700.0, 'qty': 0.01716053, 'num': 1},
#   {'px': 46511.0, 'qty': 0.004884, 'num': 1},
#   {'px': 46100.79, 'qty': 0.00051, 'num': 1},
#   {'px': 46100.0, 'qty': 0.1, 'num': 1},
#   {'px': 46000.0, 'qty': 0.0075, 'num': 2},
#   {'px': 45678.0, 'qty': 0.03036804, 'num': 1},
#   {'px': 45500.0, 'qty': 0.00551, 'num': 2},
#   {'px': 45151.0, 'qty': 0.0079, 'num': 1},
#   {'px': 45100.0, 'qty': 0.1, 'num': 1},
#   {'px': 45000.03, 'qty': 0.00114209, 'num': 1},
#   {'px': 45000.0, 'qty': 2.2943201, 'num': 4},
#   {'px': 44805.0, 'qty': 0.00848014, 'num': 1},
#   {'px': 44500.0, 'qty': 0.00267686, 'num': 1},
#   {'px': 44101.02, 'qty': 0.00110079, 'num': 1},
#   {'px': 44100.0, 'qty': 0.105, 'num': 2},
#   {'px': 44000.0, 'qty': 0.05446363, 'num': 3},
#   {'px': 43200.0, 'qty': 0.45312106, 'num': 1},
#   {'px': 43100.0, 'qty': 0.1, 'num': 1},
#   {'px': 43000.0, 'qty': 0.32717634, 'num': 1},
#   {'px': 42700.0, 'qty': 0.005, 'num': 1},
#   {'px': 42200.78, 'qty': 0.00051, 'num': 1},
#   {'px': 42100.0, 'qty': 0.11, 'num': 2},
#   {'px': 42000.0, 'qty': 0.17833691, 'num': 3},
#   {'px': 41500.0, 'qty': 0.0025, 'num': 1},
#   {'px': 41300.0, 'qty': 0.005, 'num': 1},
#   {'px': 41100.0, 'qty': 0.1, 'num': 1},
#   {'px': 40765.45, 'qty': 0.02, 'num': 1},
#   {'px': 40500.0, 'qty': 0.00535267, 'num': 1},
#   {'px': 40432.0, 'qty': 0.00119214, 'num': 1},
#   {'px': 40100.0, 'qty': 0.1, 'num': 1},
#   {'px': 40041.77, 'qty': 0.00175497, 'num': 1},
#   {'px': 40000.0, 'qty': 0.84052257, 'num': 5},
#   {'px': 39900.0, 'qty': 0.005, 'num': 1},
#   {'px': 39700.0, 'qty': 0.00051, 'num': 1},
#   {'px': 39100.0, 'qty': 0.1, 'num': 1},
#   {'px': 39000.0, 'qty': 0.00825466, 'num': 1},
#   {'px': 38594.42, 'qty': 0.00300891, 'num': 1},
#   {'px': 38100.0, 'qty': 0.1, 'num': 1},
#   {'px': 37350.0, 'qty': 0.0024759, 'num': 1},
#   {'px': 37300.0, 'qty': 0.007, 'num': 1},
#   {'px': 37100.0, 'qty': 0.07, 'num': 1},
#   {'px': 37000.0, 'qty': 0.04072623, 'num': 2},
#   {'px': 36100.0, 'qty': 0.1, 'num': 1},
#   {'px': 35500.0, 'qty': 0.00203358, 'num': 1},
#   {'px': 35300.0, 'qty': 0.00753567, 'num': 1},
#   {'px': 35100.0, 'qty': 0.1, 'num': 1},
#   {'px': 34100.0, 'qty': 0.1, 'num': 1},
#   {'px': 33100.0, 'qty': 0.1, 'num': 1},
#   {'px': 32100.0, 'qty': 0.1, 'num': 1},
#   {'px': 31100.0, 'qty': 0.1, 'num': 1},
#   {'px': 31000.0, 'qty': 0.005, 'num': 1},
#   {'px': 30331.2, 'qty': 0.00105571, 'num': 1},
#   {'px': 30100.0, 'qty': 0.1, 'num': 1},
#   {'px': 30000.0, 'qty': 0.27104804, 'num': 4},
#   {'px': 29496.66, 'qty': 0.001221, 'num': 1},
#   {'px': 25555.0, 'qty': 0.01, 'num': 1},
#   {'px': 25000.0, 'qty': 0.00859861, 'num': 1},
#   {'px': 20305.0, 'qty': 0.00097641, 'num': 1},
#   {'px': 20000.0, 'qty': 0.25270341, 'num': 1},
#   {'px': 10200.0, 'qty': 0.44682391, 'num': 1},
#   {'px': 10000.0, 'qty': 0.004523, 'num': 1},
#   {'px': 4000.0, 'qty': 2.10627988, 'num': 1},
#   {'px': 3500.0, 'qty': 0.18750142, 'num': 1},
#   {'px': 1200.0, 'qty': 0.22284197, 'num': 1},
#   {'px': 39.9, 'qty': 11.16401904, 'num': 1},
#   {'px': 4.44, 'qty': 7.52620254, 'num': 2},
#   {'px': 1.8, 'qty': 7.46458611, 'num': 1}],
#  'asks': [{'px': 63151.39, 'qty': 0.23757082, 'num': 1},
#   {'px': 63159.2, 'qty': 0.07, 'num': 1},
#   {'px': 63161.14, 'qty': 0.63330084, 'num': 1},
#   {'px': 63162.24, 'qty': 0.47512827, 'num': 1},
#   {'px': 63186.2, 'qty': 0.51, 'num': 1},
#   {'px': 63200.48, 'qty': 0.79194741, 'num': 1},
#   {'px': 63211.5, 'qty': 0.669, 'num': 1},
#   {'px': 63229.03, 'qty': 0.002, 'num': 1},
#   {'px': 63233.01, 'qty': 0.08333333, 'num': 1},
#   {'px': 63240.03, 'qty': 0.23166638, 'num': 1},
#   {'px': 63243.49, 'qty': 1.68101156, 'num': 1},
#   {'px': 63246.52, 'qty': 0.189, 'num': 1},
#   {'px': 63253.34, 'qty': 0.15832957, 'num': 1},
#   {'px': 63273.95, 'qty': 0.15837037, 'num': 1},
#   {'px': 63283.38, 'qty': 1.782, 'num': 1},
#   {'px': 63296.17, 'qty': 0.1, 'num': 1},
#   {'px': 63301.53, 'qty': 1.902, 'num': 1},
#   {'px': 63313.48, 'qty': 1.58359756, 'num': 1},
#   {'px': 63319.65, 'qty': 0.078, 'num': 1},
#   {'px': 63322.55, 'qty': 1.68101156, 'num': 1},
#   {'px': 63355.76, 'qty': 1.736, 'num': 1},
#   {'px': 63359.34, 'qty': 0.11666666, 'num': 1},
#   {'px': 63390.05, 'qty': 0.0011, 'num': 1},
#   {'px': 63401.71, 'qty': 1.68101156, 'num': 1},
#   {'px': 63422.5, 'qty': 0.13333333, 'num': 1},
#   {'px': 63480.97, 'qty': 1.68101156, 'num': 1},
#   {'px': 64003.95, 'qty': 0.0017045, 'num': 1},
#   {'px': 64700.0, 'qty': 0.003, 'num': 1},
#   {'px': 64750.0, 'qty': 0.07618593, 'num': 1},
#   {'px': 64945.9, 'qty': 0.00468, 'num': 1},
#   {'px': 64950.0, 'qty': 0.001, 'num': 1},
#   {'px': 65000.0, 'qty': 0.01944615, 'num': 5},
#   {'px': 65446.35, 'qty': 0.01519176, 'num': 2},
#   {'px': 65450.0, 'qty': 0.021, 'num': 1},
#   {'px': 65500.0, 'qty': 0.00143311, 'num': 1},
#   {'px': 66000.0, 'qty': 0.98410859, 'num': 3},
#   {'px': 66000.78, 'qty': 0.00405135, 'num': 1},
#   {'px': 66000.8, 'qty': 0.00200411, 'num': 1},
#   {'px': 66145.97, 'qty': 0.01083024, 'num': 1},
#   {'px': 66192.21, 'qty': 0.0010251, 'num': 1},
#   {'px': 66400.0, 'qty': 0.02158674, 'num': 1},
#   {'px': 66459.58, 'qty': 10.42162171, 'num': 1},
#   {'px': 66500.0, 'qty': 0.00415072, 'num': 1},
#   {'px': 66725.0, 'qty': 0.722665, 'num': 1},
#   {'px': 66882.34, 'qty': 0.278, 'num': 1},
#   {'px': 66888.0, 'qty': 0.06743896, 'num': 1},
#   {'px': 66930.0, 'qty': 0.01012088, 'num': 1},
#   {'px': 67000.0, 'qty': 9.85479879, 'num': 4},
#   {'px': 67500.0, 'qty': 0.0342448, 'num': 1},
#   {'px': 67561.76, 'qty': 0.01159111, 'num': 1},
#   {'px': 67900.0, 'qty': 0.01633337, 'num': 1},
#   {'px': 67969.7, 'qty': 0.00057171, 'num': 1},
#   {'px': 68000.0, 'qty': 2.95987827, 'num': 3},
#   {'px': 68900.0, 'qty': 0.0014, 'num': 1},
#   {'px': 68955.0, 'qty': 0.001, 'num': 1},
#   {'px': 69000.0, 'qty': 0.0015, 'num': 1},
#   {'px': 69500.0, 'qty': 0.07126617, 'num': 1},
#   {'px': 69502.29, 'qty': 0.00058698, 'num': 1},
#   {'px': 69800.0, 'qty': 0.001, 'num': 1},
#   {'px': 70000.0, 'qty': 0.09012874, 'num': 3},
#   {'px': 70450.0, 'qty': 0.02, 'num': 1},
#   {'px': 70596.34, 'qty': 0.0025761, 'num': 1},
#   {'px': 71155.0, 'qty': 0.001, 'num': 1},
#   {'px': 72000.0, 'qty': 0.00087023, 'num': 1},
#   {'px': 72090.0, 'qty': 0.21, 'num': 1},
#   {'px': 72200.0, 'qty': 0.00386628, 'num': 1},
#   {'px': 72500.0, 'qty': 0.0013, 'num': 1},
#   {'px': 73335.0, 'qty': 0.001, 'num': 1},
#   {'px': 74000.0, 'qty': 0.04919113, 'num': 1},
#   {'px': 74600.0, 'qty': 0.5, 'num': 1},
#   {'px': 75000.0, 'qty': 0.16510721, 'num': 1},
#   {'px': 75060.64, 'qty': 0.00162323, 'num': 1},
#   {'px': 75500.0, 'qty': 0.02, 'num': 1},
#   {'px': 76004.0, 'qty': 0.01976011, 'num': 1},
#   {'px': 78695.0, 'qty': 0.002, 'num': 1},
#   {'px': 79000.0, 'qty': 0.001, 'num': 1},
#   {'px': 79850.0, 'qty': 0.5, 'num': 1},
#   {'px': 80450.0, 'qty': 0.02, 'num': 1},
#   {'px': 85500.0, 'qty': 0.02, 'num': 1},
#   {'px': 89990.0, 'qty': 0.001, 'num': 1},
#   {'px': 95000.0, 'qty': 0.002, 'num': 1},
#   {'px': 98283.42, 'qty': 0.00093803, 'num': 1},
#   {'px': 100000.0, 'qty': 0.3049957, 'num': 3},
#   {'px': 103000.0, 'qty': 0.01204752, 'num': 1},
#   {'px': 159398.3, 'qty': 1.0001, 'num': 1},
#   {'px': 6000714.11, 'qty': 0.00093318, 'num': 1}]}

# %%
type(response)
# Out:
# dict

# %%
len(response)
# Out:
# 3

# %%
# Choosing what to work with
c = response['bids']
c
# Out:
# [{'px': 63136.48, 'qty': 0.63354811, 'num': 1},
#  {'px': 63136.0, 'qty': 0.52, 'num': 1},
#  {'px': 63121.74, 'qty': 0.23757711, 'num': 1},
#  {'px': 63117.9, 'qty': 0.06, 'num': 1},
#  {'px': 63114.96, 'qty': 0.47514164, 'num': 1},
#  {'px': 63106.45, 'qty': 0.08333333, 'num': 1},
#  {'px': 63096.95, 'qty': 0.335, 'num': 1},
#  {'px': 63086.84, 'qty': 0.338, 'num': 1},
#  {'px': 63078.11, 'qty': 1.3282706, 'num': 1},
#  {'px': 63074.33, 'qty': 0.79183645, 'num': 1},
#  {'px': 63071.97, 'qty': 0.181, 'num': 1},
#  {'px': 63057.71, 'qty': 0.2, 'num': 1},
#  {'px': 63044.89, 'qty': 0.008, 'num': 1},
#  {'px': 63036.11, 'qty': 0.22047154, 'num': 1},
#  {'px': 63036.1, 'qty': 0.15841463, 'num': 1},
#  {'px': 63026.01, 'qty': 0.00071779, 'num': 1},
#  {'px': 63017.49, 'qty': 0.1, 'num': 1},
#  {'px': 63014.17, 'qty': 1.58295339, 'num': 1},
#  {'px': 63011.19, 'qty': 0.15836729, 'num': 1},
#  {'px': 62996.4, 'qty': 0.00071813, 'num': 1},
#  {'px': 62990.96, 'qty': 0.209, 'num': 1},
#  {'px': 62950.03, 'qty': 0.11666666, 'num': 1},
#  {'px': 62937.23, 'qty': 0.0005, 'num': 1},
#  {'px': 62886.89, 'qty': 0.13333333, 'num': 1},
#  {'px': 62807.51, 'qty': 0.05, 'num': 1},
#  {'px': 62135.73, 'qty': 0.00050511, 'num': 1},
#  {'px': 62000.0, 'qty': 0.1, 'num': 1},
#  {'px': 61974.85, 'qty': 0.01226424, 'num': 1},
#  {'px': 61902.0, 'qty': 0.00160564, 'num': 1},
#  {'px': 61864.84, 'qty': 0.1, 'num': 1},
#  {'px': 61500.0, 'qty': 0.035, 'num': 1},
#  {'px': 61350.0, 'qty': 0.02058837, 'num': 1},
#  {'px': 61000.0, 'qty': 0.00053987, 'num': 1},
#  {'px': 60876.0, 'qty': 0.059, 'num': 1},
#  {'px': 60775.0, 'qty': 0.05736152, 'num': 1},
#  {'px': 60700.0, 'qty': 0.247, 'num': 1},
#  {'px': 60500.0, 'qty': 0.00357289, 'num': 1},
#  {'px': 60355.73, 'qty': 0.0074079, 'num': 1},
#  {'px': 60301.01, 'qty': 0.00062143, 'num': 1},
#  {'px': 60224.58, 'qty': 0.00815462, 'num': 1},
#  {'px': 60200.0, 'qty': 0.56452651, 'num': 1},
#  {'px': 60192.0, 'qty': 0.05906089, 'num': 1},
#  {'px': 60180.02, 'qty': 0.01291803, 'num': 1},
#  {'px': 60121.0, 'qty': 0.00737, 'num': 1},
#  {'px': 60100.0, 'qty': 0.00442709, 'num': 2},
#  {'px': 60050.0, 'qty': 0.02355713, 'num': 1},
#  {'px': 60006.0, 'qty': 0.00761, 'num': 1},
#  {'px': 60000.0, 'qty': 0.7200538, 'num': 4},
#  {'px': 59950.0, 'qty': 0.0005, 'num': 1},
#  {'px': 59900.0, 'qty': 0.0668593, 'num': 1},
#  {'px': 59870.0, 'qty': 0.0005, 'num': 1},
#  {'px': 59777.0, 'qty': 0.046, 'num': 1},
#  {'px': 59750.0, 'qty': 0.0005, 'num': 1},
#  {'px': 59400.0, 'qty': 1.32233196, 'num': 1},
#  {'px': 59250.0, 'qty': 0.0089845, 'num': 1},
#  {'px': 59100.0, 'qty': 0.00107933, 'num': 1},
#  {'px': 59000.0, 'qty': 0.00071608, 'num': 1},
#  {'px': 58990.57, 'qty': 0.00063311, 'num': 1},
#  {'px': 58550.0, 'qty': 0.00053, 'num': 1},
#  {'px': 58500.0, 'qty': 0.00123391, 'num': 1},
#  {'px': 58200.0, 'qty': 0.00408246, 'num': 1},
#  {'px': 58125.0, 'qty': 0.00371889, 'num': 1},
#  {'px': 58088.0, 'qty': 0.001, 'num': 1},
#  {'px': 58000.0, 'qty': 0.11270218, 'num': 4},
#  {'px': 57898.43, 'qty': 0.19933921, 'num': 1},
#  {'px': 57600.0, 'qty': 0.0013143, 'num': 2},
#  {'px': 57584.0, 'qty': 0.0005, 'num': 1},
#  {'px': 57567.0, 'qty': 0.09, 'num': 1},
#  {'px': 57500.0, 'qty': 0.15, 'num': 1},
#  {'px': 57300.0, 'qty': 0.001, 'num': 1},
#  {'px': 57006.99, 'qty': 0.00241497, 'num': 1},
#  {'px': 57000.0, 'qty': 0.41003069, 'num': 5},
#  {'px': 56900.0, 'qty': 0.00055345, 'num': 1},
#  {'px': 56805.0, 'qty': 1.1276582, 'num': 1},
#  {'px': 56600.0, 'qty': 0.00763815, 'num': 1},
#  {'px': 56500.0, 'qty': 0.09828026, 'num': 2},
#  {'px': 56200.0, 'qty': 0.010361, 'num': 2},
#  {'px': 56121.0, 'qty': 0.00307, 'num': 1},
#  {'px': 56030.0, 'qty': 0.0015059, 'num': 1},
#  {'px': 56000.0, 'qty': 0.0147893, 'num': 4},
#  {'px': 55651.0, 'qty': 0.00694941, 'num': 1},
#  {'px': 55555.0, 'qty': 0.02, 'num': 1},
#  {'px': 55500.0, 'qty': 0.005, 'num': 1},
#  {'px': 55200.0, 'qty': 0.00091226, 'num': 1},
#  {'px': 55100.0, 'qty': 0.00100044, 'num': 1},
#  {'px': 55051.0, 'qty': 0.004, 'num': 1},
#  {'px': 55001.09, 'qty': 0.00107617, 'num': 1},
#  {'px': 55000.0, 'qty': 0.00770617, 'num': 3},
#  {'px': 54600.0, 'qty': 0.0007, 'num': 1},
#  {'px': 54545.0, 'qty': 0.01014989, 'num': 1},
#  {'px': 54222.0, 'qty': 0.01011945, 'num': 1},
#  {'px': 54200.0, 'qty': 0.0015, 'num': 1},
#  {'px': 54000.0, 'qty': 0.02509966, 'num': 5},
#  {'px': 53500.0, 'qty': 0.0012, 'num': 1},
#  {'px': 53400.0, 'qty': 0.02827895, 'num': 2},
#  {'px': 52500.0, 'qty': 0.0025, 'num': 1},
#  {'px': 52200.0, 'qty': 0.005, 'num': 1},
#  {'px': 52100.0, 'qty': 0.10338596, 'num': 2},
#  {'px': 52000.0, 'qty': 0.0408841, 'num': 2},
#  {'px': 51755.0, 'qty': 0.01240825, 'num': 1},
#  {'px': 51600.0, 'qty': 0.00051, 'num': 1},
#  {'px': 51557.6, 'qty': 0.4, 'num': 1},
#  {'px': 51500.0, 'qty': 0.001812, 'num': 2},
#  {'px': 51100.0, 'qty': 0.1, 'num': 1},
#  {'px': 50285.0, 'qty': 0.00082, 'num': 1},
#  {'px': 50200.0, 'qty': 0.00051, 'num': 1},
#  {'px': 50100.0, 'qty': 0.1, 'num': 1},
#  {'px': 50002.0, 'qty': 0.20005, 'num': 1},
#  {'px': 50000.0, 'qty': 0.4278676, 'num': 7},
#  {'px': 49952.0, 'qty': 0.000835, 'num': 1},
#  {'px': 49900.0, 'qty': 0.00054693, 'num': 1},
#  {'px': 49700.0, 'qty': 0.005, 'num': 1},
#  {'px': 49672.17, 'qty': 0.01867843, 'num': 1},
#  {'px': 49621.0, 'qty': 0.00084, 'num': 1},
#  {'px': 49293.0, 'qty': 0.00084, 'num': 1},
#  {'px': 49100.0, 'qty': 0.1, 'num': 1},
#  {'px': 49000.0, 'qty': 0.00552697, 'num': 1},
#  {'px': 48966.0, 'qty': 0.00084, 'num': 1},
#  {'px': 48889.0, 'qty': 1.47833731, 'num': 1},
#  {'px': 48642.0, 'qty': 0.00085, 'num': 1},
#  {'px': 48300.0, 'qty': 0.005, 'num': 1},
#  {'px': 48100.0, 'qty': 0.10267201, 'num': 2},
#  {'px': 48000.0, 'qty': 0.06927595, 'num': 4},
#  {'px': 47700.0, 'qty': 0.00051, 'num': 1},
#  {'px': 47500.0, 'qty': 0.001, 'num': 1},
#  {'px': 47100.0, 'qty': 0.1, 'num': 1},
#  {'px': 47000.0, 'qty': 0.044, 'num': 1},
#  {'px': 46900.0, 'qty': 0.005, 'num': 1},
#  {'px': 46700.0, 'qty': 0.01716053, 'num': 1},
#  {'px': 46511.0, 'qty': 0.004884, 'num': 1},
#  {'px': 46100.79, 'qty': 0.00051, 'num': 1},
#  {'px': 46100.0, 'qty': 0.1, 'num': 1},
#  {'px': 46000.0, 'qty': 0.0075, 'num': 2},
#  {'px': 45678.0, 'qty': 0.03036804, 'num': 1},
#  {'px': 45500.0, 'qty': 0.00551, 'num': 2},
#  {'px': 45151.0, 'qty': 0.0079, 'num': 1},
#  {'px': 45100.0, 'qty': 0.1, 'num': 1},
#  {'px': 45000.03, 'qty': 0.00114209, 'num': 1},
#  {'px': 45000.0, 'qty': 2.2943201, 'num': 4},
#  {'px': 44805.0, 'qty': 0.00848014, 'num': 1},
#  {'px': 44500.0, 'qty': 0.00267686, 'num': 1},
#  {'px': 44101.02, 'qty': 0.00110079, 'num': 1},
#  {'px': 44100.0, 'qty': 0.105, 'num': 2},
#  {'px': 44000.0, 'qty': 0.05446363, 'num': 3},
#  {'px': 43200.0, 'qty': 0.45312106, 'num': 1},
#  {'px': 43100.0, 'qty': 0.1, 'num': 1},
#  {'px': 43000.0, 'qty': 0.32717634, 'num': 1},
#  {'px': 42700.0, 'qty': 0.005, 'num': 1},
#  {'px': 42200.78, 'qty': 0.00051, 'num': 1},
#  {'px': 42100.0, 'qty': 0.11, 'num': 2},
#  {'px': 42000.0, 'qty': 0.17833691, 'num': 3},
#  {'px': 41500.0, 'qty': 0.0025, 'num': 1},
#  {'px': 41300.0, 'qty': 0.005, 'num': 1},
#  {'px': 41100.0, 'qty': 0.1, 'num': 1},
#  {'px': 40765.45, 'qty': 0.02, 'num': 1},
#  {'px': 40500.0, 'qty': 0.00535267, 'num': 1},
#  {'px': 40432.0, 'qty': 0.00119214, 'num': 1},
#  {'px': 40100.0, 'qty': 0.1, 'num': 1},
#  {'px': 40041.77, 'qty': 0.00175497, 'num': 1},
#  {'px': 40000.0, 'qty': 0.84052257, 'num': 5},
#  {'px': 39900.0, 'qty': 0.005, 'num': 1},
#  {'px': 39700.0, 'qty': 0.00051, 'num': 1},
#  {'px': 39100.0, 'qty': 0.1, 'num': 1},
#  {'px': 39000.0, 'qty': 0.00825466, 'num': 1},
#  {'px': 38594.42, 'qty': 0.00300891, 'num': 1},
#  {'px': 38100.0, 'qty': 0.1, 'num': 1},
#  {'px': 37350.0, 'qty': 0.0024759, 'num': 1},
#  {'px': 37300.0, 'qty': 0.007, 'num': 1},
#  {'px': 37100.0, 'qty': 0.07, 'num': 1},
#  {'px': 37000.0, 'qty': 0.04072623, 'num': 2},
#  {'px': 36100.0, 'qty': 0.1, 'num': 1},
#  {'px': 35500.0, 'qty': 0.00203358, 'num': 1},
#  {'px': 35300.0, 'qty': 0.00753567, 'num': 1},
#  {'px': 35100.0, 'qty': 0.1, 'num': 1},
#  {'px': 34100.0, 'qty': 0.1, 'num': 1},
#  {'px': 33100.0, 'qty': 0.1, 'num': 1},
#  {'px': 32100.0, 'qty': 0.1, 'num': 1},
#  {'px': 31100.0, 'qty': 0.1, 'num': 1},
#  {'px': 31000.0, 'qty': 0.005, 'num': 1},
#  {'px': 30331.2, 'qty': 0.00105571, 'num': 1},
#  {'px': 30100.0, 'qty': 0.1, 'num': 1},
#  {'px': 30000.0, 'qty': 0.27104804, 'num': 4},
#  {'px': 29496.66, 'qty': 0.001221, 'num': 1},
#  {'px': 25555.0, 'qty': 0.01, 'num': 1},
#  {'px': 25000.0, 'qty': 0.00859861, 'num': 1},
#  {'px': 20305.0, 'qty': 0.00097641, 'num': 1},
#  {'px': 20000.0, 'qty': 0.25270341, 'num': 1},
#  {'px': 10200.0, 'qty': 0.44682391, 'num': 1},
#  {'px': 10000.0, 'qty': 0.004523, 'num': 1},
#  {'px': 4000.0, 'qty': 2.10627988, 'num': 1},
#  {'px': 3500.0, 'qty': 0.18750142, 'num': 1},
#  {'px': 1200.0, 'qty': 0.22284197, 'num': 1},
#  {'px': 39.9, 'qty': 11.16401904, 'num': 1},
#  {'px': 4.44, 'qty': 7.52620254, 'num': 2},
#  {'px': 1.8, 'qty': 7.46458611, 'num': 1}]

# %%
d = response['asks']
d
# Out:
# [{'px': 63151.39, 'qty': 0.23757082, 'num': 1},
#  {'px': 63159.2, 'qty': 0.07, 'num': 1},
#  {'px': 63161.14, 'qty': 0.63330084, 'num': 1},
#  {'px': 63162.24, 'qty': 0.47512827, 'num': 1},
#  {'px': 63186.2, 'qty': 0.51, 'num': 1},
#  {'px': 63200.48, 'qty': 0.79194741, 'num': 1},
#  {'px': 63211.5, 'qty': 0.669, 'num': 1},
#  {'px': 63229.03, 'qty': 0.002, 'num': 1},
#  {'px': 63233.01, 'qty': 0.08333333, 'num': 1},
#  {'px': 63240.03, 'qty': 0.23166638, 'num': 1},
#  {'px': 63243.49, 'qty': 1.68101156, 'num': 1},
#  {'px': 63246.52, 'qty': 0.189, 'num': 1},
#  {'px': 63253.34, 'qty': 0.15832957, 'num': 1},
#  {'px': 63273.95, 'qty': 0.15837037, 'num': 1},
#  {'px': 63283.38, 'qty': 1.782, 'num': 1},
#  {'px': 63296.17, 'qty': 0.1, 'num': 1},
#  {'px': 63301.53, 'qty': 1.902, 'num': 1},
#  {'px': 63313.48, 'qty': 1.58359756, 'num': 1},
#  {'px': 63319.65, 'qty': 0.078, 'num': 1},
#  {'px': 63322.55, 'qty': 1.68101156, 'num': 1},
#  {'px': 63355.76, 'qty': 1.736, 'num': 1},
#  {'px': 63359.34, 'qty': 0.11666666, 'num': 1},
#  {'px': 63390.05, 'qty': 0.0011, 'num': 1},
#  {'px': 63401.71, 'qty': 1.68101156, 'num': 1},
#  {'px': 63422.5, 'qty': 0.13333333, 'num': 1},
#  {'px': 63480.97, 'qty': 1.68101156, 'num': 1},
#  {'px': 64003.95, 'qty': 0.0017045, 'num': 1},
#  {'px': 64700.0, 'qty': 0.003, 'num': 1},
#  {'px': 64750.0, 'qty': 0.07618593, 'num': 1},
#  {'px': 64945.9, 'qty': 0.00468, 'num': 1},
#  {'px': 64950.0, 'qty': 0.001, 'num': 1},
#  {'px': 65000.0, 'qty': 0.01944615, 'num': 5},
#  {'px': 65446.35, 'qty': 0.01519176, 'num': 2},
#  {'px': 65450.0, 'qty': 0.021, 'num': 1},
#  {'px': 65500.0, 'qty': 0.00143311, 'num': 1},
#  {'px': 66000.0, 'qty': 0.98410859, 'num': 3},
#  {'px': 66000.78, 'qty': 0.00405135, 'num': 1},
#  {'px': 66000.8, 'qty': 0.00200411, 'num': 1},
#  {'px': 66145.97, 'qty': 0.01083024, 'num': 1},
#  {'px': 66192.21, 'qty': 0.0010251, 'num': 1},
#  {'px': 66400.0, 'qty': 0.02158674, 'num': 1},
#  {'px': 66459.58, 'qty': 10.42162171, 'num': 1},
#  {'px': 66500.0, 'qty': 0.00415072, 'num': 1},
#  {'px': 66725.0, 'qty': 0.722665, 'num': 1},
#  {'px': 66882.34, 'qty': 0.278, 'num': 1},
#  {'px': 66888.0, 'qty': 0.06743896, 'num': 1},
#  {'px': 66930.0, 'qty': 0.01012088, 'num': 1},
#  {'px': 67000.0, 'qty': 9.85479879, 'num': 4},
#  {'px': 67500.0, 'qty': 0.0342448, 'num': 1},
#  {'px': 67561.76, 'qty': 0.01159111, 'num': 1},
#  {'px': 67900.0, 'qty': 0.01633337, 'num': 1},
#  {'px': 67969.7, 'qty': 0.00057171, 'num': 1},
#  {'px': 68000.0, 'qty': 2.95987827, 'num': 3},
#  {'px': 68900.0, 'qty': 0.0014, 'num': 1},
#  {'px': 68955.0, 'qty': 0.001, 'num': 1},
#  {'px': 69000.0, 'qty': 0.0015, 'num': 1},
#  {'px': 69500.0, 'qty': 0.07126617, 'num': 1},
#  {'px': 69502.29, 'qty': 0.00058698, 'num': 1},
#  {'px': 69800.0, 'qty': 0.001, 'num': 1},
#  {'px': 70000.0, 'qty': 0.09012874, 'num': 3},
#  {'px': 70450.0, 'qty': 0.02, 'num': 1},
#  {'px': 70596.34, 'qty': 0.0025761, 'num': 1},
#  {'px': 71155.0, 'qty': 0.001, 'num': 1},
#  {'px': 72000.0, 'qty': 0.00087023, 'num': 1},
#  {'px': 72090.0, 'qty': 0.21, 'num': 1},
#  {'px': 72200.0, 'qty': 0.00386628, 'num': 1},
#  {'px': 72500.0, 'qty': 0.0013, 'num': 1},
#  {'px': 73335.0, 'qty': 0.001, 'num': 1},
#  {'px': 74000.0, 'qty': 0.04919113, 'num': 1},
#  {'px': 74600.0, 'qty': 0.5, 'num': 1},
#  {'px': 75000.0, 'qty': 0.16510721, 'num': 1},
#  {'px': 75060.64, 'qty': 0.00162323, 'num': 1},
#  {'px': 75500.0, 'qty': 0.02, 'num': 1},
#  {'px': 76004.0, 'qty': 0.01976011, 'num': 1},
#  {'px': 78695.0, 'qty': 0.002, 'num': 1},
#  {'px': 79000.0, 'qty': 0.001, 'num': 1},
#  {'px': 79850.0, 'qty': 0.5, 'num': 1},
#  {'px': 80450.0, 'qty': 0.02, 'num': 1},
#  {'px': 85500.0, 'qty': 0.02, 'num': 1},
#  {'px': 89990.0, 'qty': 0.001, 'num': 1},
#  {'px': 95000.0, 'qty': 0.002, 'num': 1},
#  {'px': 98283.42, 'qty': 0.00093803, 'num': 1},
#  {'px': 100000.0, 'qty': 0.3049957, 'num': 3},
#  {'px': 103000.0, 'qty': 0.01204752, 'num': 1},
#  {'px': 159398.3, 'qty': 1.0001, 'num': 1},
#  {'px': 6000714.11, 'qty': 0.00093318, 'num': 1}]

# %%
df_= pd.DataFrame (c)
df = pd.DataFrame (d)

# %%
df
# Out:
#             px       qty  num
# 0     63151.39  0.237571    1
# 1     63159.20  0.070000    1
# 2     63161.14  0.633301    1
# 3     63162.24  0.475128    1
# 4     63186.20  0.510000    1
# ..         ...       ...  ...
# 81    98283.42  0.000938    1
# 82   100000.00  0.304996    3
# 83   103000.00  0.012048    1
# 84   159398.30  1.000100    1
# 85  6000714.11  0.000933    1
#
# [86 rows x 3 columns]

# %%
df_
# Out:
#            px        qty  num
# 0    63136.48   0.633548    1
# 1    63136.00   0.520000    1
# 2    63121.74   0.237577    1
# 3    63117.90   0.060000    1
# 4    63114.96   0.475142    1
# ..        ...        ...  ...
# 190   3500.00   0.187501    1
# 191   1200.00   0.222842    1
# 192     39.90  11.164019    1
# 193      4.44   7.526203    2
# 194      1.80   7.464586    1
#
# [195 rows x 3 columns]

# %%
url_3='https://api.blockchain.com/v3/exchange/symbols'

# %%
# Json file
response = requests.get(url_3).json()

# %%
response
# Out:
# {'XLM-EUR': {'base_currency': 'XLM',
#   'base_currency_scale': 7,
#   'counter_currency': 'EUR',
#   'counter_currency_scale': 2,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 5,
#   'min_order_size': 700000000,
#   'min_order_size_scale': 7,
#   'max_order_size': 0,
#   'max_order_size_scale': 7,
#   'lot_size': 1,
#   'lot_size_scale': 7,
#   'status': 'open',
#   'id': 11,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'ALGO-BTC': {'base_currency': 'ALGO',
#   'base_currency_scale': 6,
#   'counter_currency': 'BTC',
#   'counter_currency_scale': 8,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 8,
#   'min_order_size': 20000000,
#   'min_order_size_scale': 6,
#   'max_order_size': 0,
#   'max_order_size_scale': 6,
#   'lot_size': 1,
#   'lot_size_scale': 6,
#   'status': 'open',
#   'id': 30,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'EFI-USDT': {'base_currency': 'EFI',
#   'base_currency_scale': 8,
#   'counter_currency': 'USDT',
#   'counter_currency_scale': 6,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 3,
#   'min_order_size': 1000000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 9,
#   'lot_size': 1,
#   'lot_size_scale': 8,
#   'status': 'open',
#   'id': 90,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'XLM-BTC': {'base_currency': 'XLM',
#   'base_currency_scale': 7,
#   'counter_currency': 'BTC',
#   'counter_currency_scale': 8,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 8,
#   'min_order_size': 720000000,
#   'min_order_size_scale': 7,
#   'max_order_size': 0,
#   'max_order_size_scale': 7,
#   'lot_size': 1,
#   'lot_size_scale': 7,
#   'status': 'close',
#   'id': 12,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'USDC-GBP': {'base_currency': 'USDC',
#   'base_currency_scale': 6,
#   'counter_currency': 'GBP',
#   'counter_currency_scale': 2,
#   'min_price_increment': 10000,
#   'min_price_increment_scale': 8,
#   'min_order_size': 500000000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 10000,
#   'lot_size_scale': 8,
#   'status': 'open',
#   'id': 68,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'CLOUT-USD': {'base_currency': 'CLOUT',
#   'base_currency_scale': 9,
#   'counter_currency': 'USD',
#   'counter_currency_scale': 2,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 2,
#   'min_order_size': 1800000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 1,
#   'lot_size_scale': 8,
#   'status': 'open',
#   'id': 64,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'OGN-USDT': {'base_currency': 'OGN',
#   'base_currency_scale': 8,
#   'counter_currency': 'USDT',
#   'counter_currency_scale': 6,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 4,
#   'min_order_size': 20000000,
#   'min_order_size_scale': 7,
#   'max_order_size': 0,
#   'max_order_size_scale': 7,
#   'lot_size': 1,
#   'lot_size_scale': 6,
#   'status': 'open',
#   'id': 54,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'STX-USDC': {'base_currency': 'STX',
#   'base_currency_scale': 6,
#   'counter_currency': 'USDC',
#   'counter_currency_scale': 6,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 3,
#   'min_order_size': 100000,
#   'min_order_size_scale': 6,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 1,
#   'lot_size_scale': 8,
#   'status': 'open',
#   'id': 89,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'EOS-USD': {'base_currency': 'EOS',
#   'base_currency_scale': 4,
#   'counter_currency': 'USD',
#   'counter_currency_scale': 2,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 2,
#   'min_order_size': 8800000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 1,
#   'lot_size_scale': 8,
#   'status': 'close',
#   'id': 96,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'PAX-USD': {'base_currency': 'PAX',
#   'base_currency_scale': 8,
#   'counter_currency': 'USD',
#   'counter_currency_scale': 2,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 4,
#   'min_order_size': 500000000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 10000,
#   'lot_size_scale': 8,
#   'status': 'open',
#   'id': 14,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'BCH-USD': {'base_currency': 'BCH',
#   'base_currency_scale': 8,
#   'counter_currency': 'USD',
#   'counter_currency_scale': 2,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 2,
#   'min_order_size': 1800000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 1,
#   'lot_size_scale': 8,
#   'status': 'open',
#   'id': 6,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'DAI-EUR': {'base_currency': 'DAI',
#   'base_currency_scale': 8,
#   'counter_currency': 'EUR',
#   'counter_currency_scale': 2,
#   'min_price_increment': 10000,
#   'min_price_increment_scale': 8,
#   'min_order_size': 500000000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 10000,
#   'lot_size_scale': 8,
#   'status': 'open',
#   'id': 77,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'USDT-GBP': {'base_currency': 'USDT',
#   'base_currency_scale': 6,
#   'counter_currency': 'GBP',
#   'counter_currency_scale': 2,
#   'min_price_increment': 10000,
#   'min_price_increment_scale': 8,
#   'min_order_size': 500000000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 10000,
#   'lot_size_scale': 8,
#   'status': 'open',
#   'id': 48,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'LINK-USDT': {'base_currency': 'LINK',
#   'base_currency_scale': 8,
#   'counter_currency': 'USDT',
#   'counter_currency_scale': 6,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 3,
#   'min_order_size': 1000000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 1,
#   'lot_size_scale': 8,
#   'status': 'open',
#   'id': 84,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'STX-USD': {'base_currency': 'STX',
#   'base_currency_scale': 6,
#   'counter_currency': 'USD',
#   'counter_currency_scale': 2,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 3,
#   'min_order_size': 100000,
#   'min_order_size_scale': 6,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 1,
#   'lot_size_scale': 8,
#   'status': 'open',
#   'id': 86,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'MATIC-USDT': {'base_currency': 'MATIC',
#   'base_currency_scale': 8,
#   'counter_currency': 'USDT',
#   'counter_currency_scale': 6,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 3,
#   'min_order_size': 100000000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 1,
#   'lot_size_scale': 8,
#   'status': 'open',
#   'id': 103,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'WDGLD-USD': {'base_currency': 'WDGLD',
#   'base_currency_scale': 8,
#   'counter_currency': 'USD',
#   'counter_currency_scale': 2,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 2,
#   'min_order_size': 2500000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 1,
#   'lot_size_scale': 8,
#   'status': 'open',
#   'id': 55,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'ETH-USD': {'base_currency': 'ETH',
#   'base_currency_scale': 8,
#   'counter_currency': 'USD',
#   'counter_currency_scale': 2,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 2,
#   'min_order_size': 220000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 1,
#   'lot_size_scale': 8,
#   'status': 'open',
#   'id': 2,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'LEND-USD': {'base_currency': 'LEND',
#   'base_currency_scale': 8,
#   'counter_currency': 'USD',
#   'counter_currency_scale': 2,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 4,
#   'min_order_size': 20000000,
#   'min_order_size_scale': 7,
#   'max_order_size': 0,
#   'max_order_size_scale': 7,
#   'lot_size': 1,
#   'lot_size_scale': 6,
#   'status': 'close',
#   'id': 43,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'XLM-PAX': {'base_currency': 'XLM',
#   'base_currency_scale': 7,
#   'counter_currency': 'PAX',
#   'counter_currency_scale': 8,
#   'min_price_increment': 1000,
#   'min_price_increment_scale': 8,
#   'min_order_size': 720000000,
#   'min_order_size_scale': 7,
#   'max_order_size': 0,
#   'max_order_size_scale': 7,
#   'lot_size': 1,
#   'lot_size_scale': 7,
#   'status': 'close',
#   'id': 19,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'XRP-EUR': {'base_currency': 'XRP',
#   'base_currency_scale': 6,
#   'counter_currency': 'EUR',
#   'counter_currency_scale': 2,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 4,
#   'min_order_size': 25000000,
#   'min_order_size_scale': 6,
#   'max_order_size': 0,
#   'max_order_size_scale': 6,
#   'lot_size': 1,
#   'lot_size_scale': 6,
#   'status': 'close',
#   'id': 42,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'XLM-USD': {'base_currency': 'XLM',
#   'base_currency_scale': 7,
#   'counter_currency': 'USD',
#   'counter_currency_scale': 2,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 5,
#   'min_order_size': 180000000,
#   'min_order_size_scale': 7,
#   'max_order_size': 0,
#   'max_order_size_scale': 7,
#   'lot_size': 1,
#   'lot_size_scale': 7,
#   'status': 'open',
#   'id': 10,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'LINK-USDC': {'base_currency': 'LINK',
#   'base_currency_scale': 8,
#   'counter_currency': 'USDC',
#   'counter_currency_scale': 6,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 3,
#   'min_order_size': 1000000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 1,
#   'lot_size_scale': 8,
#   'status': 'open',
#   'id': 85,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'DGLD-BTC': {'base_currency': 'DGLD',
#   'base_currency_scale': 8,
#   'counter_currency': 'BTC',
#   'counter_currency_scale': 8,
#   'min_price_increment': 100,
#   'min_price_increment_scale': 8,
#   'min_order_size': 3500000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 1,
#   'lot_size_scale': 8,
#   'status': 'open',
#   'id': 34,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'BCH-EUR': {'base_currency': 'BCH',
#   'base_currency_scale': 8,
#   'counter_currency': 'EUR',
#   'counter_currency_scale': 2,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 2,
#   'min_order_size': 1800000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 1,
#   'lot_size_scale': 8,
#   'status': 'open',
#   'id': 7,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'BCH-BTC': {'base_currency': 'BCH',
#   'base_currency_scale': 8,
#   'counter_currency': 'BTC',
#   'counter_currency_scale': 8,
#   'min_price_increment': 100,
#   'min_price_increment_scale': 8,
#   'min_order_size': 2200000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 1,
#   'lot_size_scale': 8,
#   'status': 'open',
#   'id': 8,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'CLOUT-BTC': {'base_currency': 'CLOUT',
#   'base_currency_scale': 9,
#   'counter_currency': 'BTC',
#   'counter_currency_scale': 8,
#   'min_price_increment': 100,
#   'min_price_increment_scale': 8,
#   'min_order_size': 2200000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 1,
#   'lot_size_scale': 8,
#   'status': 'open',
#   'id': 65,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'BTC-USD': {'base_currency': 'BTC',
#   'base_currency_scale': 8,
#   'counter_currency': 'USD',
#   'counter_currency_scale': 2,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 2,
#   'min_order_size': 50000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 1,
#   'lot_size_scale': 8,
#   'status': 'open',
#   'id': 1,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'BCH-ETH': {'base_currency': 'BCH',
#   'base_currency_scale': 8,
#   'counter_currency': 'ETH',
#   'counter_currency_scale': 8,
#   'min_price_increment': 100,
#   'min_price_increment_scale': 8,
#   'min_order_size': 2200000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 1,
#   'lot_size_scale': 8,
#   'status': 'close',
#   'id': 9,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'ETH-TRY': {'base_currency': 'ETH',
#   'base_currency_scale': 8,
#   'counter_currency': 'TRY',
#   'counter_currency_scale': 2,
#   'min_price_increment': 10,
#   'min_price_increment_scale': 2,
#   'min_order_size': 2200000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 1,
#   'lot_size_scale': 8,
#   'status': 'close',
#   'id': 38,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'BTC-TRY': {'base_currency': 'BTC',
#   'base_currency_scale': 8,
#   'counter_currency': 'TRY',
#   'counter_currency_scale': 2,
#   'min_price_increment': 10,
#   'min_price_increment_scale': 2,
#   'min_order_size': 50000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 1,
#   'lot_size_scale': 8,
#   'status': 'close',
#   'id': 37,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'ALGO-USD': {'base_currency': 'ALGO',
#   'base_currency_scale': 6,
#   'counter_currency': 'USD',
#   'counter_currency_scale': 2,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 4,
#   'min_order_size': 20000000,
#   'min_order_size_scale': 7,
#   'max_order_size': 0,
#   'max_order_size_scale': 7,
#   'lot_size': 1,
#   'lot_size_scale': 6,
#   'status': 'open',
#   'id': 31,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'ETH-EUR': {'base_currency': 'ETH',
#   'base_currency_scale': 8,
#   'counter_currency': 'EUR',
#   'counter_currency_scale': 2,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 2,
#   'min_order_size': 220000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 1,
#   'lot_size_scale': 8,
#   'status': 'open',
#   'id': 5,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'DOGE-USD': {'base_currency': 'DOGE',
#   'base_currency_scale': 8,
#   'counter_currency': 'USD',
#   'counter_currency_scale': 2,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 5,
#   'min_order_size': 180000000,
#   'min_order_size_scale': 7,
#   'max_order_size': 0,
#   'max_order_size_scale': 7,
#   'lot_size': 1,
#   'lot_size_scale': 7,
#   'status': 'open',
#   'id': 61,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'STX-USDT': {'base_currency': 'STX',
#   'base_currency_scale': 6,
#   'counter_currency': 'USDT',
#   'counter_currency_scale': 6,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 3,
#   'min_order_size': 100000,
#   'min_order_size_scale': 6,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 1,
#   'lot_size_scale': 8,
#   'status': 'open',
#   'id': 87,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'XRP-USD': {'base_currency': 'XRP',
#   'base_currency_scale': 6,
#   'counter_currency': 'USD',
#   'counter_currency_scale': 2,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 4,
#   'min_order_size': 25000000,
#   'min_order_size_scale': 6,
#   'max_order_size': 0,
#   'max_order_size_scale': 6,
#   'lot_size': 1,
#   'lot_size_scale': 6,
#   'status': 'close',
#   'id': 41,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'XLM-ETH': {'base_currency': 'XLM',
#   'base_currency_scale': 7,
#   'counter_currency': 'ETH',
#   'counter_currency_scale': 8,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 8,
#   'min_order_size': 720000000,
#   'min_order_size_scale': 7,
#   'max_order_size': 0,
#   'max_order_size_scale': 7,
#   'lot_size': 1,
#   'lot_size_scale': 7,
#   'status': 'close',
#   'id': 13,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'YFI-USD': {'base_currency': 'YFI',
#   'base_currency_scale': 8,
#   'counter_currency': 'USD',
#   'counter_currency_scale': 2,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 2,
#   'min_order_size': 100000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 1,
#   'lot_size_scale': 8,
#   'status': 'open',
#   'id': 45,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'BTC-PAX': {'base_currency': 'BTC',
#   'base_currency_scale': 8,
#   'counter_currency': 'PAX',
#   'counter_currency_scale': 8,
#   'min_price_increment': 10000000,
#   'min_price_increment_scale': 8,
#   'min_order_size': 50000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 1,
#   'lot_size_scale': 8,
#   'status': 'close',
#   'id': 16,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'WBTC-USDC': {'base_currency': 'WBTC',
#   'base_currency_scale': 8,
#   'counter_currency': 'USDC',
#   'counter_currency_scale': 6,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 2,
#   'min_order_size': 2000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 1,
#   'lot_size_scale': 8,
#   'status': 'open',
#   'id': 100,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'MKR-USDT': {'base_currency': 'MKR',
#   'base_currency_scale': 8,
#   'counter_currency': 'USDT',
#   'counter_currency_scale': 6,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 2,
#   'min_order_size': 28240,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 1,
#   'lot_size_scale': 8,
#   'status': 'open',
#   'id': 105,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'UNI-USDT': {'base_currency': 'UNI',
#   'base_currency_scale': 8,
#   'counter_currency': 'USDT',
#   'counter_currency_scale': 6,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 3,
#   'min_order_size': 8800000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 1,
#   'lot_size_scale': 8,
#   'status': 'open',
#   'id': 71,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'DOT-EUR': {'base_currency': 'DOT',
#   'base_currency_scale': 9,
#   'counter_currency': 'EUR',
#   'counter_currency_scale': 2,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 2,
#   'min_order_size': 8800000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 1,
#   'lot_size_scale': 8,
#   'status': 'open',
#   'id': 59,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'BCH-PAX': {'base_currency': 'BCH',
#   'base_currency_scale': 8,
#   'counter_currency': 'PAX',
#   'counter_currency_scale': 8,
#   'min_price_increment': 1000000,
#   'min_price_increment_scale': 8,
#   'min_order_size': 1800000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 1,
#   'lot_size_scale': 8,
#   'status': 'close',
#   'id': 18,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'DAI-USDC': {'base_currency': 'DAI',
#   'base_currency_scale': 8,
#   'counter_currency': 'USDC',
#   'counter_currency_scale': 6,
#   'min_price_increment': 10000,
#   'min_price_increment_scale': 8,
#   'min_order_size': 500000000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 10000,
#   'lot_size_scale': 8,
#   'status': 'open',
#   'id': 76,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'UNI-USD': {'base_currency': 'UNI',
#   'base_currency_scale': 8,
#   'counter_currency': 'USD',
#   'counter_currency_scale': 2,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 3,
#   'min_order_size': 8800000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 1,
#   'lot_size_scale': 8,
#   'status': 'open',
#   'id': 69,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'ETH-BTC': {'base_currency': 'ETH',
#   'base_currency_scale': 8,
#   'counter_currency': 'BTC',
#   'counter_currency_scale': 8,
#   'min_price_increment': 100,
#   'min_price_increment_scale': 8,
#   'min_order_size': 220000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 1,
#   'lot_size_scale': 8,
#   'status': 'open',
#   'id': 3,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'WDGLD-BTC': {'base_currency': 'WDGLD',
#   'base_currency_scale': 8,
#   'counter_currency': 'BTC',
#   'counter_currency_scale': 8,
#   'min_price_increment': 100,
#   'min_price_increment_scale': 8,
#   'min_order_size': 2500000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 1,
#   'lot_size_scale': 8,
#   'status': 'open',
#   'id': 56,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'USDC-EUR': {'base_currency': 'USDC',
#   'base_currency_scale': 6,
#   'counter_currency': 'EUR',
#   'counter_currency_scale': 2,
#   'min_price_increment': 10000,
#   'min_price_increment_scale': 8,
#   'min_order_size': 500000000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 10000,
#   'lot_size_scale': 8,
#   'status': 'open',
#   'id': 67,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'WBTC-USDT': {'base_currency': 'WBTC',
#   'base_currency_scale': 8,
#   'counter_currency': 'USDT',
#   'counter_currency_scale': 6,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 2,
#   'min_order_size': 2000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 1,
#   'lot_size_scale': 8,
#   'status': 'open',
#   'id': 101,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'MKR-USDC': {'base_currency': 'MKR',
#   'base_currency_scale': 8,
#   'counter_currency': 'USDC',
#   'counter_currency_scale': 6,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 2,
#   'min_order_size': 28240,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 1,
#   'lot_size_scale': 8,
#   'status': 'open',
#   'id': 106,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'LTC-USD': {'base_currency': 'LTC',
#   'base_currency_scale': 8,
#   'counter_currency': 'USD',
#   'counter_currency_scale': 2,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 2,
#   'min_order_size': 8800000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 1,
#   'lot_size_scale': 8,
#   'status': 'open',
#   'id': 20,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'LINK-USD': {'base_currency': 'LINK',
#   'base_currency_scale': 8,
#   'counter_currency': 'USD',
#   'counter_currency_scale': 2,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 3,
#   'min_order_size': 1000000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 1,
#   'lot_size_scale': 8,
#   'status': 'open',
#   'id': 83,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'DOGE-USDT': {'base_currency': 'DOGE',
#   'base_currency_scale': 8,
#   'counter_currency': 'USDT',
#   'counter_currency_scale': 6,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 5,
#   'min_order_size': 180000000,
#   'min_order_size_scale': 7,
#   'max_order_size': 0,
#   'max_order_size_scale': 7,
#   'lot_size': 1,
#   'lot_size_scale': 7,
#   'status': 'open',
#   'id': 62,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'COMP-USD': {'base_currency': 'COMP',
#   'base_currency_scale': 8,
#   'counter_currency': 'USD',
#   'counter_currency_scale': 2,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 2,
#   'min_order_size': 1800000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 1,
#   'lot_size_scale': 8,
#   'status': 'open',
#   'id': 80,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'LTC-BTC': {'base_currency': 'LTC',
#   'base_currency_scale': 8,
#   'counter_currency': 'BTC',
#   'counter_currency_scale': 8,
#   'min_price_increment': 100,
#   'min_price_increment_scale': 8,
#   'min_order_size': 8800000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 1,
#   'lot_size_scale': 8,
#   'status': 'close',
#   'id': 23,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'EFI-USD': {'base_currency': 'EFI',
#   'base_currency_scale': 8,
#   'counter_currency': 'USD',
#   'counter_currency_scale': 2,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 3,
#   'min_order_size': 1000000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 1,
#   'lot_size_scale': 8,
#   'status': 'open',
#   'id': 91,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'EOS-USDT': {'base_currency': 'EOS',
#   'base_currency_scale': 4,
#   'counter_currency': 'USDT',
#   'counter_currency_scale': 6,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 2,
#   'min_order_size': 8800000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 1,
#   'lot_size_scale': 8,
#   'status': 'close',
#   'id': 97,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'DAI-USDT': {'base_currency': 'DAI',
#   'base_currency_scale': 8,
#   'counter_currency': 'USDT',
#   'counter_currency_scale': 6,
#   'min_price_increment': 10000,
#   'min_price_increment_scale': 8,
#   'min_order_size': 500000000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 10000,
#   'lot_size_scale': 8,
#   'status': 'open',
#   'id': 75,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'BTC-GBP': {'base_currency': 'BTC',
#   'base_currency_scale': 8,
#   'counter_currency': 'GBP',
#   'counter_currency_scale': 2,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 2,
#   'min_order_size': 70000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 1,
#   'lot_size_scale': 8,
#   'status': 'open',
#   'id': 35,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'USDC-USD': {'base_currency': 'USDC',
#   'base_currency_scale': 6,
#   'counter_currency': 'USD',
#   'counter_currency_scale': 2,
#   'min_price_increment': 10000,
#   'min_price_increment_scale': 8,
#   'min_order_size': 500000000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 10000,
#   'lot_size_scale': 8,
#   'status': 'open',
#   'id': 66,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'MKR-USD': {'base_currency': 'MKR',
#   'base_currency_scale': 8,
#   'counter_currency': 'USD',
#   'counter_currency_scale': 2,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 2,
#   'min_order_size': 28240,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 1,
#   'lot_size_scale': 8,
#   'status': 'open',
#   'id': 107,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'LTC-TRY': {'base_currency': 'LTC',
#   'base_currency_scale': 8,
#   'counter_currency': 'TRY',
#   'counter_currency_scale': 2,
#   'min_price_increment': 10,
#   'min_price_increment_scale': 2,
#   'min_order_size': 8800000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 1,
#   'lot_size_scale': 8,
#   'status': 'close',
#   'id': 40,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'WBTC-USD': {'base_currency': 'WBTC',
#   'base_currency_scale': 8,
#   'counter_currency': 'USD',
#   'counter_currency_scale': 2,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 2,
#   'min_order_size': 2000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 1,
#   'lot_size_scale': 8,
#   'status': 'open',
#   'id': 99,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'UNI-USDC': {'base_currency': 'UNI',
#   'base_currency_scale': 8,
#   'counter_currency': 'USDC',
#   'counter_currency_scale': 6,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 3,
#   'min_order_size': 8800000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 1,
#   'lot_size_scale': 8,
#   'status': 'open',
#   'id': 72,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'LTC-EUR': {'base_currency': 'LTC',
#   'base_currency_scale': 8,
#   'counter_currency': 'EUR',
#   'counter_currency_scale': 2,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 2,
#   'min_order_size': 8800000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 1,
#   'lot_size_scale': 8,
#   'status': 'open',
#   'id': 21,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'WDGLD-DGLD': {'base_currency': 'WDGLD',
#   'base_currency_scale': 8,
#   'counter_currency': 'DGLD',
#   'counter_currency_scale': 8,
#   'min_price_increment': 10000,
#   'min_price_increment_scale': 8,
#   'min_order_size': 2500000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 10000,
#   'lot_size_scale': 8,
#   'status': 'open',
#   'id': 57,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'DOT-USD': {'base_currency': 'DOT',
#   'base_currency_scale': 9,
#   'counter_currency': 'USD',
#   'counter_currency_scale': 2,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 2,
#   'min_order_size': 8800000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 1,
#   'lot_size_scale': 8,
#   'status': 'open',
#   'id': 58,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'USDT-TRY': {'base_currency': 'USDT',
#   'base_currency_scale': 6,
#   'counter_currency': 'TRY',
#   'counter_currency_scale': 2,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 2,
#   'min_order_size': 500000000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 10000,
#   'lot_size_scale': 8,
#   'status': 'close',
#   'id': 39,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'USDT-USD': {'base_currency': 'USDT',
#   'base_currency_scale': 6,
#   'counter_currency': 'USD',
#   'counter_currency_scale': 2,
#   'min_price_increment': 10000,
#   'min_price_increment_scale': 8,
#   'min_order_size': 500000000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 10000,
#   'lot_size_scale': 8,
#   'status': 'open',
#   'id': 24,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'COMP-USDT': {'base_currency': 'COMP',
#   'base_currency_scale': 8,
#   'counter_currency': 'USDT',
#   'counter_currency_scale': 6,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 2,
#   'min_order_size': 1800000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 1,
#   'lot_size_scale': 8,
#   'status': 'open',
#   'id': 81,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'LEND-USDT': {'base_currency': 'LEND',
#   'base_currency_scale': 8,
#   'counter_currency': 'USDT',
#   'counter_currency_scale': 6,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 4,
#   'min_order_size': 20000000,
#   'min_order_size_scale': 7,
#   'max_order_size': 0,
#   'max_order_size_scale': 7,
#   'lot_size': 1,
#   'lot_size_scale': 6,
#   'status': 'close',
#   'id': 44,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'ETH-GBP': {'base_currency': 'ETH',
#   'base_currency_scale': 8,
#   'counter_currency': 'GBP',
#   'counter_currency_scale': 2,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 2,
#   'min_order_size': 3500000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 1,
#   'lot_size_scale': 8,
#   'status': 'open',
#   'id': 36,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'OGN-USD': {'base_currency': 'OGN',
#   'base_currency_scale': 8,
#   'counter_currency': 'USD',
#   'counter_currency_scale': 2,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 4,
#   'min_order_size': 20000000,
#   'min_order_size_scale': 7,
#   'max_order_size': 0,
#   'max_order_size_scale': 7,
#   'lot_size': 1,
#   'lot_size_scale': 6,
#   'status': 'open',
#   'id': 53,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'AAVE-USDT': {'base_currency': 'AAVE',
#   'base_currency_scale': 8,
#   'counter_currency': 'USDT',
#   'counter_currency_scale': 6,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 2,
#   'min_order_size': 3500000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 1,
#   'lot_size_scale': 8,
#   'status': 'open',
#   'id': 50,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'ETH-PAX': {'base_currency': 'ETH',
#   'base_currency_scale': 8,
#   'counter_currency': 'PAX',
#   'counter_currency_scale': 8,
#   'min_price_increment': 1000000,
#   'min_price_increment_scale': 8,
#   'min_order_size': 2200000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 1,
#   'lot_size_scale': 8,
#   'status': 'close',
#   'id': 17,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'USDC-USDT': {'base_currency': 'USDC',
#   'base_currency_scale': 6,
#   'counter_currency': 'USDT',
#   'counter_currency_scale': 6,
#   'min_price_increment': 10000,
#   'min_price_increment_scale': 8,
#   'min_order_size': 500000000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 10000,
#   'lot_size_scale': 8,
#   'status': 'open',
#   'id': 73,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'BCH-USDT': {'base_currency': 'BCH',
#   'base_currency_scale': 8,
#   'counter_currency': 'USDT',
#   'counter_currency_scale': 6,
#   'min_price_increment': 1000000,
#   'min_price_increment_scale': 8,
#   'min_order_size': 1800000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 1,
#   'lot_size_scale': 8,
#   'status': 'close',
#   'id': 28,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'ALGO-USDT': {'base_currency': 'ALGO',
#   'base_currency_scale': 6,
#   'counter_currency': 'USDT',
#   'counter_currency_scale': 6,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 4,
#   'min_order_size': 20000000,
#   'min_order_size_scale': 7,
#   'max_order_size': 0,
#   'max_order_size_scale': 7,
#   'lot_size': 1,
#   'lot_size_scale': 6,
#   'status': 'close',
#   'id': 32,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'ENJ-USD': {'base_currency': 'ENJ',
#   'base_currency_scale': 8,
#   'counter_currency': 'USD',
#   'counter_currency_scale': 2,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 4,
#   'min_order_size': 20000000,
#   'min_order_size_scale': 7,
#   'max_order_size': 0,
#   'max_order_size_scale': 7,
#   'lot_size': 1,
#   'lot_size_scale': 6,
#   'status': 'open',
#   'id': 51,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'SUSHI-USDC': {'base_currency': 'SUSHI',
#   'base_currency_scale': 8,
#   'counter_currency': 'USDC',
#   'counter_currency_scale': 6,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 3,
#   'min_order_size': 12500000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 1,
#   'lot_size_scale': 8,
#   'status': 'open',
#   'id': 95,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'LTC-USDT': {'base_currency': 'LTC',
#   'base_currency_scale': 8,
#   'counter_currency': 'USDT',
#   'counter_currency_scale': 6,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 2,
#   'min_order_size': 8800000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 1,
#   'lot_size_scale': 8,
#   'status': 'close',
#   'id': 29,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'DAI-GBP': {'base_currency': 'DAI',
#   'base_currency_scale': 8,
#   'counter_currency': 'GBP',
#   'counter_currency_scale': 2,
#   'min_price_increment': 10000,
#   'min_price_increment_scale': 8,
#   'min_order_size': 500000000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 10000,
#   'lot_size_scale': 8,
#   'status': 'open',
#   'id': 79,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'EFI-USDC': {'base_currency': 'EFI',
#   'base_currency_scale': 8,
#   'counter_currency': 'USDC',
#   'counter_currency_scale': 6,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 3,
#   'min_order_size': 1000000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 1,
#   'lot_size_scale': 8,
#   'status': 'open',
#   'id': 92,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'BTC-EUR': {'base_currency': 'BTC',
#   'base_currency_scale': 8,
#   'counter_currency': 'EUR',
#   'counter_currency_scale': 2,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 2,
#   'min_order_size': 50000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 1,
#   'lot_size_scale': 8,
#   'status': 'open',
#   'id': 4,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'USDT-EUR': {'base_currency': 'USDT',
#   'base_currency_scale': 6,
#   'counter_currency': 'EUR',
#   'counter_currency_scale': 2,
#   'min_price_increment': 10000,
#   'min_price_increment_scale': 8,
#   'min_order_size': 500000000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 10000,
#   'lot_size_scale': 8,
#   'status': 'open',
#   'id': 25,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'DGLD-USD': {'base_currency': 'DGLD',
#   'base_currency_scale': 8,
#   'counter_currency': 'USD',
#   'counter_currency_scale': 2,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 2,
#   'min_order_size': 3500000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 1,
#   'lot_size_scale': 8,
#   'status': 'open',
#   'id': 33,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'EOS-USDC': {'base_currency': 'EOS',
#   'base_currency_scale': 4,
#   'counter_currency': 'USDC',
#   'counter_currency_scale': 6,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 2,
#   'min_order_size': 8800000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 1,
#   'lot_size_scale': 8,
#   'status': 'close',
#   'id': 98,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'YFI-USDT': {'base_currency': 'YFI',
#   'base_currency_scale': 8,
#   'counter_currency': 'USDT',
#   'counter_currency_scale': 6,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 2,
#   'min_order_size': 100000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 1,
#   'lot_size_scale': 8,
#   'status': 'open',
#   'id': 46,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'SUSHI-USDT': {'base_currency': 'SUSHI',
#   'base_currency_scale': 8,
#   'counter_currency': 'USDT',
#   'counter_currency_scale': 6,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 3,
#   'min_order_size': 1000000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 1,
#   'lot_size_scale': 8,
#   'status': 'open',
#   'id': 93,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'ENJ-USDT': {'base_currency': 'ENJ',
#   'base_currency_scale': 8,
#   'counter_currency': 'USDT',
#   'counter_currency_scale': 6,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 4,
#   'min_order_size': 20000000,
#   'min_order_size_scale': 7,
#   'max_order_size': 0,
#   'max_order_size_scale': 7,
#   'lot_size': 1,
#   'lot_size_scale': 6,
#   'status': 'open',
#   'id': 52,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'COMP-USDC': {'base_currency': 'COMP',
#   'base_currency_scale': 8,
#   'counter_currency': 'USDC',
#   'counter_currency_scale': 6,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 2,
#   'min_order_size': 1800000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 1,
#   'lot_size_scale': 8,
#   'status': 'open',
#   'id': 82,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'LTC-PAX': {'base_currency': 'LTC',
#   'base_currency_scale': 8,
#   'counter_currency': 'PAX',
#   'counter_currency_scale': 8,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 2,
#   'min_order_size': 8800000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 1,
#   'lot_size_scale': 8,
#   'status': 'close',
#   'id': 22,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'MATIC-USDC': {'base_currency': 'MATIC',
#   'base_currency_scale': 8,
#   'counter_currency': 'USDC',
#   'counter_currency_scale': 6,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 3,
#   'min_order_size': 100000000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 1,
#   'lot_size_scale': 8,
#   'status': 'open',
#   'id': 102,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'PAX-EUR': {'base_currency': 'PAX',
#   'base_currency_scale': 8,
#   'counter_currency': 'EUR',
#   'counter_currency_scale': 2,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 4,
#   'min_order_size': 500000000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 10000,
#   'lot_size_scale': 8,
#   'status': 'close',
#   'id': 15,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'AAVE-USD': {'base_currency': 'AAVE',
#   'base_currency_scale': 8,
#   'counter_currency': 'USD',
#   'counter_currency_scale': 2,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 2,
#   'min_order_size': 3500000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 1,
#   'lot_size_scale': 8,
#   'status': 'open',
#   'id': 49,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'DOT-GBP': {'base_currency': 'DOT',
#   'base_currency_scale': 9,
#   'counter_currency': 'GBP',
#   'counter_currency_scale': 2,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 2,
#   'min_order_size': 8800000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 1,
#   'lot_size_scale': 8,
#   'status': 'open',
#   'id': 60,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'BTC-USDT': {'base_currency': 'BTC',
#   'base_currency_scale': 8,
#   'counter_currency': 'USDT',
#   'counter_currency_scale': 6,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 2,
#   'min_order_size': 50000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 1,
#   'lot_size_scale': 8,
#   'status': 'open',
#   'id': 26,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'ETH-USDT': {'base_currency': 'ETH',
#   'base_currency_scale': 8,
#   'counter_currency': 'USDT',
#   'counter_currency_scale': 6,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 2,
#   'min_order_size': 2200000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 1,
#   'lot_size_scale': 8,
#   'status': 'open',
#   'id': 27,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'MATIC-USD': {'base_currency': 'MATIC',
#   'base_currency_scale': 8,
#   'counter_currency': 'USD',
#   'counter_currency_scale': 2,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 3,
#   'min_order_size': 100000000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 1,
#   'lot_size_scale': 8,
#   'status': 'open',
#   'id': 104,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'SUSHI-USD': {'base_currency': 'SUSHI',
#   'base_currency_scale': 8,
#   'counter_currency': 'USD',
#   'counter_currency_scale': 2,
#   'min_price_increment': 1,
#   'min_price_increment_scale': 3,
#   'min_order_size': 12500000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 1,
#   'lot_size_scale': 8,
#   'status': 'open',
#   'id': 94,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0},
#  'DAI-USD': {'base_currency': 'DAI',
#   'base_currency_scale': 8,
#   'counter_currency': 'USD',
#   'counter_currency_scale': 2,
#   'min_price_increment': 10000,
#   'min_price_increment_scale': 8,
#   'min_order_size': 500000000,
#   'min_order_size_scale': 8,
#   'max_order_size': 0,
#   'max_order_size_scale': 8,
#   'lot_size': 10000,
#   'lot_size_scale': 8,
#   'status': 'open',
#   'id': 74,
#   'auction_price': 0.0,
#   'auction_size': 0.0,
#   'auction_time': '',
#   'imbalance': 0.0}}

# %%
type(response)
# Out:
# dict

# %%
len(response)
# Out:
# 102

# %%
response['DGLD-USD']
# Out:
# {'base_currency': 'DGLD',
#  'base_currency_scale': 8,
#  'counter_currency': 'USD',
#  'counter_currency_scale': 2,
#  'min_price_increment': 1,
#  'min_price_increment_scale': 2,
#  'min_order_size': 3500000,
#  'min_order_size_scale': 8,
#  'max_order_size': 0,
#  'max_order_size_scale': 8,
#  'lot_size': 1,
#  'lot_size_scale': 8,
#  'status': 'open',
#  'id': 33,
#  'auction_price': 0.0,
#  'auction_size': 0.0,
#  'auction_time': '',
#  'imbalance': 0.0}

# %%
response['DGLD-USD']['base_currency']
# Out:
# 'DGLD'

# %%
len(response)
# Out:
# 102

# %%
type(response)
# Out:
# dict

# %%
d_keys_list = list(response.keys())

# %%
type(d_keys_list)
# Out:
# list

# %% [markdown]
# # LOOP - API

# %%
url='https://api.blockchain.com/v3/exchange/l2/'

d = []
e = []
n_found = []

r_c=0
s_c=1

# for c in iter(d_keys_list):
#     try:
#         response = requests.get(f'{url}+{c}').json()
#         d.append(response['bids'])

for c in d_keys_list:
    response = requests.get(f'{url}+{c}').json()
    d.append(response['bids'])
    print (f'Processing Record {r_c} of Set {s_c} | {c}')
    r_c = r_c +1
    if r_c == 50:
        r_c = 0 
        s_c = s_c +1
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-56-ecd86e8605f1> in <module>
#      14
#      15 for c in d_keys_list:
# ---> 16     response = requests.get(f'{url}+{c}').json()
#      17     d.append(response['bids'])
#      18     print (f'Processing Record {r_c} of Set {s_c} | {c}')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/models.py in json(self, **kwargs)
#     896                     # used.
#     897                     pass
# --> 898         return complexjson.loads(self.text, **kwargs)
#     899
#     900     @property
#
# ~/opt/anaconda3/lib/python3.8/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# ~/opt/anaconda3/lib/python3.8/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~/opt/anaconda3/lib/python3.8/json/decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
