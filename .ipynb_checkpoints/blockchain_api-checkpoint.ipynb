# %%
# This library does not brin much information about daily transactions

# %%
from tradingview_ta import TA_Handler, Interval, Exchange

# %%
tesla = TA_Handler(
    symbol="TSLA",
    screener="america",
    exchange="NASDAQ",
    interval=Interval.INTERVAL_1_DAY
)
print(tesla.get_analysis().summary)
# Example output: {"RECOMMENDATION": "BUY", "BUY": 8, "NEUTRAL": 6, "SELL": 3}
# Out:
# {'RECOMMENDATION': 'BUY', 'BUY': 15, 'SELL': 5, 'NEUTRAL': 6}

# %%
tesla = TA_Handler(
    symbol="RSRBTC",
    screener="crypto",
    exchange="BINANCE",
    interval=Interval.INTERVAL_1_MONTH
)
print(tesla.get_analysis().summary)
# Out:
# {'RECOMMENDATION': 'SELL', 'BUY': 3, 'SELL': 6, 'NEUTRAL': 6}

# %% [markdown]
# # https://www.blockchain.com/api

# %% [markdown]
# # 24 Hours Ticker

# %%
# Dependencies and Setp up
import json
import requests
import pandas as pd
import numpy as np
import datetime as dt

# %%
url = 'https://api.blockchain.com/v3/exchange/tickers'

# %%
# Json file
response = requests.get(url).json()

# %%
response
# Out:
# [{'symbol': 'XLM-EUR',
#   'price_24h': 0.31807,
#   'volume_24h': 57185.5911822,
#   'last_trade_price': 0.311},
#  {'symbol': 'ALGO-BTC',
#   'price_24h': 3.087e-05,
#   'volume_24h': 223.638922,
#   'last_trade_price': 3.024e-05},
#  {'symbol': 'EFI-USDT',
#   'price_24h': 1.48,
#   'volume_24h': 3414.00474007,
#   'last_trade_price': 1.499},
#  {'symbol': 'XLM-BTC',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 5.51e-06},
#  {'symbol': 'USDC-GBP',
#   'price_24h': 0.7447,
#   'volume_24h': 50000.0,
#   'last_trade_price': 0.7447},
#  {'symbol': 'OGN-USDT',
#   'price_24h': 1.0535,
#   'volume_24h': 0.0,
#   'last_trade_price': 1.0535},
#  {'symbol': 'CLOUT-USD',
#   'price_24h': 77.65,
#   'volume_24h': 529.95665278,
#   'last_trade_price': 75.12},
#  {'symbol': 'STX-USDC',
#   'price_24h': 1.941,
#   'volume_24h': 25515.41380356,
#   'last_trade_price': 1.969},
#  {'symbol': 'EOS-USD',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.0},
#  {'symbol': 'BCH-USD',
#   'price_24h': 601.1,
#   'volume_24h': 175.6808587,
#   'last_trade_price': 599.55},
#  {'symbol': 'PAX-USD',
#   'price_24h': 1.0001,
#   'volume_24h': 0.0,
#   'last_trade_price': 1.0001},
#  {'symbol': 'DAI-EUR',
#   'price_24h': 0.8675,
#   'volume_24h': 9994.3089,
#   'last_trade_price': 0.8675},
#  {'symbol': 'USDT-GBP',
#   'price_24h': 0.7425,
#   'volume_24h': 12772.6015,
#   'last_trade_price': 0.7424},
#  {'symbol': 'LINK-USDT',
#   'price_24h': 32.65,
#   'volume_24h': 109.91158788,
#   'last_trade_price': 32.67},
#  {'symbol': 'STX-USD',
#   'price_24h': 1.937,
#   'volume_24h': 49635.54610985,
#   'last_trade_price': 1.985},
#  {'symbol': 'MATIC-USDT',
#   'price_24h': 1.944,
#   'volume_24h': 0.0,
#   'last_trade_price': 1.944},
#  {'symbol': 'WDGLD-USD',
#   'price_24h': 175.52,
#   'volume_24h': 107.68485005,
#   'last_trade_price': 176.23},
#  {'symbol': 'ETH-USD',
#   'price_24h': 4511.66,
#   'volume_24h': 1941.48203185,
#   'last_trade_price': 4490.74},
#  {'symbol': 'LEND-USD',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.4909},
#  {'symbol': 'XLM-PAX',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.06981},
#  {'symbol': 'XRP-EUR',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.22},
#  {'symbol': 'XLM-USD',
#   'price_24h': 0.37055,
#   'volume_24h': 240895.8536803,
#   'last_trade_price': 0.36273},
#  {'symbol': 'LINK-USDC',
#   'price_24h': 32.852,
#   'volume_24h': 15.20670243,
#   'last_trade_price': 32.852},
#  {'symbol': 'DGLD-BTC',
#   'price_24h': 0.002834,
#   'volume_24h': 0.05652057,
#   'last_trade_price': 0.002834},
#  {'symbol': 'BCH-EUR',
#   'price_24h': 525.7,
#   'volume_24h': 33.49015694,
#   'last_trade_price': 515.58},
#  {'symbol': 'BCH-BTC',
#   'price_24h': 0.009769,
#   'volume_24h': 0.57888872,
#   'last_trade_price': 0.009812},
#  {'symbol': 'CLOUT-BTC',
#   'price_24h': 0.001236,
#   'volume_24h': 654.88346129,
#   'last_trade_price': 0.001217},
#  {'symbol': 'BTC-USD',
#   'price_24h': 61122.68,
#   'volume_24h': 325.89883167,
#   'last_trade_price': 61163.3},
#  {'symbol': 'BCH-ETH',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.582678},
#  {'symbol': 'ETH-TRY',
#   'price_24h': 23950.9,
#   'volume_24h': 0.0,
#   'last_trade_price': 23950.9},
#  {'symbol': 'BTC-TRY',
#   'price_24h': 390682.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 390682.0},
#  {'symbol': 'ALGO-USD',
#   'price_24h': 1.9,
#   'volume_24h': 62500.491474,
#   'last_trade_price': 1.8393},
#  {'symbol': 'ETH-EUR',
#   'price_24h': 3920.0,
#   'volume_24h': 16.64469458,
#   'last_trade_price': 3886.52},
#  {'symbol': 'DOGE-USD',
#   'price_24h': 0.26432,
#   'volume_24h': 42221.3724294,
#   'last_trade_price': 0.25998},
#  {'symbol': 'STX-USDT',
#   'price_24h': 1.922,
#   'volume_24h': 63951.62810474,
#   'last_trade_price': 1.96},
#  {'symbol': 'XRP-USD',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.29},
#  {'symbol': 'XLM-ETH',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.00019195},
#  {'symbol': 'YFI-USD',
#   'price_24h': 34389.41,
#   'volume_24h': 0.0,
#   'last_trade_price': 34389.41},
#  {'symbol': 'BTC-PAX',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 6115.0},
#  {'symbol': 'WBTC-USDC',
#   'price_24h': 60485.35,
#   'volume_24h': 0.0,
#   'last_trade_price': 60485.35},
#  {'symbol': 'MKR-USDT',
#   'price_24h': 2671.2,
#   'volume_24h': 0.0,
#   'last_trade_price': 2671.2},
#  {'symbol': 'UNI-USDT',
#   'price_24h': 27.944,
#   'volume_24h': 0.0,
#   'last_trade_price': 27.944},
#  {'symbol': 'DOT-EUR',
#   'price_24h': 46.94,
#   'volume_24h': 71.87589018,
#   'last_trade_price': 45.99},
#  {'symbol': 'BCH-PAX',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 339.24},
#  {'symbol': 'DAI-USDC',
#   'price_24h': 1.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 1.0},
#  {'symbol': 'UNI-USD',
#   'price_24h': 25.039,
#   'volume_24h': 0.0,
#   'last_trade_price': 25.028},
#  {'symbol': 'ETH-BTC',
#   'price_24h': 0.0746,
#   'volume_24h': 1.34481986,
#   'last_trade_price': 0.0732},
#  {'symbol': 'WDGLD-BTC',
#   'price_24h': 0.002902,
#   'volume_24h': 5.019,
#   'last_trade_price': 0.002902},
#  {'symbol': 'USDC-EUR',
#   'price_24h': 0.8672,
#   'volume_24h': 7.9064,
#   'last_trade_price': 0.8672},
#  {'symbol': 'WBTC-USDT',
#   'price_24h': 58764.45,
#   'volume_24h': 0.0,
#   'last_trade_price': 58202.11},
#  {'symbol': 'MKR-USDC',
#   'price_24h': 2453.35,
#   'volume_24h': 0.0,
#   'last_trade_price': 2453.35},
#  {'symbol': 'LINK-USD',
#   'price_24h': 31.365,
#   'volume_24h': 497.66509356,
#   'last_trade_price': 32.8},
#  {'symbol': 'LTC-USD',
#   'price_24h': 201.27,
#   'volume_24h': 34.18600661,
#   'last_trade_price': 200.41},
#  {'symbol': 'DOGE-USDT',
#   'price_24h': 0.26435,
#   'volume_24h': 4330.7266345,
#   'last_trade_price': 0.26435},
#  {'symbol': 'COMP-USD',
#   'price_24h': 367.0,
#   'volume_24h': 3.36669979,
#   'last_trade_price': 362.42},
#  {'symbol': 'LTC-BTC',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.005827},
#  {'symbol': 'EFI-USD',
#   'price_24h': 1.35,
#   'volume_24h': 24.203,
#   'last_trade_price': 1.38},
#  {'symbol': 'EOS-USDT',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.0},
#  {'symbol': 'DAI-USDT',
#   'price_24h': 1.0001,
#   'volume_24h': 0.0,
#   'last_trade_price': 1.0001},
#  {'symbol': 'BTC-GBP',
#   'price_24h': 45380.75,
#   'volume_24h': 7.06583125,
#   'last_trade_price': 45201.0},
#  {'symbol': 'USDC-USD',
#   'price_24h': 1.0001,
#   'volume_24h': 0.0,
#   'last_trade_price': 1.0002},
#  {'symbol': 'MKR-USD',
#   'price_24h': 2523.37,
#   'volume_24h': 0.0,
#   'last_trade_price': 2523.37},
#  {'symbol': 'LTC-TRY',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.0},
#  {'symbol': 'WBTC-USD',
#   'price_24h': 58824.32,
#   'volume_24h': 0.0,
#   'last_trade_price': 58824.32},
#  {'symbol': 'UNI-USDC',
#   'price_24h': 25.714,
#   'volume_24h': 0.0,
#   'last_trade_price': 25.714},
#  {'symbol': 'LTC-EUR',
#   'price_24h': 174.51,
#   'volume_24h': 80.89586421,
#   'last_trade_price': 172.42},
#  {'symbol': 'WDGLD-DGLD',
#   'price_24h': 1.01,
#   'volume_24h': 0.0,
#   'last_trade_price': 1.01},
#  {'symbol': 'DOT-USD',
#   'price_24h': 52.8,
#   'volume_24h': 2409.82414246,
#   'last_trade_price': 52.0},
#  {'symbol': 'USDT-TRY',
#   'price_24h': 8.29,
#   'volume_24h': 0.0,
#   'last_trade_price': 8.29},
#  {'symbol': 'USDT-USD',
#   'price_24h': 1.0009,
#   'volume_24h': 84527.1379,
#   'last_trade_price': 1.0009},
#  {'symbol': 'COMP-USDT',
#   'price_24h': 366.77,
#   'volume_24h': 0.0,
#   'last_trade_price': 366.77},
#  {'symbol': 'LEND-USDT',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.4854},
#  {'symbol': 'ETH-GBP',
#   'price_24h': 3377.08,
#   'volume_24h': 22.37153318,
#   'last_trade_price': 3316.39},
#  {'symbol': 'OGN-USD',
#   'price_24h': 0.96,
#   'volume_24h': 491.857595,
#   'last_trade_price': 0.96},
#  {'symbol': 'AAVE-USDT',
#   'price_24h': 333.53,
#   'volume_24h': 25.07311949,
#   'last_trade_price': 344.03},
#  {'symbol': 'ETH-PAX',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 219.41},
#  {'symbol': 'USDC-USDT',
#   'price_24h': 0.999,
#   'volume_24h': 1686.737,
#   'last_trade_price': 0.999},
#  {'symbol': 'BCH-USDT',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 358.46},
#  {'symbol': 'ALGO-USDT',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.3614},
#  {'symbol': 'ENJ-USD',
#   'price_24h': 2.9093,
#   'volume_24h': 372.600617,
#   'last_trade_price': 2.8947},
#  {'symbol': 'SUSHI-USDC',
#   'price_24h': 12.097,
#   'volume_24h': 0.0,
#   'last_trade_price': 12.097},
#  {'symbol': 'LTC-USDT',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 73.28},
#  {'symbol': 'DAI-GBP',
#   'price_24h': 0.7322,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.7322},
#  {'symbol': 'EFI-USDC',
#   'price_24h': 1.2,
#   'volume_24h': 0.0,
#   'last_trade_price': 1.2},
#  {'symbol': 'BTC-EUR',
#   'price_24h': 52961.92,
#   'volume_24h': 11.95027848,
#   'last_trade_price': 53070.84},
#  {'symbol': 'USDT-EUR',
#   'price_24h': 0.8657,
#   'volume_24h': 213221.8492,
#   'last_trade_price': 0.8664},
#  {'symbol': 'DGLD-USD',
#   'price_24h': 175.69,
#   'volume_24h': 201.03598286,
#   'last_trade_price': 177.31},
#  {'symbol': 'EOS-USDC',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.0},
#  {'symbol': 'YFI-USDT',
#   'price_24h': 33886.08,
#   'volume_24h': 0.00552711,
#   'last_trade_price': 34080.64},
#  {'symbol': 'SUSHI-USDT',
#   'price_24h': 13.141,
#   'volume_24h': 0.0,
#   'last_trade_price': 13.141},
#  {'symbol': 'COMP-USDC',
#   'price_24h': 339.89,
#   'volume_24h': 0.0,
#   'last_trade_price': 339.89},
#  {'symbol': 'ENJ-USDT',
#   'price_24h': 2.8675,
#   'volume_24h': 8.030003,
#   'last_trade_price': 2.8752},
#  {'symbol': 'LTC-PAX',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 74.03},
#  {'symbol': 'MATIC-USDC',
#   'price_24h': 1.905,
#   'volume_24h': 0.0,
#   'last_trade_price': 1.905},
#  {'symbol': 'PAX-EUR',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.9444},
#  {'symbol': 'AAVE-USD',
#   'price_24h': 327.13,
#   'volume_24h': 99.66676327,
#   'last_trade_price': 326.4},
#  {'symbol': 'BTC-USDT',
#   'price_24h': 61671.5,
#   'volume_24h': 4.00824783,
#   'last_trade_price': 61017.3},
#  {'symbol': 'DOT-GBP',
#   'price_24h': 39.0,
#   'volume_24h': 359.05635185,
#   'last_trade_price': 37.0},
#  {'symbol': 'ETH-USDT',
#   'price_24h': 4520.1,
#   'volume_24h': 20.48738371,
#   'last_trade_price': 4481.23},
#  {'symbol': 'MATIC-USD',
#   'price_24h': 1.999,
#   'volume_24h': 2990.4508093,
#   'last_trade_price': 1.895},
#  {'symbol': 'SUSHI-USD',
#   'price_24h': 12.261,
#   'volume_24h': 36.15404786,
#   'last_trade_price': 13.181},
#  {'symbol': 'DAI-USD',
#   'price_24h': 1.0004,
#   'volume_24h': 26086.7112,
#   'last_trade_price': 0.9945}]

# %%
type(response)
# Out:
# list

# %%
len(response)
# Out:
# 102

# %%
today= dt.datetime.today().strftime("%m-%d-%Y")
today
# Out:
# '11-05-2021'

# %%
df= pd.DataFrame (response)
df['difference'] = ''
df['date']=today
df
# Out:
#         symbol    price_24h    volume_24h  last_trade_price difference  \
# 0      XLM-EUR     0.318070  57185.591182          0.311000
# 1     ALGO-BTC     0.000031    223.638922          0.000030
# 2     EFI-USDT     1.480000   3414.004740          1.499000
# 3      XLM-BTC     0.000000      0.000000          0.000006
# 4     USDC-GBP     0.744700  50000.000000          0.744700
# ..         ...          ...           ...               ...        ...
# 97     DOT-GBP    39.000000    359.056352         37.000000
# 98    ETH-USDT  4520.100000     20.487384       4481.230000
# 99   MATIC-USD     1.999000   2990.450809          1.895000
# 100  SUSHI-USD    12.261000     36.154048         13.181000
# 101    DAI-USD     1.000400  26086.711200          0.994500
#
#            date
# 0    11-05-2021
# 1    11-05-2021
# 2    11-05-2021
# 3    11-05-2021
# 4    11-05-2021
# ..          ...
# 97   11-05-2021
# 98   11-05-2021
# 99   11-05-2021
# 100  11-05-2021
# 101  11-05-2021
#
# [102 rows x 6 columns]

# %%
df.to_csv(f'blockchain_{today}.csv', sep=',', index=False)
