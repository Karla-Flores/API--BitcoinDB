# %%
# This library does not brin much information about daily transactions

# %%
from tradingview_ta import TA_Handler, Interval, Exchange

# %%
tesla = TA_Handler(
    symbol="TSLA",
    screener="america",
    exchange="NASDAQ",
    interval=Interval.INTERVAL_1_DAY
)
print(tesla.get_analysis().summary)
# Example output: {"RECOMMENDATION": "BUY", "BUY": 8, "NEUTRAL": 6, "SELL": 3}
# Out:
# {'RECOMMENDATION': 'SELL', 'BUY': 5, 'SELL': 11, 'NEUTRAL': 10}

# %%
tesla = TA_Handler(
    symbol="RSRBTC",
    screener="crypto",
    exchange="BINANCE",
    interval=Interval.INTERVAL_1_MONTH
)
print(tesla.get_analysis().summary)
# Out:
# {'RECOMMENDATION': 'SELL', 'BUY': 1, 'SELL': 7, 'NEUTRAL': 7}

# %% [markdown]
# # https://www.blockchain.com/api

# %% [markdown]
# # 24 Hours Ticker

# %%
# Dependencies and Setp up
import json
import requests
import pandas as pd
import numpy as np
import datetime as dt

# %%
url = 'https://api.blockchain.com/v3/exchange/tickers'

# %%
# Json file
response = requests.get(url).json()

# %%
response
# Out:
# [{'symbol': 'XLM-EUR',
#   'price_24h': 0.27218,
#   'volume_24h': 472444.437416,
#   'last_trade_price': 0.24168},
#  {'symbol': 'EFI-USDT',
#   'price_24h': 1.146,
#   'volume_24h': 0.0,
#   'last_trade_price': 1.146},
#  {'symbol': 'ALGO-BTC',
#   'price_24h': 3.355e-05,
#   'volume_24h': 93.46291,
#   'last_trade_price': 3.24e-05},
#  {'symbol': 'XLM-BTC',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 5.51e-06},
#  {'symbol': 'USDC-GBP',
#   'price_24h': 0.7563,
#   'volume_24h': 61320.8245,
#   'last_trade_price': 0.7561},
#  {'symbol': 'OGN-USDT',
#   'price_24h': 0.7597,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.7597},
#  {'symbol': 'CLOUT-USD',
#   'price_24h': 94.55,
#   'volume_24h': 949.67286648,
#   'last_trade_price': 92.0},
#  {'symbol': 'STX-USDC',
#   'price_24h': 2.327,
#   'volume_24h': 11349.64832825,
#   'last_trade_price': 2.145},
#  {'symbol': 'CEUR-USDT',
#   'price_24h': 1.14,
#   'volume_24h': 0.0,
#   'last_trade_price': 1.14},
#  {'symbol': 'EOS-USD',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.0},
#  {'symbol': 'BCH-USD',
#   'price_24h': 466.2,
#   'volume_24h': 23.28378155,
#   'last_trade_price': 458.88},
#  {'symbol': 'PAX-USD',
#   'price_24h': 0.9999,
#   'volume_24h': 64043.3683,
#   'last_trade_price': 0.9998},
#  {'symbol': 'DAI-EUR',
#   'price_24h': 0.8514,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.8514},
#  {'symbol': 'USDT-GBP',
#   'price_24h': 0.7577,
#   'volume_24h': 5891.4641,
#   'last_trade_price': 0.7564},
#  {'symbol': 'LINK-USDT',
#   'price_24h': 21.573,
#   'volume_24h': 2103.90819868,
#   'last_trade_price': 20.972},
#  {'symbol': 'STX-USD',
#   'price_24h': 2.327,
#   'volume_24h': 35067.58287165,
#   'last_trade_price': 2.144},
#  {'symbol': 'MATIC-USDT',
#   'price_24h': 2.169,
#   'volume_24h': 5554.58443117,
#   'last_trade_price': 2.227},
#  {'symbol': 'WDGLD-USD',
#   'price_24h': 174.17,
#   'volume_24h': 200.95637982,
#   'last_trade_price': 173.44},
#  {'symbol': 'ETH-USD',
#   'price_24h': 4384.21,
#   'volume_24h': 4176.43740248,
#   'last_trade_price': 4151.09},
#  {'symbol': 'LEND-USD',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.4909},
#  {'symbol': 'XLM-PAX',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.06981},
#  {'symbol': 'XRP-EUR',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.22},
#  {'symbol': 'XLM-USD',
#   'price_24h': 0.29655,
#   'volume_24h': 148344.4824816,
#   'last_trade_price': 0.27465},
#  {'symbol': 'LINK-USDC',
#   'price_24h': 20.987,
#   'volume_24h': 5.38206252,
#   'last_trade_price': 20.0},
#  {'symbol': 'DGLD-BTC',
#   'price_24h': 0.003548,
#   'volume_24h': 0.0617841,
#   'last_trade_price': 0.003548},
#  {'symbol': 'BCH-EUR',
#   'price_24h': 413.38,
#   'volume_24h': 90.90106169,
#   'last_trade_price': 404.15},
#  {'symbol': 'BCH-BTC',
#   'price_24h': 0.009433,
#   'volume_24h': 0.07121243,
#   'last_trade_price': 0.00952},
#  {'symbol': 'BTC-USD',
#   'price_24h': 49633.83,
#   'volume_24h': 559.08501416,
#   'last_trade_price': 48443.7},
#  {'symbol': 'CLOUT-BTC',
#   'price_24h': 0.001701,
#   'volume_24h': 0.56027902,
#   'last_trade_price': 0.001756},
#  {'symbol': 'BCH-ETH',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.582678},
#  {'symbol': 'ETH-TRY',
#   'price_24h': 23950.9,
#   'volume_24h': 0.0,
#   'last_trade_price': 23950.9},
#  {'symbol': 'BTC-TRY',
#   'price_24h': 390682.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 390682.0},
#  {'symbol': 'ALGO-USD',
#   'price_24h': 1.6494,
#   'volume_24h': 11368.717864,
#   'last_trade_price': 1.5717},
#  {'symbol': 'ETH-EUR',
#   'price_24h': 3858.17,
#   'volume_24h': 68.76080387,
#   'last_trade_price': 3665.88},
#  {'symbol': 'DOGE-USD',
#   'price_24h': 0.17749,
#   'volume_24h': 83862.6706941,
#   'last_trade_price': 0.17147},
#  {'symbol': 'STX-USDT',
#   'price_24h': 2.325,
#   'volume_24h': 16465.59659662,
#   'last_trade_price': 2.144},
#  {'symbol': 'XRP-USD',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.29},
#  {'symbol': 'XLM-ETH',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.00019195},
#  {'symbol': 'YFI-USD',
#   'price_24h': 21839.16,
#   'volume_24h': 0.001,
#   'last_trade_price': 21839.16},
#  {'symbol': 'BTC-PAX',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 6115.0},
#  {'symbol': 'WBTC-USDC',
#   'price_24h': 50261.62,
#   'volume_24h': 6.95e-05,
#   'last_trade_price': 50261.62},
#  {'symbol': 'MKR-USDT',
#   'price_24h': 2591.64,
#   'volume_24h': 0.0,
#   'last_trade_price': 2591.64},
#  {'symbol': 'UNI-USDT',
#   'price_24h': 17.152,
#   'volume_24h': 0.0,
#   'last_trade_price': 17.131},
#  {'symbol': 'DOT-EUR',
#   'price_24h': 25.49,
#   'volume_24h': 1273.25800637,
#   'last_trade_price': 24.37},
#  {'symbol': 'BCH-PAX',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 339.24},
#  {'symbol': 'DAI-USDC',
#   'price_24h': 0.9996,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.9996},
#  {'symbol': 'UNI-USD',
#   'price_24h': 18.536,
#   'volume_24h': 0.0,
#   'last_trade_price': 18.536},
#  {'symbol': 'ETH-BTC',
#   'price_24h': 0.08754,
#   'volume_24h': 8.7030689,
#   'last_trade_price': 0.085686},
#  {'symbol': 'WDGLD-BTC',
#   'price_24h': 0.003462,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.003462},
#  {'symbol': 'USDC-EUR',
#   'price_24h': 0.8845,
#   'volume_24h': 1449.7238,
#   'last_trade_price': 0.8851},
#  {'symbol': 'WBTC-USDT',
#   'price_24h': 51434.7,
#   'volume_24h': 0.0,
#   'last_trade_price': 51434.7},
#  {'symbol': 'MKR-USDC',
#   'price_24h': 2522.02,
#   'volume_24h': 0.00280796,
#   'last_trade_price': 2522.02},
#  {'symbol': 'LTC-USD',
#   'price_24h': 158.26,
#   'volume_24h': 102.83953168,
#   'last_trade_price': 153.85},
#  {'symbol': 'LINK-USD',
#   'price_24h': 21.227,
#   'volume_24h': 2318.4100167,
#   'last_trade_price': 20.578},
#  {'symbol': 'DOGE-USDT',
#   'price_24h': 0.17827,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.17827},
#  {'symbol': 'COMP-USD',
#   'price_24h': 212.55,
#   'volume_24h': 312.15284172,
#   'last_trade_price': 197.74},
#  {'symbol': 'CEUR-EUR',
#   'price_24h': 1.06,
#   'volume_24h': 0.0,
#   'last_trade_price': 1.06},
#  {'symbol': 'LTC-BTC',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.005827},
#  {'symbol': 'EFI-USD',
#   'price_24h': 1.38,
#   'volume_24h': 0.0,
#   'last_trade_price': 1.38},
#  {'symbol': 'EOS-USDT',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.0},
#  {'symbol': 'DAI-USDT',
#   'price_24h': 0.993,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.993},
#  {'symbol': 'BTC-GBP',
#   'price_24h': 37989.8,
#   'volume_24h': 6.76658679,
#   'last_trade_price': 36688.2},
#  {'symbol': 'USDC-USD',
#   'price_24h': 0.9999,
#   'volume_24h': 50.5331,
#   'last_trade_price': 0.9999},
#  {'symbol': 'MKR-USD',
#   'price_24h': 2691.23,
#   'volume_24h': 0.0,
#   'last_trade_price': 2691.23},
#  {'symbol': 'LTC-TRY',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.0},
#  {'symbol': 'WBTC-USD',
#   'price_24h': 50465.15,
#   'volume_24h': 6.94e-05,
#   'last_trade_price': 50465.15},
#  {'symbol': 'UNI-USDC',
#   'price_24h': 16.991,
#   'volume_24h': 0.0,
#   'last_trade_price': 16.991},
#  {'symbol': 'LTC-EUR',
#   'price_24h': 142.61,
#   'volume_24h': 421.9084723,
#   'last_trade_price': 136.9},
#  {'symbol': 'WDGLD-DGLD',
#   'price_24h': 0.99,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.99},
#  {'symbol': 'DOT-USD',
#   'price_24h': 28.85,
#   'volume_24h': 704.18643797,
#   'last_trade_price': 26.8},
#  {'symbol': 'USDT-TRY',
#   'price_24h': 8.29,
#   'volume_24h': 0.0,
#   'last_trade_price': 8.29},
#  {'symbol': 'USDT-USD',
#   'price_24h': 1.001,
#   'volume_24h': 76899.4967,
#   'last_trade_price': 1.0003},
#  {'symbol': 'COMP-USDT',
#   'price_24h': 212.44,
#   'volume_24h': 963.06034659,
#   'last_trade_price': 197.89},
#  {'symbol': 'LEND-USDT',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.4854},
#  {'symbol': 'ETH-GBP',
#   'price_24h': 3285.8,
#   'volume_24h': 36.23137685,
#   'last_trade_price': 3141.39},
#  {'symbol': 'OGN-USD',
#   'price_24h': 0.7419,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.7419},
#  {'symbol': 'AAVE-USDT',
#   'price_24h': 192.16,
#   'volume_24h': 113.97267993,
#   'last_trade_price': 179.54},
#  {'symbol': 'ETH-PAX',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 219.41},
#  {'symbol': 'USDC-USDT',
#   'price_24h': 0.9995,
#   'volume_24h': 22.0,
#   'last_trade_price': 0.9995},
#  {'symbol': 'BCH-USDT',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 358.46},
#  {'symbol': 'ALGO-USDT',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.3614},
#  {'symbol': 'SUSHI-USDC',
#   'price_24h': 5.295,
#   'volume_24h': 0.0,
#   'last_trade_price': 5.245},
#  {'symbol': 'ENJ-USD',
#   'price_24h': 2.9292,
#   'volume_24h': 2455.250933,
#   'last_trade_price': 2.6647},
#  {'symbol': 'LTC-USDT',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 73.28},
#  {'symbol': 'DAI-GBP',
#   'price_24h': 0.7555,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.7555},
#  {'symbol': 'BTC-EUR',
#   'price_24h': 43823.49,
#   'volume_24h': 51.65789249,
#   'last_trade_price': 42839.75},
#  {'symbol': 'EFI-USDC',
#   'price_24h': 1.376,
#   'volume_24h': 0.0,
#   'last_trade_price': 1.376},
#  {'symbol': 'USDT-EUR',
#   'price_24h': 0.8836,
#   'volume_24h': 8426.0295,
#   'last_trade_price': 0.8851},
#  {'symbol': 'DGLD-USD',
#   'price_24h': 174.05,
#   'volume_24h': 80.0,
#   'last_trade_price': 173.89},
#  {'symbol': 'EOS-USDC',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.0},
#  {'symbol': 'YFI-USDT',
#   'price_24h': 21760.52,
#   'volume_24h': 0.001,
#   'last_trade_price': 21760.52},
#  {'symbol': 'SUSHI-USDT',
#   'price_24h': 6.732,
#   'volume_24h': 0.0,
#   'last_trade_price': 6.732},
#  {'symbol': 'COMP-USDC',
#   'price_24h': 212.67,
#   'volume_24h': 0.05403603,
#   'last_trade_price': 201.53},
#  {'symbol': 'ENJ-USDT',
#   'price_24h': 2.916,
#   'volume_24h': 12.871234,
#   'last_trade_price': 2.6135},
#  {'symbol': 'LTC-PAX',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 74.03},
#  {'symbol': 'MATIC-USDC',
#   'price_24h': 2.435,
#   'volume_24h': 0.0,
#   'last_trade_price': 2.435},
#  {'symbol': 'PAX-EUR',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.9444},
#  {'symbol': 'AAVE-USD',
#   'price_24h': 193.36,
#   'volume_24h': 325.81614776,
#   'last_trade_price': 177.15},
#  {'symbol': 'DOT-GBP',
#   'price_24h': 21.69,
#   'volume_24h': 756.96167762,
#   'last_trade_price': 20.84},
#  {'symbol': 'BTC-USDT',
#   'price_24h': 49644.11,
#   'volume_24h': 57.28541296,
#   'last_trade_price': 48350.55},
#  {'symbol': 'ETH-USDT',
#   'price_24h': 4371.94,
#   'volume_24h': 1421.15675566,
#   'last_trade_price': 4148.74},
#  {'symbol': 'MATIC-USD',
#   'price_24h': 2.336,
#   'volume_24h': 11356.40176156,
#   'last_trade_price': 2.219},
#  {'symbol': 'SUSHI-USD',
#   'price_24h': 5.597,
#   'volume_24h': 4.38,
#   'last_trade_price': 5.48},
#  {'symbol': 'DAI-USD',
#   'price_24h': 1.0007,
#   'volume_24h': 0.0,
#   'last_trade_price': 1.0007}]

# %%
type(response)
# Out:
# list

# %%
len(response)
# Out:
# 104

# %%
today= dt.datetime.today().strftime("%m-%d-%Y")
today
# Out:
# '12-09-2021'

# %%
df= pd.DataFrame (response)
df['difference'] = ''
df['date']=today
df
# Out:
#         symbol     price_24h     volume_24h  last_trade_price difference  \
# 0      XLM-EUR      0.272180  472444.437416          0.241680
# 1     EFI-USDT      1.146000       0.000000          1.146000
# 2     ALGO-BTC      0.000034      93.462910          0.000032
# 3      XLM-BTC      0.000000       0.000000          0.000006
# 4     USDC-GBP      0.756300   61320.824500          0.756100
# ..         ...           ...            ...               ...        ...
# 99    BTC-USDT  49644.110000      57.285413      48350.550000
# 100   ETH-USDT   4371.940000    1421.156756       4148.740000
# 101  MATIC-USD      2.336000   11356.401762          2.219000
# 102  SUSHI-USD      5.597000       4.380000          5.480000
# 103    DAI-USD      1.000700       0.000000          1.000700
#
#            date
# 0    12-09-2021
# 1    12-09-2021
# 2    12-09-2021
# 3    12-09-2021
# 4    12-09-2021
# ..          ...
# 99   12-09-2021
# 100  12-09-2021
# 101  12-09-2021
# 102  12-09-2021
# 103  12-09-2021
#
# [104 rows x 6 columns]

# %%
df.to_csv(f'blockchain_{today}.csv', sep=',', index=False)
