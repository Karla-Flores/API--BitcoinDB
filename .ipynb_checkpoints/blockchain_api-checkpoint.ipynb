# %%
# This library does not brin much information about daily transactions

# %%
from tradingview_ta import TA_Handler, Interval, Exchange

# %%
tesla = TA_Handler(
    symbol="TSLA",
    screener="america",
    exchange="NASDAQ",
    interval=Interval.INTERVAL_1_DAY
)
print(tesla.get_analysis().summary)
# Example output: {"RECOMMENDATION": "BUY", "BUY": 8, "NEUTRAL": 6, "SELL": 3}
# Out:
# {'RECOMMENDATION': 'BUY', 'BUY': 13, 'SELL': 4, 'NEUTRAL': 9}

# %%
tesla = TA_Handler(
    symbol="RSRBTC",
    screener="crypto",
    exchange="BINANCE",
    interval=Interval.INTERVAL_1_MONTH
)
print(tesla.get_analysis().summary)
# Out:
# {'RECOMMENDATION': 'SELL', 'BUY': 2, 'SELL': 8, 'NEUTRAL': 5}

# %% [markdown]
# # https://www.blockchain.com/api

# %% [markdown]
# # 24 Hours Ticker

# %%
# Dependencies and Setp up
import json
import requests
import pandas as pd
import numpy as np
import datetime as dt

# %%
url = 'https://api.blockchain.com/v3/exchange/tickers'

# %%
# Json file
response = requests.get(url).json()

# %%
response
# Out:
# [{'symbol': 'XLM-EUR',
#   'price_24h': 0.33384,
#   'volume_24h': 47583.5990657,
#   'last_trade_price': 0.35},
#  {'symbol': 'ALGO-BTC',
#   'price_24h': 3.114e-05,
#   'volume_24h': 492.712764,
#   'last_trade_price': 3.114e-05},
#  {'symbol': 'EFI-USDT',
#   'price_24h': 1.787,
#   'volume_24h': 0.0,
#   'last_trade_price': 1.839},
#  {'symbol': 'XLM-BTC',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 5.51e-06},
#  {'symbol': 'USDC-GBP',
#   'price_24h': 0.751,
#   'volume_24h': 394.619,
#   'last_trade_price': 0.7488},
#  {'symbol': 'OGN-USDT',
#   'price_24h': 1.0464,
#   'volume_24h': 2867.363407,
#   'last_trade_price': 1.31},
#  {'symbol': 'CLOUT-USD',
#   'price_24h': 78.22,
#   'volume_24h': 3851.1349106,
#   'last_trade_price': 74.46},
#  {'symbol': 'STX-USDC',
#   'price_24h': 2.179,
#   'volume_24h': 18040.04047966,
#   'last_trade_price': 2.315},
#  {'symbol': 'EOS-USD',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.0},
#  {'symbol': 'BCH-USD',
#   'price_24h': 667.58,
#   'volume_24h': 60.99788593,
#   'last_trade_price': 679.6},
#  {'symbol': 'PAX-USD',
#   'price_24h': 0.9999,
#   'volume_24h': 1300.0,
#   'last_trade_price': 0.9999},
#  {'symbol': 'DAI-EUR',
#   'price_24h': 0.8723,
#   'volume_24h': 59993.472,
#   'last_trade_price': 0.8727},
#  {'symbol': 'USDT-GBP',
#   'price_24h': 0.7472,
#   'volume_24h': 7049.283,
#   'last_trade_price': 0.7484},
#  {'symbol': 'LINK-USDT',
#   'price_24h': 34.252,
#   'volume_24h': 11.0945582,
#   'last_trade_price': 34.819},
#  {'symbol': 'STX-USD',
#   'price_24h': 2.194,
#   'volume_24h': 28610.89871832,
#   'last_trade_price': 2.315},
#  {'symbol': 'MATIC-USDT',
#   'price_24h': 1.778,
#   'volume_24h': 4.73127019,
#   'last_trade_price': 1.677},
#  {'symbol': 'WDGLD-USD',
#   'price_24h': 181.52,
#   'volume_24h': 159.99999996,
#   'last_trade_price': 182.29},
#  {'symbol': 'ETH-USD',
#   'price_24h': 4626.55,
#   'volume_24h': 2050.75302902,
#   'last_trade_price': 4778.19},
#  {'symbol': 'LEND-USD',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.4909},
#  {'symbol': 'XLM-PAX',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.06981},
#  {'symbol': 'XRP-EUR',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.22},
#  {'symbol': 'XLM-USD',
#   'price_24h': 0.38082,
#   'volume_24h': 1270969.1880447,
#   'last_trade_price': 0.39073},
#  {'symbol': 'LINK-USDC',
#   'price_24h': 34.142,
#   'volume_24h': 0.03,
#   'last_trade_price': 34.51},
#  {'symbol': 'DGLD-BTC',
#   'price_24h': 0.002814,
#   'volume_24h': 0.1325238,
#   'last_trade_price': 0.002814},
#  {'symbol': 'BCH-EUR',
#   'price_24h': 589.0,
#   'volume_24h': 23.11988878,
#   'last_trade_price': 594.46},
#  {'symbol': 'BCH-BTC',
#   'price_24h': 0.010377,
#   'volume_24h': 0.0369069,
#   'last_trade_price': 0.010377},
#  {'symbol': 'CLOUT-BTC',
#   'price_24h': 0.001208,
#   'volume_24h': 35.763888,
#   'last_trade_price': 0.001141},
#  {'symbol': 'BTC-USD',
#   'price_24h': 64518.9,
#   'volume_24h': 275.01427634,
#   'last_trade_price': 64956.64},
#  {'symbol': 'BCH-ETH',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.582678},
#  {'symbol': 'ETH-TRY',
#   'price_24h': 23950.9,
#   'volume_24h': 0.0,
#   'last_trade_price': 23950.9},
#  {'symbol': 'BTC-TRY',
#   'price_24h': 390682.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 390682.0},
#  {'symbol': 'ALGO-USD',
#   'price_24h': 1.92,
#   'volume_24h': 95564.143031,
#   'last_trade_price': 2.155},
#  {'symbol': 'ETH-EUR',
#   'price_24h': 4043.01,
#   'volume_24h': 30.79028498,
#   'last_trade_price': 4200.0},
#  {'symbol': 'DOGE-USD',
#   'price_24h': 0.27645,
#   'volume_24h': 45124.0983324,
#   'last_trade_price': 0.26871},
#  {'symbol': 'STX-USDT',
#   'price_24h': 2.193,
#   'volume_24h': 14464.9949095,
#   'last_trade_price': 2.235},
#  {'symbol': 'XRP-USD',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.29},
#  {'symbol': 'XLM-ETH',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.00019195},
#  {'symbol': 'YFI-USD',
#   'price_24h': 34728.8,
#   'volume_24h': 0.04907505,
#   'last_trade_price': 34755.56},
#  {'symbol': 'BTC-PAX',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 6115.0},
#  {'symbol': 'WBTC-USDC',
#   'price_24h': 60485.35,
#   'volume_24h': 0.0,
#   'last_trade_price': 60485.35},
#  {'symbol': 'MKR-USDT',
#   'price_24h': 3348.68,
#   'volume_24h': 0.0,
#   'last_trade_price': 3381.03},
#  {'symbol': 'UNI-USDT',
#   'price_24h': 25.084,
#   'volume_24h': 0.19476136,
#   'last_trade_price': 25.084},
#  {'symbol': 'DOT-EUR',
#   'price_24h': 42.6,
#   'volume_24h': 49.14624701,
#   'last_trade_price': 42.42},
#  {'symbol': 'BCH-PAX',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 339.24},
#  {'symbol': 'DAI-USDC',
#   'price_24h': 1.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 1.0},
#  {'symbol': 'UNI-USD',
#   'price_24h': 24.56,
#   'volume_24h': 0.77687235,
#   'last_trade_price': 24.56},
#  {'symbol': 'ETH-BTC',
#   'price_24h': 0.072267,
#   'volume_24h': 7.09811822,
#   'last_trade_price': 0.07353},
#  {'symbol': 'WDGLD-BTC',
#   'price_24h': 0.002675,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.002675},
#  {'symbol': 'USDC-EUR',
#   'price_24h': 0.8723,
#   'volume_24h': 50014.0014,
#   'last_trade_price': 0.8737},
#  {'symbol': 'WBTC-USDT',
#   'price_24h': 60732.3,
#   'volume_24h': 0.0,
#   'last_trade_price': 60732.3},
#  {'symbol': 'MKR-USDC',
#   'price_24h': 3197.49,
#   'volume_24h': 0.0,
#   'last_trade_price': 3197.49},
#  {'symbol': 'LINK-USD',
#   'price_24h': 33.93,
#   'volume_24h': 47.63331951,
#   'last_trade_price': 33.39},
#  {'symbol': 'LTC-USD',
#   'price_24h': 256.36,
#   'volume_24h': 1091.28239964,
#   'last_trade_price': 277.25},
#  {'symbol': 'DOGE-USDT',
#   'price_24h': 0.26498,
#   'volume_24h': 1692.2449804,
#   'last_trade_price': 0.261},
#  {'symbol': 'COMP-USD',
#   'price_24h': 326.31,
#   'volume_24h': 43.55090527,
#   'last_trade_price': 329.39},
#  {'symbol': 'LTC-BTC',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.005827},
#  {'symbol': 'EFI-USD',
#   'price_24h': 1.62,
#   'volume_24h': 4464.49191895,
#   'last_trade_price': 1.542},
#  {'symbol': 'EOS-USDT',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.0},
#  {'symbol': 'DAI-USDT',
#   'price_24h': 0.9997,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.9997},
#  {'symbol': 'BTC-GBP',
#   'price_24h': 48267.34,
#   'volume_24h': 9.60567863,
#   'last_trade_price': 48979.15},
#  {'symbol': 'USDC-USD',
#   'price_24h': 1.0001,
#   'volume_24h': 9265.8206,
#   'last_trade_price': 1.0001},
#  {'symbol': 'MKR-USD',
#   'price_24h': 2845.48,
#   'volume_24h': 0.00646,
#   'last_trade_price': 2845.48},
#  {'symbol': 'LTC-TRY',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.0},
#  {'symbol': 'WBTC-USD',
#   'price_24h': 58823.35,
#   'volume_24h': 0.0,
#   'last_trade_price': 58823.35},
#  {'symbol': 'UNI-USDC',
#   'price_24h': 25.714,
#   'volume_24h': 0.0,
#   'last_trade_price': 25.714},
#  {'symbol': 'LTC-EUR',
#   'price_24h': 224.41,
#   'volume_24h': 160.81441972,
#   'last_trade_price': 246.0},
#  {'symbol': 'WDGLD-DGLD',
#   'price_24h': 1.01,
#   'volume_24h': 0.0,
#   'last_trade_price': 1.01},
#  {'symbol': 'DOT-USD',
#   'price_24h': 47.04,
#   'volume_24h': 2741.39258506,
#   'last_trade_price': 47.31},
#  {'symbol': 'USDT-TRY',
#   'price_24h': 8.29,
#   'volume_24h': 0.0,
#   'last_trade_price': 8.29},
#  {'symbol': 'USDT-USD',
#   'price_24h': 1.0055,
#   'volume_24h': 168152.6751,
#   'last_trade_price': 1.0004},
#  {'symbol': 'COMP-USDT',
#   'price_24h': 336.06,
#   'volume_24h': 0.2975492,
#   'last_trade_price': 330.93},
#  {'symbol': 'LEND-USDT',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.4854},
#  {'symbol': 'ETH-GBP',
#   'price_24h': 3461.16,
#   'volume_24h': 35.45457288,
#   'last_trade_price': 3582.05},
#  {'symbol': 'OGN-USD',
#   'price_24h': 1.08,
#   'volume_24h': 5640.521331,
#   'last_trade_price': 1.3},
#  {'symbol': 'AAVE-USDT',
#   'price_24h': 312.67,
#   'volume_24h': 13.81632975,
#   'last_trade_price': 312.0},
#  {'symbol': 'ETH-PAX',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 219.41},
#  {'symbol': 'USDC-USDT',
#   'price_24h': 0.999,
#   'volume_24h': 8205.0,
#   'last_trade_price': 0.9997},
#  {'symbol': 'BCH-USDT',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 358.46},
#  {'symbol': 'ALGO-USDT',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.3614},
#  {'symbol': 'ENJ-USD',
#   'price_24h': 2.9402,
#   'volume_24h': 186.422747,
#   'last_trade_price': 2.9088},
#  {'symbol': 'SUSHI-USDC',
#   'price_24h': 12.298,
#   'volume_24h': 0.0,
#   'last_trade_price': 12.298},
#  {'symbol': 'LTC-USDT',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 73.28},
#  {'symbol': 'DAI-GBP',
#   'price_24h': 0.7379,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.7379},
#  {'symbol': 'EFI-USDC',
#   'price_24h': 1.2,
#   'volume_24h': 0.0,
#   'last_trade_price': 1.2},
#  {'symbol': 'BTC-EUR',
#   'price_24h': 56375.9,
#   'volume_24h': 10.3894792,
#   'last_trade_price': 56966.41},
#  {'symbol': 'USDT-EUR',
#   'price_24h': 0.873,
#   'volume_24h': 25840.444,
#   'last_trade_price': 0.874},
#  {'symbol': 'DGLD-USD',
#   'price_24h': 180.72,
#   'volume_24h': 220.1325238,
#   'last_trade_price': 181.67},
#  {'symbol': 'EOS-USDC',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.0},
#  {'symbol': 'YFI-USDT',
#   'price_24h': 34462.8,
#   'volume_24h': 0.001,
#   'last_trade_price': 34462.8},
#  {'symbol': 'SUSHI-USDT',
#   'price_24h': 11.589,
#   'volume_24h': 0.0,
#   'last_trade_price': 11.589},
#  {'symbol': 'COMP-USDC',
#   'price_24h': 358.39,
#   'volume_24h': 0.0,
#   'last_trade_price': 358.39},
#  {'symbol': 'ENJ-USDT',
#   'price_24h': 3.1,
#   'volume_24h': 12.823422,
#   'last_trade_price': 2.88},
#  {'symbol': 'LTC-PAX',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 74.03},
#  {'symbol': 'MATIC-USDC',
#   'price_24h': 1.693,
#   'volume_24h': 1.00000001,
#   'last_trade_price': 1.693},
#  {'symbol': 'PAX-EUR',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.9444},
#  {'symbol': 'AAVE-USD',
#   'price_24h': 311.09,
#   'volume_24h': 19.44237094,
#   'last_trade_price': 305.0},
#  {'symbol': 'BTC-USDT',
#   'price_24h': 64481.5,
#   'volume_24h': 7.11713222,
#   'last_trade_price': 64296.6},
#  {'symbol': 'DOT-GBP',
#   'price_24h': 35.77,
#   'volume_24h': 30.07966653,
#   'last_trade_price': 38.2},
#  {'symbol': 'ETH-USDT',
#   'price_24h': 4651.51,
#   'volume_24h': 12.83076886,
#   'last_trade_price': 4755.38},
#  {'symbol': 'MATIC-USD',
#   'price_24h': 1.703,
#   'volume_24h': 4843.86696234,
#   'last_trade_price': 1.756},
#  {'symbol': 'SUSHI-USD',
#   'price_24h': 11.701,
#   'volume_24h': 44.0,
#   'last_trade_price': 11.701},
#  {'symbol': 'DAI-USD',
#   'price_24h': 1.0003,
#   'volume_24h': 15.8022,
#   'last_trade_price': 1.0003},
#  {'symbol': 'CEUR-USDT',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.0},
#  {'symbol': 'CEUR-EUR',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.0}]

# %%
type(response)
# Out:
# list

# %%
len(response)
# Out:
# 104

# %%
today= dt.datetime.today().strftime("%m-%d-%Y")
today
# Out:
# '11-11-2021'

# %%
df= pd.DataFrame (response)
df['difference'] = ''
df['date']=today
df
# Out:
#         symbol  price_24h    volume_24h  last_trade_price difference  \
# 0      XLM-EUR   0.333840  47583.599066          0.350000
# 1     ALGO-BTC   0.000031    492.712764          0.000031
# 2     EFI-USDT   1.787000      0.000000          1.839000
# 3      XLM-BTC   0.000000      0.000000          0.000006
# 4     USDC-GBP   0.751000    394.619000          0.748800
# ..         ...        ...           ...               ...        ...
# 99   MATIC-USD   1.703000   4843.866962          1.756000
# 100  SUSHI-USD  11.701000     44.000000         11.701000
# 101    DAI-USD   1.000300     15.802200          1.000300
# 102  CEUR-USDT   0.000000      0.000000          0.000000
# 103   CEUR-EUR   0.000000      0.000000          0.000000
#
#            date
# 0    11-11-2021
# 1    11-11-2021
# 2    11-11-2021
# 3    11-11-2021
# 4    11-11-2021
# ..          ...
# 99   11-11-2021
# 100  11-11-2021
# 101  11-11-2021
# 102  11-11-2021
# 103  11-11-2021
#
# [104 rows x 6 columns]

# %%
df.to_csv(f'blockchain_{today}.csv', sep=',', index=False)
