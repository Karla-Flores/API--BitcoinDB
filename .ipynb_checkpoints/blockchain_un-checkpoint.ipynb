# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from pathlib import Path
from sklearn.preprocessing import StandardScaler

# %%
# importing csv
df = pd.read_csv('out.csv')
df.head()
# Out:
#    Unnamed: 0    id symbol  num_market_pairs  max_supply  circulating_supply  \
# 0           0  1027    ETH              4536         0.0        1.182389e+08
# 1           1  1027    ETH              4536         0.0        1.182525e+08
# 2           2  1027    ETH              4539         0.0        1.182647e+08
# 3           3  1027    ETH              4532         0.0        1.182780e+08
# 4           4  1027    ETH              4537         0.0        1.182925e+08
#
#    total_supply  cmc_rank  tradable        price  ...  percent_change_24h  \
# 0  1.182389e+08         2         0  4544.425359  ...            1.184483
# 1  1.182525e+08         2         0  4710.833463  ...            3.621842
# 2  1.182647e+08         2         0  4798.612451  ...            2.157528
# 3  1.182780e+08         2         0  4738.157890  ...           -1.109926
# 4  1.182925e+08         2         0  4585.716122  ...           -3.218616
#
#    percent_change_7d  percent_change_30d  percent_change_60d    market_cap  \
# 0           3.746573           26.518131           28.706692  5.373281e+11
# 1          10.733688           32.309437           34.454509  5.570679e+11
# 2          10.984709           36.741072           37.382295  5.675063e+11
# 3           3.290245           36.808144           44.651201  5.604197e+11
# 4           0.420480           30.998017           39.737530  5.424560e+11
#
#    market_cap_dominance  fully_diluted_market_cap        date  difference  \
# 0               19.5812              5.373281e+11  11-06-2021     0.00000
# 1               19.5951              5.570679e+11  11-07-2021   166.40810
# 2               19.4133              5.675063e+11  11-08-2021    87.77899
# 3               19.3235              5.604197e+11  11-09-2021   -60.45456
# 4               19.4910              5.424560e+11  11-10-2021  -152.44177
#
#    %_difference
# 0       0.00000
# 1       0.00000
# 2      -0.47251
# 3      -1.68871
# 4       1.52159
#
# [5 rows x 23 columns]

# %%
model = KMeans(n_clusters=5, random_state=5)

# %%
symbol = df['symbol'].values
df.drop(['symbol', 'date', 'Unnamed: 0', 'id' ], axis=1,inplace=True)
df
# Out:
#        num_market_pairs    max_supply  circulating_supply  total_supply  \
# 0                  4536  0.000000e+00        1.182389e+08  1.182389e+08
# 1                  4536  0.000000e+00        1.182525e+08  1.182525e+08
# 2                  4539  0.000000e+00        1.182647e+08  1.182647e+08
# 3                  4532  0.000000e+00        1.182780e+08  1.182780e+08
# 4                  4537  0.000000e+00        1.182925e+08  1.182925e+08
# ...                 ...           ...                 ...           ...
# 33958                 3  1.067846e+11        4.474824e+10  4.474824e+10
# 33959                24  8.537500e+06        7.433782e+06  8.386162e+06
# 33960                13  1.000000e+09        4.328001e+07  1.000000e+09
# 33961                 2  1.000000e+15        5.829597e+14  5.829597e+14
# 33962                 8  0.000000e+00        7.209318e+09  1.000000e+10
#
#        cmc_rank  tradable         price    volume_24h  volume_change_24h  \
# 0             2         0  4.544425e+03  1.479250e+10            -0.0514
# 1             2         0  4.710833e+03  1.508883e+10             1.9094
# 2             2         0  4.798612e+03  1.868153e+10            24.4513
# 3             2         0  4.738158e+03  1.962432e+10             5.4274
# 4             2         0  4.585716e+03  2.318447e+10            19.1566
# ...         ...       ...           ...           ...                ...
# 33958       997         0  2.855404e-04  1.366582e+04            83.9787
# 33959       418         0  1.460950e+01  4.013171e+06             4.6704
# 33960       515         0  1.695637e+00  1.212702e+07           -43.0118
# 33961       688         0  6.036970e-08  4.367870e+05           -68.8979
# 33962       902         0  2.382820e-03  9.076169e+05            35.5871
#
#        percent_change_1h  percent_change_24h  percent_change_7d  \
# 0              -0.420293            1.184483           3.746573
# 1               0.403481            3.621842          10.733688
# 2               0.184804            2.157528          10.984709
# 3               0.431362           -1.109926           3.290245
# 4              -0.432665           -3.218616           0.420480
# ...                  ...                 ...                ...
# 33958          -0.863682           20.760185          31.257848
# 33959           0.087931           12.045613           5.241256
# 33960          -0.874228           10.354242         -35.009455
# 33961           0.172708           -4.575632         -37.207816
# 33962          -0.160888           26.842083          -9.612679
#
#        percent_change_30d  percent_change_60d    market_cap  \
# 0               26.518131           28.706692  5.373281e+11
# 1               32.309437           34.454509  5.570679e+11
# 2               36.741072           37.382295  5.675063e+11
# 3               36.808144           44.651201  5.604197e+11
# 4               30.998017           39.737530  5.424560e+11
# ...                   ...                 ...           ...
# 33958           47.472244          -30.100417  1.277743e+07
# 33959           23.281201           41.664058  1.086038e+08
# 33960          -45.123808          -45.123808  7.338717e+07
# 33961          -66.252713          782.894082  3.519311e+07
# 33962          -28.158059           -6.204229  1.717851e+07
#
#        market_cap_dominance  fully_diluted_market_cap  difference  \
# 0                   19.5812              5.373281e+11     0.00000
# 1                   19.5951              5.570679e+11   166.40810
# 2                   19.4133              5.675063e+11    87.77899
# 3                   19.3235              5.604197e+11   -60.45456
# 4                   19.4910              5.424560e+11  -152.44177
# ...                     ...                       ...         ...
# 33958                0.0006              3.049133e+07     0.00000
# 33959                0.0048              1.247286e+08     0.00000
# 33960                0.0000              1.695637e+09     0.00000
# 33961                0.0000              6.036970e+07     0.00000
# 33962                0.0008              2.382820e+07     0.00000
#
#        %_difference
# 0           0.00000
# 1           0.00000
# 2          -0.47251
# 3          -1.68871
# 4           1.52159
# ...             ...
# 33958       0.00000
# 33959       0.00000
# 33960       0.00000
# 33961       0.00000
# 33962       0.00000
#
# [33963 rows x 19 columns]

# %%
df_dummies= pd.get_dummies(df, drop_first=True)

# %%
df_dummies.dtypes
# Out:
# num_market_pairs              int64
# max_supply                  float64
# circulating_supply          float64
# total_supply                float64
# cmc_rank                      int64
# tradable                      int64
# price                       float64
# volume_24h                  float64
# volume_change_24h           float64
# percent_change_1h           float64
# percent_change_24h          float64
# percent_change_7d           float64
# percent_change_30d          float64
# percent_change_60d          float64
# market_cap                  float64
# market_cap_dominance        float64
# fully_diluted_market_cap    float64
# difference                  float64
# %_difference                float64
# dtype: object

# %%
model.fit(df_dummies)
# Out:
# KMeans(n_clusters=5, random_state=5)

# %%
predictions = model.predict(df_dummies)
print(predictions)
# Out:
# [0 0 0 ... 0 0 0]

# %%
df["class"] = model.labels_
df['name'] = symbol
df.head()
# Out:
#    num_market_pairs  max_supply  circulating_supply  total_supply  cmc_rank  \
# 0              4536         0.0        1.182389e+08  1.182389e+08         2
# 1              4536         0.0        1.182525e+08  1.182525e+08         2
# 2              4539         0.0        1.182647e+08  1.182647e+08         2
# 3              4532         0.0        1.182780e+08  1.182780e+08         2
# 4              4537         0.0        1.182925e+08  1.182925e+08         2
#
#    tradable        price    volume_24h  volume_change_24h  percent_change_1h  \
# 0         0  4544.425359  1.479250e+10            -0.0514          -0.420293
# 1         0  4710.833463  1.508883e+10             1.9094           0.403481
# 2         0  4798.612451  1.868153e+10            24.4513           0.184804
# 3         0  4738.157890  1.962432e+10             5.4274           0.431362
# 4         0  4585.716122  2.318447e+10            19.1566          -0.432665
#
#    ...  percent_change_7d  percent_change_30d  percent_change_60d  \
# 0  ...           3.746573           26.518131           28.706692
# 1  ...          10.733688           32.309437           34.454509
# 2  ...          10.984709           36.741072           37.382295
# 3  ...           3.290245           36.808144           44.651201
# 4  ...           0.420480           30.998017           39.737530
#
#      market_cap  market_cap_dominance  fully_diluted_market_cap  difference  \
# 0  5.373281e+11               19.5812              5.373281e+11     0.00000
# 1  5.570679e+11               19.5951              5.570679e+11   166.40810
# 2  5.675063e+11               19.4133              5.675063e+11    87.77899
# 3  5.604197e+11               19.3235              5.604197e+11   -60.45456
# 4  5.424560e+11               19.4910              5.424560e+11  -152.44177
#
#    %_difference  class  name
# 0       0.00000      0   ETH
# 1       0.00000      0   ETH
# 2      -0.47251      0   ETH
# 3      -1.68871      0   ETH
# 4       1.52159      0   ETH
#
# [5 rows x 21 columns]

# %%
df.dtypes
# Out:
# num_market_pairs              int64
# max_supply                  float64
# circulating_supply          float64
# total_supply                float64
# cmc_rank                      int64
# tradable                      int64
# price                       float64
# volume_24h                  float64
# volume_change_24h           float64
# percent_change_1h           float64
# percent_change_24h          float64
# percent_change_7d           float64
# percent_change_30d          float64
# percent_change_60d          float64
# market_cap                  float64
# market_cap_dominance        float64
# fully_diluted_market_cap    float64
# difference                  float64
# %_difference                float64
# class                         int32
# name                         object
# dtype: object

# %%
plt.scatter(x=df['%_difference'], y=df['market_cap'], c=df['class'])
plt.xlabel('% of Growth')
plt.ylabel('')
plt.show()
