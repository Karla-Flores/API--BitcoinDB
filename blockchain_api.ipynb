# %%
# This library does not brin much information about daily transactions

# %%
from tradingview_ta import TA_Handler, Interval, Exchange

# %%
tesla = TA_Handler(
    symbol="TSLA",
    screener="america",
    exchange="NASDAQ",
    interval=Interval.INTERVAL_1_DAY
)
print(tesla.get_analysis().summary)
# Example output: {"RECOMMENDATION": "BUY", "BUY": 8, "NEUTRAL": 6, "SELL": 3}
# Out:
# {'RECOMMENDATION': 'BUY', 'BUY': 15, 'SELL': 1, 'NEUTRAL': 10}

# %%
tesla = TA_Handler(
    symbol="RSRBTC",
    screener="crypto",
    exchange="BINANCE",
    interval=Interval.INTERVAL_1_MONTH
)
print(tesla.get_analysis().summary)
# Out:
# {'RECOMMENDATION': 'NEUTRAL', 'BUY': 5, 'SELL': 4, 'NEUTRAL': 6}

# %% [markdown]
# # https://www.blockchain.com/api

# %% [markdown]
# # 24 Hours Ticker

# %%
# Dependencies and Setp up
import json
import requests
import pandas as pd
import numpy as np
import datetime as dt

# %%
url = 'https://api.blockchain.com/v3/exchange/tickers'

# %%
# Json file
response = requests.get(url).json()

# %%
response
# Out:
# [{'symbol': 'XLM-EUR',
#   'price_24h': 0.29356,
#   'volume_24h': 106320.4442228,
#   'last_trade_price': 0.30075},
#  {'symbol': 'EFI-USDT',
#   'price_24h': 2.082,
#   'volume_24h': 27.97237127,
#   'last_trade_price': 2.082},
#  {'symbol': 'ALGO-BTC',
#   'price_24h': 3.15e-05,
#   'volume_24h': 5339.781796,
#   'last_trade_price': 3.3e-05},
#  {'symbol': 'XLM-BTC',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 5.51e-06},
#  {'symbol': 'USDC-GBP',
#   'price_24h': 0.7505,
#   'volume_24h': 76791.8214,
#   'last_trade_price': 0.7515},
#  {'symbol': 'CLOUT-USD',
#   'price_24h': 95.0,
#   'volume_24h': 886.90335857,
#   'last_trade_price': 98.79},
#  {'symbol': 'OGN-USDT',
#   'price_24h': 1.012,
#   'volume_24h': 0.0,
#   'last_trade_price': 1.012},
#  {'symbol': 'CEUR-USDT',
#   'price_24h': 1.11,
#   'volume_24h': 0.0,
#   'last_trade_price': 1.11},
#  {'symbol': 'STX-USDC',
#   'price_24h': 2.304,
#   'volume_24h': 27391.80612571,
#   'last_trade_price': 3.136},
#  {'symbol': 'EOS-USD',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.0},
#  {'symbol': 'BCH-USD',
#   'price_24h': 568.95,
#   'volume_24h': 226.82451988,
#   'last_trade_price': 574.03},
#  {'symbol': 'PAX-USD',
#   'price_24h': 0.9999,
#   'volume_24h': 2106.2184,
#   'last_trade_price': 1.0001},
#  {'symbol': 'DAI-EUR',
#   'price_24h': 0.8799,
#   'volume_24h': 40115.0,
#   'last_trade_price': 0.889},
#  {'symbol': 'USDT-GBP',
#   'price_24h': 0.751,
#   'volume_24h': 23985.556,
#   'last_trade_price': 0.7524},
#  {'symbol': 'LINK-USDT',
#   'price_24h': 25.884,
#   'volume_24h': 2.23651596,
#   'last_trade_price': 26.067},
#  {'symbol': 'STX-USD',
#   'price_24h': 2.304,
#   'volume_24h': 123994.3220456,
#   'last_trade_price': 3.078},
#  {'symbol': 'MATIC-USDT',
#   'price_24h': 1.86,
#   'volume_24h': 14.0,
#   'last_trade_price': 1.86},
#  {'symbol': 'WDGLD-USD',
#   'price_24h': 174.99,
#   'volume_24h': 602.86166653,
#   'last_trade_price': 173.64},
#  {'symbol': 'ETH-USD',
#   'price_24h': 4477.29,
#   'volume_24h': 6313.29543717,
#   'last_trade_price': 4673.33},
#  {'symbol': 'LEND-USD',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.4909},
#  {'symbol': 'XLM-PAX',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.06981},
#  {'symbol': 'XRP-EUR',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.22},
#  {'symbol': 'XLM-USD',
#   'price_24h': 0.33439,
#   'volume_24h': 420728.7196989,
#   'last_trade_price': 0.34208},
#  {'symbol': 'LINK-USDC',
#   'price_24h': 24.49,
#   'volume_24h': 426.89478214,
#   'last_trade_price': 25.551},
#  {'symbol': 'DGLD-BTC',
#   'price_24h': 0.003021,
#   'volume_24h': 23.0,
#   'last_trade_price': 0.003037},
#  {'symbol': 'BCH-EUR',
#   'price_24h': 491.24,
#   'volume_24h': 61.76942845,
#   'last_trade_price': 505.27},
#  {'symbol': 'BCH-BTC',
#   'price_24h': 0.009917,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.009917},
#  {'symbol': 'BTC-USD',
#   'price_24h': 57478.84,
#   'volume_24h': 510.92684877,
#   'last_trade_price': 56895.68},
#  {'symbol': 'CLOUT-BTC',
#   'price_24h': 0.001608,
#   'volume_24h': 265.39990837,
#   'last_trade_price': 0.001593},
#  {'symbol': 'BCH-ETH',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.582678},
#  {'symbol': 'ETH-TRY',
#   'price_24h': 23950.9,
#   'volume_24h': 0.0,
#   'last_trade_price': 23950.9},
#  {'symbol': 'BTC-TRY',
#   'price_24h': 390682.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 390682.0},
#  {'symbol': 'ALGO-USD',
#   'price_24h': 1.7839,
#   'volume_24h': 120873.839976,
#   'last_trade_price': 1.8616},
#  {'symbol': 'ETH-EUR',
#   'price_24h': 3905.27,
#   'volume_24h': 80.01341931,
#   'last_trade_price': 4160.0},
#  {'symbol': 'DOGE-USD',
#   'price_24h': 0.22201,
#   'volume_24h': 86989.7010928,
#   'last_trade_price': 0.20662},
#  {'symbol': 'STX-USDT',
#   'price_24h': 2.309,
#   'volume_24h': 88042.96169694,
#   'last_trade_price': 3.098},
#  {'symbol': 'XRP-USD',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.29},
#  {'symbol': 'XLM-ETH',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.00019195},
#  {'symbol': 'YFI-USD',
#   'price_24h': 29383.29,
#   'volume_24h': 0.00232611,
#   'last_trade_price': 29383.29},
#  {'symbol': 'BTC-PAX',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 6115.0},
#  {'symbol': 'WBTC-USDC',
#   'price_24h': 59758.13,
#   'volume_24h': 0.0,
#   'last_trade_price': 59758.13},
#  {'symbol': 'MKR-USDT',
#   'price_24h': 3122.56,
#   'volume_24h': 0.0,
#   'last_trade_price': 3122.56},
#  {'symbol': 'UNI-USDT',
#   'price_24h': 20.136,
#   'volume_24h': 0.0,
#   'last_trade_price': 20.13},
#  {'symbol': 'DOT-EUR',
#   'price_24h': 33.0,
#   'volume_24h': 703.93969957,
#   'last_trade_price': 34.5},
#  {'symbol': 'BCH-PAX',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 339.24},
#  {'symbol': 'DAI-USDC',
#   'price_24h': 0.9983,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.9983},
#  {'symbol': 'UNI-USD',
#   'price_24h': 21.249,
#   'volume_24h': 0.3,
#   'last_trade_price': 21.249},
#  {'symbol': 'ETH-BTC',
#   'price_24h': 0.078,
#   'volume_24h': 16.64933844,
#   'last_trade_price': 0.082144},
#  {'symbol': 'WDGLD-BTC',
#   'price_24h': 0.003067,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.003067},
#  {'symbol': 'USDC-EUR',
#   'price_24h': 0.883,
#   'volume_24h': 28279.59,
#   'last_trade_price': 0.883},
#  {'symbol': 'WBTC-USDT',
#   'price_24h': 59500.71,
#   'volume_24h': 0.0,
#   'last_trade_price': 59500.71},
#  {'symbol': 'MKR-USDC',
#   'price_24h': 3324.77,
#   'volume_24h': 2.29560756,
#   'last_trade_price': 3195.64},
#  {'symbol': 'LTC-USD',
#   'price_24h': 204.54,
#   'volume_24h': 1846.63436493,
#   'last_trade_price': 209.46},
#  {'symbol': 'LINK-USD',
#   'price_24h': 24.463,
#   'volume_24h': 2.7,
#   'last_trade_price': 25.652},
#  {'symbol': 'DOGE-USDT',
#   'price_24h': 0.21531,
#   'volume_24h': 4638.9847828,
#   'last_trade_price': 0.21493},
#  {'symbol': 'COMP-USD',
#   'price_24h': 285.79,
#   'volume_24h': 9.09131888,
#   'last_trade_price': 277.11},
#  {'symbol': 'CEUR-EUR',
#   'price_24h': 1.07,
#   'volume_24h': 0.0,
#   'last_trade_price': 1.07},
#  {'symbol': 'LTC-BTC',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.005827},
#  {'symbol': 'EFI-USD',
#   'price_24h': 2.64,
#   'volume_24h': 14.18560665,
#   'last_trade_price': 2.64},
#  {'symbol': 'EOS-USDT',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.0},
#  {'symbol': 'DAI-USDT',
#   'price_24h': 0.9998,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.9998},
#  {'symbol': 'BTC-GBP',
#   'price_24h': 43117.86,
#   'volume_24h': 13.5415515,
#   'last_trade_price': 42800.23},
#  {'symbol': 'USDC-USD',
#   'price_24h': 0.9999,
#   'volume_24h': 25112.4418,
#   'last_trade_price': 0.9999},
#  {'symbol': 'MKR-USD',
#   'price_24h': 3129.19,
#   'volume_24h': 5.70877947,
#   'last_trade_price': 3126.19},
#  {'symbol': 'LTC-TRY',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.0},
#  {'symbol': 'WBTC-USD',
#   'price_24h': 58041.19,
#   'volume_24h': 0.0,
#   'last_trade_price': 58041.19},
#  {'symbol': 'UNI-USDC',
#   'price_24h': 21.107,
#   'volume_24h': 0.0,
#   'last_trade_price': 21.107},
#  {'symbol': 'LTC-EUR',
#   'price_24h': 180.35,
#   'volume_24h': 545.67150055,
#   'last_trade_price': 184.81},
#  {'symbol': 'WDGLD-DGLD',
#   'price_24h': 0.99,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.99},
#  {'symbol': 'DOT-USD',
#   'price_24h': 35.63,
#   'volume_24h': 2207.95970705,
#   'last_trade_price': 37.8},
#  {'symbol': 'USDT-TRY',
#   'price_24h': 8.29,
#   'volume_24h': 0.0,
#   'last_trade_price': 8.29},
#  {'symbol': 'COMP-USDT',
#   'price_24h': 286.81,
#   'volume_24h': 0.0,
#   'last_trade_price': 286.81},
#  {'symbol': 'USDT-USD',
#   'price_24h': 1.001,
#   'volume_24h': 672515.5961,
#   'last_trade_price': 1.0009},
#  {'symbol': 'LEND-USDT',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.4854},
#  {'symbol': 'ETH-GBP',
#   'price_24h': 3303.72,
#   'volume_24h': 77.13997294,
#   'last_trade_price': 3517.99},
#  {'symbol': 'OGN-USD',
#   'price_24h': 0.98,
#   'volume_24h': 157.718313,
#   'last_trade_price': 0.98},
#  {'symbol': 'AAVE-USDT',
#   'price_24h': 256.88,
#   'volume_24h': 46.12710388,
#   'last_trade_price': 264.23},
#  {'symbol': 'ETH-PAX',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 219.41},
#  {'symbol': 'USDC-USDT',
#   'price_24h': 0.9991,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.9991},
#  {'symbol': 'BCH-USDT',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 358.46},
#  {'symbol': 'ALGO-USDT',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.3614},
#  {'symbol': 'SUSHI-USDC',
#   'price_24h': 7.89,
#   'volume_24h': 0.0,
#   'last_trade_price': 7.89},
#  {'symbol': 'ENJ-USD',
#   'price_24h': 3.8931,
#   'volume_24h': 1616.012401,
#   'last_trade_price': 3.46},
#  {'symbol': 'LTC-USDT',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 73.28},
#  {'symbol': 'DAI-GBP',
#   'price_24h': 0.7491,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.7491},
#  {'symbol': 'EFI-USDC',
#   'price_24h': 1.989,
#   'volume_24h': 0.0,
#   'last_trade_price': 1.989},
#  {'symbol': 'BTC-EUR',
#   'price_24h': 50849.69,
#   'volume_24h': 14.54888253,
#   'last_trade_price': 50415.11},
#  {'symbol': 'USDT-EUR',
#   'price_24h': 0.8831,
#   'volume_24h': 286409.2102,
#   'last_trade_price': 0.8832},
#  {'symbol': 'DGLD-USD',
#   'price_24h': 175.64,
#   'volume_24h': 285.0,
#   'last_trade_price': 173.45},
#  {'symbol': 'EOS-USDC',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.0},
#  {'symbol': 'YFI-USDT',
#   'price_24h': 29991.97,
#   'volume_24h': 0.0,
#   'last_trade_price': 30006.99},
#  {'symbol': 'SUSHI-USDT',
#   'price_24h': 7.847,
#   'volume_24h': 0.285,
#   'last_trade_price': 7.847},
#  {'symbol': 'COMP-USDC',
#   'price_24h': 247.48,
#   'volume_24h': 0.0,
#   'last_trade_price': 247.48},
#  {'symbol': 'ENJ-USDT',
#   'price_24h': 3.5827,
#   'volume_24h': 133.912049,
#   'last_trade_price': 3.5},
#  {'symbol': 'LTC-PAX',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 74.03},
#  {'symbol': 'MATIC-USDC',
#   'price_24h': 1.681,
#   'volume_24h': 0.0,
#   'last_trade_price': 1.681},
#  {'symbol': 'PAX-EUR',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.9444},
#  {'symbol': 'AAVE-USD',
#   'price_24h': 257.46,
#   'volume_24h': 202.53832721,
#   'last_trade_price': 264.42},
#  {'symbol': 'BTC-USDT',
#   'price_24h': 57020.07,
#   'volume_24h': 17.51338884,
#   'last_trade_price': 57012.3},
#  {'symbol': 'DOT-GBP',
#   'price_24h': 28.1,
#   'volume_24h': 143.20043674,
#   'last_trade_price': 27.62},
#  {'symbol': 'ETH-USDT',
#   'price_24h': 4451.42,
#   'volume_24h': 188.69659949,
#   'last_trade_price': 4686.42},
#  {'symbol': 'MATIC-USD',
#   'price_24h': 1.728,
#   'volume_24h': 4170.16933076,
#   'last_trade_price': 1.873},
#  {'symbol': 'SUSHI-USD',
#   'price_24h': 7.392,
#   'volume_24h': 738.15830794,
#   'last_trade_price': 8.043},
#  {'symbol': 'DAI-USD',
#   'price_24h': 1.0011,
#   'volume_24h': 559.0,
#   'last_trade_price': 0.9999}]

# %%
type(response)
# Out:
# list

# %%
len(response)
# Out:
# 104

# %%
today= dt.datetime.today().strftime("%m-%d-%Y")
today
# Out:
# '11-30-2021'

# %%
df= pd.DataFrame (response)
df['difference'] = ''
df['date']=today
df
# Out:
#         symbol    price_24h     volume_24h  last_trade_price difference  \
# 0      XLM-EUR     0.293560  106320.444223          0.300750
# 1     EFI-USDT     2.082000      27.972371          2.082000
# 2     ALGO-BTC     0.000031    5339.781796          0.000033
# 3      XLM-BTC     0.000000       0.000000          0.000006
# 4     USDC-GBP     0.750500   76791.821400          0.751500
# ..         ...          ...            ...               ...        ...
# 99     DOT-GBP    28.100000     143.200437         27.620000
# 100   ETH-USDT  4451.420000     188.696599       4686.420000
# 101  MATIC-USD     1.728000    4170.169331          1.873000
# 102  SUSHI-USD     7.392000     738.158308          8.043000
# 103    DAI-USD     1.001100     559.000000          0.999900
#
#            date
# 0    11-30-2021
# 1    11-30-2021
# 2    11-30-2021
# 3    11-30-2021
# 4    11-30-2021
# ..          ...
# 99   11-30-2021
# 100  11-30-2021
# 101  11-30-2021
# 102  11-30-2021
# 103  11-30-2021
#
# [104 rows x 6 columns]

# %%
df.to_csv(f'blockchain_{today}.csv', sep=',', index=False)
