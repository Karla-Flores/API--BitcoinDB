# %%
# This library does not brin much information about daily transactions

# %%
from tradingview_ta import TA_Handler, Interval, Exchange

# %%
tesla = TA_Handler(
    symbol="TSLA",
    screener="america",
    exchange="NASDAQ",
    interval=Interval.INTERVAL_1_DAY
)
print(tesla.get_analysis().summary)
# Example output: {"RECOMMENDATION": "BUY", "BUY": 8, "NEUTRAL": 6, "SELL": 3}
# Out:
# {'RECOMMENDATION': 'NEUTRAL', 'BUY': 9, 'SELL': 10, 'NEUTRAL': 7}

# %%
tesla = TA_Handler(
    symbol="RSRBTC",
    screener="crypto",
    exchange="BINANCE",
    interval=Interval.INTERVAL_1_MONTH
)
print(tesla.get_analysis().summary)
# Out:
# {'RECOMMENDATION': 'STRONG_SELL', 'BUY': 0, 'SELL': 9, 'NEUTRAL': 6}

# %% [markdown]
# # https://www.blockchain.com/api

# %% [markdown]
# # 24 Hours Ticker

# %%
# Dependencies and Setp up
import json
import requests
import pandas as pd
import numpy as np
import datetime as dt

# %%
url = 'https://api.blockchain.com/v3/exchange/tickers'

# %%
# Json file
response = requests.get(url).json()

# %%
response
# Out:
# [{'symbol': 'XLM-EUR',
#   'price_24h': 0.241,
#   'volume_24h': 4396.1827468,
#   'last_trade_price': 0.22311},
#  {'symbol': 'EFI-USDT',
#   'price_24h': 1.138,
#   'volume_24h': 0.0,
#   'last_trade_price': 1.138},
#  {'symbol': 'ALGO-BTC',
#   'price_24h': 2.832e-05,
#   'volume_24h': 393.714294,
#   'last_trade_price': 2.895e-05},
#  {'symbol': 'XLM-BTC',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 5.51e-06},
#  {'symbol': 'USDC-GBP',
#   'price_24h': 0.7538,
#   'volume_24h': 692.2121,
#   'last_trade_price': 0.7541},
#  {'symbol': 'OGN-USDT',
#   'price_24h': 0.6789,
#   'volume_24h': 31.190835,
#   'last_trade_price': 0.6789},
#  {'symbol': 'CLOUT-USD',
#   'price_24h': 143.0,
#   'volume_24h': 6482.76873951,
#   'last_trade_price': 133.0},
#  {'symbol': 'STX-USDC',
#   'price_24h': 1.912,
#   'volume_24h': 6735.32058385,
#   'last_trade_price': 2.281},
#  {'symbol': 'CEUR-USDT',
#   'price_24h': 1.14,
#   'volume_24h': 23.699,
#   'last_trade_price': 1.13},
#  {'symbol': 'EOS-USD',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.0},
#  {'symbol': 'BCH-USD',
#   'price_24h': 435.63,
#   'volume_24h': 119.86502214,
#   'last_trade_price': 449.0},
#  {'symbol': 'PAX-USD',
#   'price_24h': 1.0001,
#   'volume_24h': 0.0,
#   'last_trade_price': 1.0001},
#  {'symbol': 'DAI-EUR',
#   'price_24h': 0.8893,
#   'volume_24h': 30000.0,
#   'last_trade_price': 0.8905},
#  {'symbol': 'USDT-GBP',
#   'price_24h': 0.7545,
#   'volume_24h': 67376.5661,
#   'last_trade_price': 0.7548},
#  {'symbol': 'LINK-USDT',
#   'price_24h': 18.033,
#   'volume_24h': 11.9371,
#   'last_trade_price': 19.53},
#  {'symbol': 'STX-USD',
#   'price_24h': 1.937,
#   'volume_24h': 10858.49577195,
#   'last_trade_price': 2.221},
#  {'symbol': 'MATIC-USDT',
#   'price_24h': 1.998,
#   'volume_24h': 106.992,
#   'last_trade_price': 2.152},
#  {'symbol': 'WDGLD-USD',
#   'price_24h': 172.67,
#   'volume_24h': 271.10574332,
#   'last_trade_price': 172.32},
#  {'symbol': 'ETH-USD',
#   'price_24h': 3821.16,
#   'volume_24h': 7205.07598248,
#   'last_trade_price': 4037.79},
#  {'symbol': 'LEND-USD',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.4909},
#  {'symbol': 'XLM-PAX',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.06981},
#  {'symbol': 'XRP-EUR',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.22},
#  {'symbol': 'XLM-USD',
#   'price_24h': 0.2651,
#   'volume_24h': 2130490.5582386,
#   'last_trade_price': 0.27256},
#  {'symbol': 'LINK-USDC',
#   'price_24h': 18.08,
#   'volume_24h': 606.1017877,
#   'last_trade_price': 19.964},
#  {'symbol': 'DGLD-BTC',
#   'price_24h': 0.003671,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.003671},
#  {'symbol': 'BCH-EUR',
#   'price_24h': 388.84,
#   'volume_24h': 21.4774403,
#   'last_trade_price': 391.07},
#  {'symbol': 'BCH-BTC',
#   'price_24h': 0.009015,
#   'volume_24h': 9.371,
#   'last_trade_price': 0.009025},
#  {'symbol': 'BTC-USD',
#   'price_24h': 47971.76,
#   'volume_24h': 502.88298862,
#   'last_trade_price': 49065.78},
#  {'symbol': 'CLOUT-BTC',
#   'price_24h': 0.002981,
#   'volume_24h': 286.37531936,
#   'last_trade_price': 0.002764},
#  {'symbol': 'BCH-ETH',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.582678},
#  {'symbol': 'ETH-TRY',
#   'price_24h': 23950.9,
#   'volume_24h': 0.0,
#   'last_trade_price': 23950.9},
#  {'symbol': 'BTC-TRY',
#   'price_24h': 390682.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 390682.0},
#  {'symbol': 'ALGO-USD',
#   'price_24h': 1.3776,
#   'volume_24h': 10503.529471,
#   'last_trade_price': 1.4346},
#  {'symbol': 'ETH-EUR',
#   'price_24h': 3429.39,
#   'volume_24h': 81.78107218,
#   'last_trade_price': 3574.18},
#  {'symbol': 'DOGE-USD',
#   'price_24h': 0.18199,
#   'volume_24h': 205997.0062837,
#   'last_trade_price': 0.1807},
#  {'symbol': 'STX-USDT',
#   'price_24h': 1.873,
#   'volume_24h': 9211.59068526,
#   'last_trade_price': 2.28},
#  {'symbol': 'XRP-USD',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.29},
#  {'symbol': 'XLM-ETH',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.00019195},
#  {'symbol': 'YFI-USD',
#   'price_24h': 20178.22,
#   'volume_24h': 0.0,
#   'last_trade_price': 20178.22},
#  {'symbol': 'BTC-PAX',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 6115.0},
#  {'symbol': 'WBTC-USDC',
#   'price_24h': 49660.9,
#   'volume_24h': 0.00100491,
#   'last_trade_price': 49660.9},
#  {'symbol': 'MKR-USDT',
#   'price_24h': 2256.56,
#   'volume_24h': 0.0,
#   'last_trade_price': 2254.93},
#  {'symbol': 'UNI-USDT',
#   'price_24h': 14.998,
#   'volume_24h': 164.413,
#   'last_trade_price': 15.21},
#  {'symbol': 'DOT-EUR',
#   'price_24h': 23.42,
#   'volume_24h': 1700.81772886,
#   'last_trade_price': 24.31},
#  {'symbol': 'BCH-PAX',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 339.24},
#  {'symbol': 'DAI-USDC',
#   'price_24h': 0.9993,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.9991},
#  {'symbol': 'UNI-USD',
#   'price_24h': 15.144,
#   'volume_24h': 682.67956808,
#   'last_trade_price': 15.455},
#  {'symbol': 'ETH-BTC',
#   'price_24h': 0.079702,
#   'volume_24h': 25.93815537,
#   'last_trade_price': 0.082381},
#  {'symbol': 'WDGLD-BTC',
#   'price_24h': 0.003545,
#   'volume_24h': 63.0,
#   'last_trade_price': 0.00354},
#  {'symbol': 'USDC-EUR',
#   'price_24h': 0.8881,
#   'volume_24h': 156.5055,
#   'last_trade_price': 0.8881},
#  {'symbol': 'WBTC-USDT',
#   'price_24h': 51434.7,
#   'volume_24h': 0.0,
#   'last_trade_price': 51434.7},
#  {'symbol': 'MKR-USDC',
#   'price_24h': 2124.4,
#   'volume_24h': 0.0,
#   'last_trade_price': 2124.4},
#  {'symbol': 'LTC-USD',
#   'price_24h': 149.8,
#   'volume_24h': 70.79587151,
#   'last_trade_price': 153.83},
#  {'symbol': 'LINK-USD',
#   'price_24h': 17.924,
#   'volume_24h': 92.12061523,
#   'last_trade_price': 18.95},
#  {'symbol': 'DOGE-USDT',
#   'price_24h': 0.17264,
#   'volume_24h': 17410.3440212,
#   'last_trade_price': 0.17986},
#  {'symbol': 'COMP-USD',
#   'price_24h': 177.33,
#   'volume_24h': 48.32007411,
#   'last_trade_price': 198.17},
#  {'symbol': 'CEUR-EUR',
#   'price_24h': 1.01,
#   'volume_24h': 28.713,
#   'last_trade_price': 1.02},
#  {'symbol': 'LTC-BTC',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.005827},
#  {'symbol': 'EFI-USD',
#   'price_24h': 1.1,
#   'volume_24h': 1.21275309,
#   'last_trade_price': 1.002},
#  {'symbol': 'EOS-USDT',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.0},
#  {'symbol': 'DAI-USDT',
#   'price_24h': 0.9998,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.9998},
#  {'symbol': 'BTC-GBP',
#   'price_24h': 36384.92,
#   'volume_24h': 10.58829019,
#   'last_trade_price': 36971.03},
#  {'symbol': 'USDC-USD',
#   'price_24h': 1.0001,
#   'volume_24h': 191408.2117,
#   'last_trade_price': 1.0004},
#  {'symbol': 'MKR-USD',
#   'price_24h': 2234.87,
#   'volume_24h': 0.0,
#   'last_trade_price': 2233.63},
#  {'symbol': 'LTC-TRY',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.0},
#  {'symbol': 'WBTC-USD',
#   'price_24h': 50663.66,
#   'volume_24h': 0.0,
#   'last_trade_price': 50663.66},
#  {'symbol': 'UNI-USDC',
#   'price_24h': 16.991,
#   'volume_24h': 0.0,
#   'last_trade_price': 16.991},
#  {'symbol': 'LTC-EUR',
#   'price_24h': 134.73,
#   'volume_24h': 275.35485498,
#   'last_trade_price': 136.19},
#  {'symbol': 'WDGLD-DGLD',
#   'price_24h': 1.01,
#   'volume_24h': 0.0,
#   'last_trade_price': 1.01},
#  {'symbol': 'DOT-USD',
#   'price_24h': 25.1,
#   'volume_24h': 547.85786432,
#   'last_trade_price': 29.0},
#  {'symbol': 'USDT-TRY',
#   'price_24h': 8.29,
#   'volume_24h': 0.0,
#   'last_trade_price': 8.29},
#  {'symbol': 'USDT-USD',
#   'price_24h': 1.0005,
#   'volume_24h': 330281.7663,
#   'last_trade_price': 1.0006},
#  {'symbol': 'COMP-USDT',
#   'price_24h': 187.36,
#   'volume_24h': 12.42863333,
#   'last_trade_price': 187.36},
#  {'symbol': 'LEND-USDT',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.4854},
#  {'symbol': 'ETH-GBP',
#   'price_24h': 2935.53,
#   'volume_24h': 144.10468361,
#   'last_trade_price': 3052.86},
#  {'symbol': 'OGN-USD',
#   'price_24h': 0.5951,
#   'volume_24h': 9.0,
#   'last_trade_price': 0.6003},
#  {'symbol': 'AAVE-USDT',
#   'price_24h': 167.38,
#   'volume_24h': 0.0,
#   'last_trade_price': 168.26},
#  {'symbol': 'ETH-PAX',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 219.41},
#  {'symbol': 'USDC-USDT',
#   'price_24h': 0.9998,
#   'volume_24h': 1265.0,
#   'last_trade_price': 0.9998},
#  {'symbol': 'BCH-USDT',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 358.46},
#  {'symbol': 'ALGO-USDT',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.3614},
#  {'symbol': 'SUSHI-USDC',
#   'price_24h': 5.762,
#   'volume_24h': 0.0,
#   'last_trade_price': 5.879},
#  {'symbol': 'ENJ-USD',
#   'price_24h': 2.5038,
#   'volume_24h': 200.0,
#   'last_trade_price': 2.5038},
#  {'symbol': 'LTC-USDT',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 73.28},
#  {'symbol': 'DAI-GBP',
#   'price_24h': 0.754,
#   'volume_24h': 4067.4,
#   'last_trade_price': 0.754},
#  {'symbol': 'BTC-EUR',
#   'price_24h': 42816.02,
#   'volume_24h': 13.28782418,
#   'last_trade_price': 43409.77},
#  {'symbol': 'EFI-USDC',
#   'price_24h': 1.097,
#   'volume_24h': 0.0,
#   'last_trade_price': 1.097},
#  {'symbol': 'USDT-EUR',
#   'price_24h': 0.8885,
#   'volume_24h': 178901.2146,
#   'last_trade_price': 0.8858},
#  {'symbol': 'DGLD-USD',
#   'price_24h': 172.92,
#   'volume_24h': 180.0,
#   'last_trade_price': 171.99},
#  {'symbol': 'EOS-USDC',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.0},
#  {'symbol': 'YFI-USDT',
#   'price_24h': 19934.87,
#   'volume_24h': 0.0,
#   'last_trade_price': 19934.87},
#  {'symbol': 'SUSHI-USDT',
#   'price_24h': 5.947,
#   'volume_24h': 28.56863165,
#   'last_trade_price': 5.76},
#  {'symbol': 'COMP-USDC',
#   'price_24h': 171.94,
#   'volume_24h': 0.0,
#   'last_trade_price': 171.94},
#  {'symbol': 'ENJ-USDT',
#   'price_24h': 2.4845,
#   'volume_24h': 147.548383,
#   'last_trade_price': 2.5},
#  {'symbol': 'LTC-PAX',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 74.03},
#  {'symbol': 'MATIC-USDC',
#   'price_24h': 2.435,
#   'volume_24h': 0.0,
#   'last_trade_price': 2.435},
#  {'symbol': 'PAX-EUR',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.9444},
#  {'symbol': 'AAVE-USD',
#   'price_24h': 161.5,
#   'volume_24h': 458.10073135,
#   'last_trade_price': 170.26},
#  {'symbol': 'DOT-GBP',
#   'price_24h': 19.0,
#   'volume_24h': 109.35855874,
#   'last_trade_price': 18.02},
#  {'symbol': 'BTC-USDT',
#   'price_24h': 47981.97,
#   'volume_24h': 29.90217078,
#   'last_trade_price': 48874.89},
#  {'symbol': 'ETH-USDT',
#   'price_24h': 3821.53,
#   'volume_24h': 1527.80892507,
#   'last_trade_price': 4037.16},
#  {'symbol': 'MATIC-USD',
#   'price_24h': 1.91,
#   'volume_24h': 3211.75903958,
#   'last_trade_price': 2.164},
#  {'symbol': 'SUSHI-USD',
#   'price_24h': 5.934,
#   'volume_24h': 148.3583891,
#   'last_trade_price': 5.78},
#  {'symbol': 'DAI-USD',
#   'price_24h': 1.0002,
#   'volume_24h': 314.783,
#   'last_trade_price': 1.0}]

# %%
type(response)
# Out:
# list

# %%
len(response)
# Out:
# 104

# %%
today= dt.datetime.today().strftime("%m-%d-%Y")
today
# Out:
# '12-15-2021'

# %%
df= pd.DataFrame (response)
df['difference'] = ''
df['date']=today
df
# Out:
#         symbol     price_24h   volume_24h  last_trade_price difference  \
# 0      XLM-EUR      0.241000  4396.182747          0.223110
# 1     EFI-USDT      1.138000     0.000000          1.138000
# 2     ALGO-BTC      0.000028   393.714294          0.000029
# 3      XLM-BTC      0.000000     0.000000          0.000006
# 4     USDC-GBP      0.753800   692.212100          0.754100
# ..         ...           ...          ...               ...        ...
# 99    BTC-USDT  47981.970000    29.902171      48874.890000
# 100   ETH-USDT   3821.530000  1527.808925       4037.160000
# 101  MATIC-USD      1.910000  3211.759040          2.164000
# 102  SUSHI-USD      5.934000   148.358389          5.780000
# 103    DAI-USD      1.000200   314.783000          1.000000
#
#            date
# 0    12-15-2021
# 1    12-15-2021
# 2    12-15-2021
# 3    12-15-2021
# 4    12-15-2021
# ..          ...
# 99   12-15-2021
# 100  12-15-2021
# 101  12-15-2021
# 102  12-15-2021
# 103  12-15-2021
#
# [104 rows x 6 columns]

# %%
df.to_csv(f'blockchain_{today}.csv', sep=',', index=False)
