# %%
# This library does not brin much information about daily transactions

# %%
from tradingview_ta import TA_Handler, Interval, Exchange

# %%
tesla = TA_Handler(
    symbol="TSLA",
    screener="america",
    exchange="NASDAQ",
    interval=Interval.INTERVAL_1_DAY
)
print(tesla.get_analysis().summary)
# Example output: {"RECOMMENDATION": "BUY", "BUY": 8, "NEUTRAL": 6, "SELL": 3}
# Out:
# {'RECOMMENDATION': 'BUY', 'BUY': 14, 'SELL': 2, 'NEUTRAL': 10}

# %%
tesla = TA_Handler(
    symbol="RSRBTC",
    screener="crypto",
    exchange="BINANCE",
    interval=Interval.INTERVAL_1_MONTH
)
print(tesla.get_analysis().summary)
# Out:
# {'RECOMMENDATION': 'STRONG_SELL', 'BUY': 0, 'SELL': 9, 'NEUTRAL': 6}

# %% [markdown]
# # https://www.blockchain.com/api

# %% [markdown]
# # 24 Hours Ticker

# %%
# Dependencies and Setp up
import json
import requests
import pandas as pd
import numpy as np
import datetime as dt

# %%
url = 'https://api.blockchain.com/v3/exchange/tickers'

# %%
# Json file
response = requests.get(url).json()

# %%
response
# Out:
# [{'symbol': 'XLM-EUR',
#   'price_24h': 0.23821,
#   'volume_24h': 106551.4587578,
#   'last_trade_price': 0.23283},
#  {'symbol': 'EFI-USDT',
#   'price_24h': 1.091,
#   'volume_24h': 0.0,
#   'last_trade_price': 1.091},
#  {'symbol': 'ALGO-BTC',
#   'price_24h': 3.568e-05,
#   'volume_24h': 1627.952789,
#   'last_trade_price': 3.6e-05},
#  {'symbol': 'XLM-BTC',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 5.51e-06},
#  {'symbol': 'USDC-GBP',
#   'price_24h': 0.7453,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.7453},
#  {'symbol': 'OGN-USDT',
#   'price_24h': 0.6806,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.6806},
#  {'symbol': 'CLOUT-USD',
#   'price_24h': 97.76,
#   'volume_24h': 3201.83075088,
#   'last_trade_price': 95.24},
#  {'symbol': 'STX-USDC',
#   'price_24h': 2.155,
#   'volume_24h': 1876.57129094,
#   'last_trade_price': 2.132},
#  {'symbol': 'CEUR-USDT',
#   'price_24h': 1.15,
#   'volume_24h': 0.0,
#   'last_trade_price': 1.15},
#  {'symbol': 'EOS-USD',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.0},
#  {'symbol': 'BCH-USD',
#   'price_24h': 430.26,
#   'volume_24h': 98.6468906,
#   'last_trade_price': 434.73},
#  {'symbol': 'PAX-USD',
#   'price_24h': 1.0001,
#   'volume_24h': 0.0,
#   'last_trade_price': 1.0001},
#  {'symbol': 'DAI-EUR',
#   'price_24h': 0.8792,
#   'volume_24h': 10000.0,
#   'last_trade_price': 0.8792},
#  {'symbol': 'USDT-GBP',
#   'price_24h': 0.7409,
#   'volume_24h': 10651.8738,
#   'last_trade_price': 0.7393},
#  {'symbol': 'LINK-USDT',
#   'price_24h': 21.017,
#   'volume_24h': 0.0,
#   'last_trade_price': 21.525},
#  {'symbol': 'STX-USD',
#   'price_24h': 2.242,
#   'volume_24h': 5920.18547799,
#   'last_trade_price': 2.242},
#  {'symbol': 'MATIC-USDT',
#   'price_24h': 2.515,
#   'volume_24h': 27.75153848,
#   'last_trade_price': 2.455},
#  {'symbol': 'WDGLD-USD',
#   'price_24h': 177.21,
#   'volume_24h': 703.15333327,
#   'last_trade_price': 178.94},
#  {'symbol': 'ETH-USD',
#   'price_24h': 3729.85,
#   'volume_24h': 6413.87852884,
#   'last_trade_price': 3731.86},
#  {'symbol': 'LEND-USD',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.4909},
#  {'symbol': 'XLM-PAX',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.06981},
#  {'symbol': 'XRP-EUR',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.22},
#  {'symbol': 'XLM-USD',
#   'price_24h': 0.26949,
#   'volume_24h': 215748.4285307,
#   'last_trade_price': 0.26986},
#  {'symbol': 'LINK-USDC',
#   'price_24h': 19.766,
#   'volume_24h': 100.26241108,
#   'last_trade_price': 19.147},
#  {'symbol': 'DGLD-BTC',
#   'price_24h': 0.003769,
#   'volume_24h': 395.89356032,
#   'last_trade_price': 0.00382},
#  {'symbol': 'BCH-EUR',
#   'price_24h': 376.87,
#   'volume_24h': 29.6035085,
#   'last_trade_price': 377.96},
#  {'symbol': 'BCH-BTC',
#   'price_24h': 0.009048,
#   'volume_24h': 0.4908841,
#   'last_trade_price': 0.0093},
#  {'symbol': 'BTC-USD',
#   'price_24h': 47164.14,
#   'volume_24h': 476.03471166,
#   'last_trade_price': 46872.52},
#  {'symbol': 'CLOUT-BTC',
#   'price_24h': 0.002064,
#   'volume_24h': 28.20409017,
#   'last_trade_price': 0.00225},
#  {'symbol': 'BCH-ETH',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.582678},
#  {'symbol': 'ETH-TRY',
#   'price_24h': 23950.9,
#   'volume_24h': 0.0,
#   'last_trade_price': 23950.9},
#  {'symbol': 'BTC-TRY',
#   'price_24h': 390682.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 390682.0},
#  {'symbol': 'ALGO-USD',
#   'price_24h': 1.7535,
#   'volume_24h': 4935.439559,
#   'last_trade_price': 1.6789},
#  {'symbol': 'ETH-EUR',
#   'price_24h': 3297.69,
#   'volume_24h': 102.47272786,
#   'last_trade_price': 3283.72},
#  {'symbol': 'DOGE-USD',
#   'price_24h': 0.17187,
#   'volume_24h': 134564.4122146,
#   'last_trade_price': 0.16734},
#  {'symbol': 'STX-USDT',
#   'price_24h': 2.251,
#   'volume_24h': 4151.17137567,
#   'last_trade_price': 2.129},
#  {'symbol': 'XRP-USD',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.29},
#  {'symbol': 'XLM-ETH',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.00019195},
#  {'symbol': 'YFI-USD',
#   'price_24h': 31068.0,
#   'volume_24h': 0.00496531,
#   'last_trade_price': 32339.67},
#  {'symbol': 'BTC-PAX',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 6115.0},
#  {'symbol': 'WBTC-USDC',
#   'price_24h': 49995.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 49995.0},
#  {'symbol': 'MKR-USDT',
#   'price_24h': 2315.65,
#   'volume_24h': 0.0,
#   'last_trade_price': 2315.65},
#  {'symbol': 'NEAR-USD',
#   'price_24h': 15.5525,
#   'volume_24h': 716.78970502,
#   'last_trade_price': 14.5591},
#  {'symbol': 'UNI-USDT',
#   'price_24h': 17.022,
#   'volume_24h': 0.0,
#   'last_trade_price': 17.022},
#  {'symbol': 'DOT-EUR',
#   'price_24h': 24.77,
#   'volume_24h': 257.2549117,
#   'last_trade_price': 24.02},
#  {'symbol': 'BCH-PAX',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 339.24},
#  {'symbol': 'DAI-USDC',
#   'price_24h': 1.0002,
#   'volume_24h': 18.4436,
#   'last_trade_price': 0.9999},
#  {'symbol': 'UNI-USD',
#   'price_24h': 18.168,
#   'volume_24h': 0.3,
#   'last_trade_price': 18.168},
#  {'symbol': 'ETH-BTC',
#   'price_24h': 0.078628,
#   'volume_24h': 1.34320807,
#   'last_trade_price': 0.079668},
#  {'symbol': 'WDGLD-BTC',
#   'price_24h': 0.003724,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.003724},
#  {'symbol': 'USDC-EUR',
#   'price_24h': 0.8724,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.8724},
#  {'symbol': 'WBTC-USDT',
#   'price_24h': 46978.49,
#   'volume_24h': 0.0,
#   'last_trade_price': 46978.49},
#  {'symbol': 'MKR-USDC',
#   'price_24h': 2482.17,
#   'volume_24h': 0.0,
#   'last_trade_price': 2482.17},
#  {'symbol': 'LTC-USD',
#   'price_24h': 148.08,
#   'volume_24h': 46.05520792,
#   'last_trade_price': 148.03},
#  {'symbol': 'LINK-USD',
#   'price_24h': 19.948,
#   'volume_24h': 0.0,
#   'last_trade_price': 19.948},
#  {'symbol': 'DOGE-USDT',
#   'price_24h': 0.17405,
#   'volume_24h': 559.5233562,
#   'last_trade_price': 0.17279},
#  {'symbol': 'COMP-USD',
#   'price_24h': 207.58,
#   'volume_24h': 24.99999999,
#   'last_trade_price': 202.46},
#  {'symbol': 'CEUR-EUR',
#   'price_24h': 0.98,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.98},
#  {'symbol': 'LTC-BTC',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.005827},
#  {'symbol': 'EFI-USD',
#   'price_24h': 1.069,
#   'volume_24h': 0.0,
#   'last_trade_price': 1.069},
#  {'symbol': 'EOS-USDT',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.0},
#  {'symbol': 'DAI-USDT',
#   'price_24h': 1.0349,
#   'volume_24h': 0.0,
#   'last_trade_price': 1.0599},
#  {'symbol': 'BTC-GBP',
#   'price_24h': 34976.95,
#   'volume_24h': 15.61233564,
#   'last_trade_price': 34367.7},
#  {'symbol': 'USDC-USD',
#   'price_24h': 1.0001,
#   'volume_24h': 634.6156,
#   'last_trade_price': 0.9999},
#  {'symbol': 'MKR-USD',
#   'price_24h': 2430.98,
#   'volume_24h': 0.0337,
#   'last_trade_price': 2430.98},
#  {'symbol': 'LTC-TRY',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.0},
#  {'symbol': 'WBTC-USD',
#   'price_24h': 47903.32,
#   'volume_24h': 7.569e-05,
#   'last_trade_price': 47903.32},
#  {'symbol': 'UNI-USDC',
#   'price_24h': 15.756,
#   'volume_24h': 0.0,
#   'last_trade_price': 15.756},
#  {'symbol': 'LTC-EUR',
#   'price_24h': 131.11,
#   'volume_24h': 362.29709796,
#   'last_trade_price': 130.05},
#  {'symbol': 'WDGLD-DGLD',
#   'price_24h': 1.01,
#   'volume_24h': 0.0,
#   'last_trade_price': 1.01},
#  {'symbol': 'DOT-USD',
#   'price_24h': 28.0,
#   'volume_24h': 111.5230329,
#   'last_trade_price': 26.78},
#  {'symbol': 'USDT-TRY',
#   'price_24h': 8.29,
#   'volume_24h': 0.0,
#   'last_trade_price': 8.29},
#  {'symbol': 'USDT-USD',
#   'price_24h': 1.0002,
#   'volume_24h': 232.3668,
#   'last_trade_price': 1.0001},
#  {'symbol': 'COMP-USDT',
#   'price_24h': 207.54,
#   'volume_24h': 25.018,
#   'last_trade_price': 197.76},
#  {'symbol': 'LEND-USDT',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.4854},
#  {'symbol': 'ETH-GBP',
#   'price_24h': 2782.38,
#   'volume_24h': 145.20934052,
#   'last_trade_price': 2725.84},
#  {'symbol': 'OGN-USD',
#   'price_24h': 0.6539,
#   'volume_24h': 280.891003,
#   'last_trade_price': 0.6539},
#  {'symbol': 'AAVE-USDT',
#   'price_24h': 258.68,
#   'volume_24h': 0.03500001,
#   'last_trade_price': 258.68},
#  {'symbol': 'ETH-PAX',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 219.41},
#  {'symbol': 'USDC-USDT',
#   'price_24h': 0.9993,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.9993},
#  {'symbol': 'BCH-USDT',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 358.46},
#  {'symbol': 'ALGO-USDT',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.3614},
#  {'symbol': 'SUSHI-USDC',
#   'price_24h': 5.264,
#   'volume_24h': 0.0,
#   'last_trade_price': 5.011},
#  {'symbol': 'ENJ-USD',
#   'price_24h': 2.6412,
#   'volume_24h': 419.730245,
#   'last_trade_price': 2.5907},
#  {'symbol': 'LTC-USDT',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 73.28},
#  {'symbol': 'DAI-GBP',
#   'price_24h': 0.7178,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.7},
#  {'symbol': 'BTC-EUR',
#   'price_24h': 41730.26,
#   'volume_24h': 18.20989964,
#   'last_trade_price': 41314.73},
#  {'symbol': 'EFI-USDC',
#   'price_24h': 1.083,
#   'volume_24h': 0.0,
#   'last_trade_price': 1.083},
#  {'symbol': 'USDT-EUR',
#   'price_24h': 0.8842,
#   'volume_24h': 21154.9807,
#   'last_trade_price': 0.8787},
#  {'symbol': 'DGLD-USD',
#   'price_24h': 177.32,
#   'volume_24h': 270.88526304,
#   'last_trade_price': 177.11},
#  {'symbol': 'EOS-USDC',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.0},
#  {'symbol': 'YFI-USDT',
#   'price_24h': 31140.0,
#   'volume_24h': 0.00262,
#   'last_trade_price': 31140.0},
#  {'symbol': 'SUSHI-USDT',
#   'price_24h': 9.783,
#   'volume_24h': 42.63719941,
#   'last_trade_price': 9.604},
#  {'symbol': 'COMP-USDC',
#   'price_24h': 187.14,
#   'volume_24h': 0.0,
#   'last_trade_price': 187.14},
#  {'symbol': 'ENJ-USDT',
#   'price_24h': 2.61,
#   'volume_24h': 422.01,
#   'last_trade_price': 2.6229},
#  {'symbol': 'LTC-PAX',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 74.03},
#  {'symbol': 'MATIC-USDC',
#   'price_24h': 2.435,
#   'volume_24h': 0.0,
#   'last_trade_price': 2.435},
#  {'symbol': 'PAX-EUR',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.9444},
#  {'symbol': 'AAVE-USD',
#   'price_24h': 264.01,
#   'volume_24h': 0.18021082,
#   'last_trade_price': 258.6},
#  {'symbol': 'NEAR-EUR',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.0},
#  {'symbol': 'DOT-GBP',
#   'price_24h': 19.81,
#   'volume_24h': 159.82715757,
#   'last_trade_price': 19.76},
#  {'symbol': 'BTC-USDT',
#   'price_24h': 47159.54,
#   'volume_24h': 113.36654092,
#   'last_trade_price': 46461.85},
#  {'symbol': 'ETH-USDT',
#   'price_24h': 3733.21,
#   'volume_24h': 1478.21490929,
#   'last_trade_price': 3728.21},
#  {'symbol': 'MATIC-USD',
#   'price_24h': 2.557,
#   'volume_24h': 5881.99337936,
#   'last_trade_price': 2.5},
#  {'symbol': 'SUSHI-USD',
#   'price_24h': 9.85,
#   'volume_24h': 434.33258775,
#   'last_trade_price': 9.464},
#  {'symbol': 'DAI-USD',
#   'price_24h': 1.0002,
#   'volume_24h': 9200.0,
#   'last_trade_price': 1.0002},
#  {'symbol': 'NEAR-USDT',
#   'price_24h': 0.0,
#   'volume_24h': 0.0,
#   'last_trade_price': 0.0}]

# %%
type(response)
# Out:
# list

# %%
len(response)
# Out:
# 107

# %%
today= dt.datetime.today().strftime("%m-%d-%Y")
today
# Out:
# '12-31-2021'

# %%
df= pd.DataFrame (response)
df['difference'] = ''
df['date']=today
df
# Out:
#         symbol    price_24h     volume_24h  last_trade_price difference  \
# 0      XLM-EUR     0.238210  106551.458758          0.232830
# 1     EFI-USDT     1.091000       0.000000          1.091000
# 2     ALGO-BTC     0.000036    1627.952789          0.000036
# 3      XLM-BTC     0.000000       0.000000          0.000006
# 4     USDC-GBP     0.745300       0.000000          0.745300
# ..         ...          ...            ...               ...        ...
# 102   ETH-USDT  3733.210000    1478.214909       3728.210000
# 103  MATIC-USD     2.557000    5881.993379          2.500000
# 104  SUSHI-USD     9.850000     434.332588          9.464000
# 105    DAI-USD     1.000200    9200.000000          1.000200
# 106  NEAR-USDT     0.000000       0.000000          0.000000
#
#            date
# 0    12-31-2021
# 1    12-31-2021
# 2    12-31-2021
# 3    12-31-2021
# 4    12-31-2021
# ..          ...
# 102  12-31-2021
# 103  12-31-2021
# 104  12-31-2021
# 105  12-31-2021
# 106  12-31-2021
#
# [107 rows x 6 columns]

# %%
df.to_csv(f'blockchain_{today}.csv', sep=',', index=False)
