# %%
# Dependencies and Setp up
import json
import requests
import pandas as pd
import numpy as np
import datetime as dt

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json
from pandas.io.json import json_normalize 
import datetime as dt


# API keys
from api_keys import YOUR_API_KEY_

# %%
# url = 'https://pro-api.coinmarketcap.com/'
url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'1000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': YOUR_API_KEY_,
}

# %%
session = Session()
session.headers.update(headers)


try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)

# %%
len(data['data'])
# Out:
# 1000

# %%
type(data)
# Out:
# dict

# %%
c = data['data'][0]
c
# Out:
# {'id': 1,
#  'name': 'Bitcoin',
#  'symbol': 'BTC',
#  'slug': 'bitcoin',
#  'num_market_pairs': 8308,
#  'date_added': '2013-04-28T00:00:00.000Z',
#  'tags': ['mineable',
#   'pow',
#   'sha-256',
#   'store-of-value',
#   'state-channel',
#   'coinbase-ventures-portfolio',
#   'three-arrows-capital-portfolio',
#   'polychain-capital-portfolio',
#   'binance-labs-portfolio',
#   'blockchain-capital-portfolio',
#   'boostvc-portfolio',
#   'cms-holdings-portfolio',
#   'dcg-portfolio',
#   'dragonfly-capital-portfolio',
#   'electric-capital-portfolio',
#   'fabric-ventures-portfolio',
#   'framework-ventures-portfolio',
#   'galaxy-digital-portfolio',
#   'huobi-capital-portfolio',
#   'alameda-research-portfolio',
#   'a16z-portfolio',
#   '1confirmation-portfolio',
#   'winklevoss-capital-portfolio',
#   'usv-portfolio',
#   'placeholder-ventures-portfolio',
#   'pantera-capital-portfolio',
#   'multicoin-capital-portfolio',
#   'paradigm-portfolio'],
#  'max_supply': 21000000,
#  'circulating_supply': 18887631,
#  'total_supply': 18887631,
#  'platform': None,
#  'cmc_rank': 1,
#  'last_updated': '2021-12-01T02:14:03.000Z',
#  'quote': {'USD': {'price': 56932.21903012491,
#    'volume_24h': 36012016208.62276,
#    'volume_change_24h': 11.693,
#    'percent_change_1h': -0.67309926,
#    'percent_change_24h': -0.92668842,
#    'percent_change_7d': 0.1066479,
#    'percent_change_30d': -7.08261632,
#    'percent_change_60d': 19.36431992,
#    'percent_change_90d': 14.56360105,
#    'market_cap': 1075314745052.1771,
#    'market_cap_dominance': 40.7206,
#    'fully_diluted_market_cap': 1195576599632.62,
#    'last_updated': '2021-12-01T02:14:03.000Z'}}}

# %%
df= pd.DataFrame (data['data'])
df['tradable']=''
df.head()
# Out:
#      id          name symbol          slug  num_market_pairs  \
# 0     1       Bitcoin    BTC       bitcoin              8308
# 1  1027      Ethereum    ETH      ethereum              4671
# 2  1839  Binance Coin    BNB  binance-coin               558
# 3   825        Tether   USDT        tether             20070
# 4  5426        Solana    SOL        solana               190
#
#                  date_added  \
# 0  2013-04-28T00:00:00.000Z
# 1  2015-08-07T00:00:00.000Z
# 2  2017-07-25T00:00:00.000Z
# 3  2015-02-25T00:00:00.000Z
# 4  2020-04-10T00:00:00.000Z
#
#                                                 tags   max_supply  \
# 0  [mineable, pow, sha-256, store-of-value, state...   21000000.0
# 1  [mineable, pow, smart-contracts, ethereum-ecos...          NaN
# 2  [marketplace, centralized-exchange, payments, ...  166801148.0
# 3  [payments, stablecoin, asset-backed-stablecoin...          NaN
# 4  [pos, platform, solana-ecosystem, cms-holdings...          NaN
#
#    circulating_supply  total_supply  \
# 0        1.888763e+07  1.888763e+07
# 1        1.185573e+08  1.185573e+08
# 2        1.668011e+08  1.668011e+08
# 3        7.357832e+10  7.635200e+10
# 4        3.058631e+08  5.102062e+08
#
#                                             platform  cmc_rank  \
# 0                                               None         1
# 1                                               None         2
# 2                                               None         3
# 3  {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...         4
# 4                                               None         5
#
#                last_updated  \
# 0  2021-12-01T02:14:03.000Z
# 1  2021-12-01T02:14:07.000Z
# 2  2021-12-01T02:13:39.000Z
# 3  2021-12-01T02:13:42.000Z
# 4  2021-12-01T02:13:43.000Z
#
#                                                quote tradable
# 0  {'USD': {'price': 56932.21903012491, 'volume_2...
# 1  {'USD': {'price': 4679.986138547398, 'volume_2...
# 2  {'USD': {'price': 628.549161361844, 'volume_24...
# 3  {'USD': {'price': 1.000606357404912, 'volume_2...
# 4  {'USD': {'price': 211.39950951564776, 'volume_...

# %%
name = df['name']
name
# Out:
# 0               Bitcoin
# 1              Ethereum
# 2          Binance Coin
# 3                Tether
# 4                Solana
#              ...
# 995    Cirus Foundation
# 996          Bird.Money
# 997            AnimalGo
# 998             Kattana
# 999              Nafter
# Name: name, Length: 1000, dtype: object

# %%
c=df['quote']
type(c)
# Out:
# pandas.core.series.Series

# %%
c[0]['USD']
# Out:
# {'price': 56932.21903012491,
#  'volume_24h': 36012016208.62276,
#  'volume_change_24h': 11.693,
#  'percent_change_1h': -0.67309926,
#  'percent_change_24h': -0.92668842,
#  'percent_change_7d': 0.1066479,
#  'percent_change_30d': -7.08261632,
#  'percent_change_60d': 19.36431992,
#  'percent_change_90d': 14.56360105,
#  'market_cap': 1075314745052.1771,
#  'market_cap_dominance': 40.7206,
#  'fully_diluted_market_cap': 1195576599632.62,
#  'last_updated': '2021-12-01T02:14:03.000Z'}

# %%
df_ =pd.DataFrame(c[0])
df_
# Out:
#                                                USD
# fully_diluted_market_cap               1.19558e+12
# last_updated              2021-12-01T02:14:03.000Z
# market_cap                             1.07531e+12
# market_cap_dominance                       40.7206
# percent_change_1h                        -0.673099
# percent_change_24h                       -0.926688
# percent_change_30d                        -7.08262
# percent_change_60d                         19.3643
# percent_change_7d                         0.106648
# percent_change_90d                         14.5636
# price                                      56932.2
# volume_24h                              3.6012e+10
# volume_change_24h                           11.693

# %%
d=[]
for i in c:
    d.append(i['USD'])

# %%
df_c =pd.DataFrame(d)
df_c['name']=name
df_c = df_c[['name','price','volume_24h','volume_change_24h','percent_change_1h','percent_change_24h','percent_change_7d','percent_change_30d','percent_change_60d','market_cap','market_cap_dominance','fully_diluted_market_cap','last_updated']]
df_c.head()
# Out:
#            name         price    volume_24h  volume_change_24h  \
# 0       Bitcoin  56932.219030  3.601202e+10            11.6930
# 1      Ethereum   4679.986139  2.868557e+10            48.1277
# 2  Binance Coin    628.549161  2.764223e+09            13.1095
# 3        Tether      1.000606  8.699418e+10            20.6957
# 4        Solana    211.399510  2.950401e+09            44.7403
#
#    percent_change_1h  percent_change_24h  percent_change_7d  \
# 0          -0.673099           -0.926688           0.106648
# 1          -0.395219            4.418427           9.381069
# 2           0.198058            0.532742           6.970044
# 3           0.048824           -0.068696           0.001183
# 4           0.278254            2.875130          -2.924229
#
#    percent_change_30d  percent_change_60d    market_cap  market_cap_dominance  \
# 0           -7.082616           19.364320  1.075315e+12               40.7206
# 1            8.842583           42.228989  5.548467e+11               21.0112
# 2           19.536541           50.378524  1.048427e+11                3.9702
# 3           -0.007706            0.043213  7.362294e+10                2.7880
# 4            2.469478           32.187557  6.465931e+10                2.4520
#
#    fully_diluted_market_cap              last_updated
# 0              1.195577e+12  2021-12-01T02:14:03.000Z
# 1              5.548467e+11  2021-12-01T02:14:07.000Z
# 2              1.048427e+11  2021-12-01T02:13:39.000Z
# 3              7.639829e+10  2021-12-01T02:13:42.000Z
# 4              1.078573e+11  2021-12-01T02:13:43.000Z

# %%
df =df.merge(df_c, on='name', how='inner')
df.head()
# Out:
#      id          name symbol          slug  num_market_pairs  \
# 0     1       Bitcoin    BTC       bitcoin              8308
# 1  1027      Ethereum    ETH      ethereum              4671
# 2  1839  Binance Coin    BNB  binance-coin               558
# 3   825        Tether   USDT        tether             20070
# 4  5426        Solana    SOL        solana               190
#
#                  date_added  \
# 0  2013-04-28T00:00:00.000Z
# 1  2015-08-07T00:00:00.000Z
# 2  2017-07-25T00:00:00.000Z
# 3  2015-02-25T00:00:00.000Z
# 4  2020-04-10T00:00:00.000Z
#
#                                                 tags   max_supply  \
# 0  [mineable, pow, sha-256, store-of-value, state...   21000000.0
# 1  [mineable, pow, smart-contracts, ethereum-ecos...          NaN
# 2  [marketplace, centralized-exchange, payments, ...  166801148.0
# 3  [payments, stablecoin, asset-backed-stablecoin...          NaN
# 4  [pos, platform, solana-ecosystem, cms-holdings...          NaN
#
#    circulating_supply  total_supply  ... volume_change_24h  percent_change_1h  \
# 0        1.888763e+07  1.888763e+07  ...           11.6930          -0.673099
# 1        1.185573e+08  1.185573e+08  ...           48.1277          -0.395219
# 2        1.668011e+08  1.668011e+08  ...           13.1095           0.198058
# 3        7.357832e+10  7.635200e+10  ...           20.6957           0.048824
# 4        3.058631e+08  5.102062e+08  ...           44.7403           0.278254
#
#   percent_change_24h percent_change_7d percent_change_30d  percent_change_60d  \
# 0          -0.926688          0.106648          -7.082616           19.364320
# 1           4.418427          9.381069           8.842583           42.228989
# 2           0.532742          6.970044          19.536541           50.378524
# 3          -0.068696          0.001183          -0.007706            0.043213
# 4           2.875130         -2.924229           2.469478           32.187557
#
#      market_cap  market_cap_dominance  fully_diluted_market_cap  \
# 0  1.075315e+12               40.7206              1.195577e+12
# 1  5.548467e+11               21.0112              5.548467e+11
# 2  1.048427e+11                3.9702              1.048427e+11
# 3  7.362294e+10                2.7880              7.639829e+10
# 4  6.465931e+10                2.4520              1.078573e+11
#
#              last_updated_y
# 0  2021-12-01T02:14:03.000Z
# 1  2021-12-01T02:14:07.000Z
# 2  2021-12-01T02:13:39.000Z
# 3  2021-12-01T02:13:42.000Z
# 4  2021-12-01T02:13:43.000Z
#
# [5 rows x 27 columns]

# %%
df = df.drop_duplicates(['name'])
len(df)
# Out:
# 1000

# %%
df = df.dropna(subset=['name'])

# %%
df.reset_index(drop=True, inplace=True)

# %%
df =df.fillna(0)
df.head()
# Out:
#      id          name symbol          slug  num_market_pairs  \
# 0     1       Bitcoin    BTC       bitcoin              8308
# 1  1027      Ethereum    ETH      ethereum              4671
# 2  1839  Binance Coin    BNB  binance-coin               558
# 3   825        Tether   USDT        tether             20070
# 4  5426        Solana    SOL        solana               190
#
#                  date_added  \
# 0  2013-04-28T00:00:00.000Z
# 1  2015-08-07T00:00:00.000Z
# 2  2017-07-25T00:00:00.000Z
# 3  2015-02-25T00:00:00.000Z
# 4  2020-04-10T00:00:00.000Z
#
#                                                 tags   max_supply  \
# 0  [mineable, pow, sha-256, store-of-value, state...   21000000.0
# 1  [mineable, pow, smart-contracts, ethereum-ecos...          0.0
# 2  [marketplace, centralized-exchange, payments, ...  166801148.0
# 3  [payments, stablecoin, asset-backed-stablecoin...          0.0
# 4  [pos, platform, solana-ecosystem, cms-holdings...          0.0
#
#    circulating_supply  total_supply  ... volume_change_24h  percent_change_1h  \
# 0        1.888763e+07  1.888763e+07  ...           11.6930          -0.673099
# 1        1.185573e+08  1.185573e+08  ...           48.1277          -0.395219
# 2        1.668011e+08  1.668011e+08  ...           13.1095           0.198058
# 3        7.357832e+10  7.635200e+10  ...           20.6957           0.048824
# 4        3.058631e+08  5.102062e+08  ...           44.7403           0.278254
#
#   percent_change_24h percent_change_7d percent_change_30d  percent_change_60d  \
# 0          -0.926688          0.106648          -7.082616           19.364320
# 1           4.418427          9.381069           8.842583           42.228989
# 2           0.532742          6.970044          19.536541           50.378524
# 3          -0.068696          0.001183          -0.007706            0.043213
# 4           2.875130         -2.924229           2.469478           32.187557
#
#      market_cap  market_cap_dominance  fully_diluted_market_cap  \
# 0  1.075315e+12               40.7206              1.195577e+12
# 1  5.548467e+11               21.0112              5.548467e+11
# 2  1.048427e+11                3.9702              1.048427e+11
# 3  7.362294e+10                2.7880              7.639829e+10
# 4  6.465931e+10                2.4520              1.078573e+11
#
#              last_updated_y
# 0  2021-12-01T02:14:03.000Z
# 1  2021-12-01T02:14:07.000Z
# 2  2021-12-01T02:13:39.000Z
# 3  2021-12-01T02:13:42.000Z
# 4  2021-12-01T02:13:43.000Z
#
# [5 rows x 27 columns]

# %%
today= dt.datetime.today().strftime("%m-%d-%Y")
today
# Out:
# '11-30-2021'

# %%
df['date']=today
df.head()
# Out:
#      id          name symbol          slug  num_market_pairs  \
# 0     1       Bitcoin    BTC       bitcoin              8308
# 1  1027      Ethereum    ETH      ethereum              4671
# 2  1839  Binance Coin    BNB  binance-coin               558
# 3   825        Tether   USDT        tether             20070
# 4  5426        Solana    SOL        solana               190
#
#                  date_added  \
# 0  2013-04-28T00:00:00.000Z
# 1  2015-08-07T00:00:00.000Z
# 2  2017-07-25T00:00:00.000Z
# 3  2015-02-25T00:00:00.000Z
# 4  2020-04-10T00:00:00.000Z
#
#                                                 tags   max_supply  \
# 0  [mineable, pow, sha-256, store-of-value, state...   21000000.0
# 1  [mineable, pow, smart-contracts, ethereum-ecos...          0.0
# 2  [marketplace, centralized-exchange, payments, ...  166801148.0
# 3  [payments, stablecoin, asset-backed-stablecoin...          0.0
# 4  [pos, platform, solana-ecosystem, cms-holdings...          0.0
#
#    circulating_supply  total_supply  ... percent_change_1h  \
# 0        1.888763e+07  1.888763e+07  ...         -0.673099
# 1        1.185573e+08  1.185573e+08  ...         -0.395219
# 2        1.668011e+08  1.668011e+08  ...          0.198058
# 3        7.357832e+10  7.635200e+10  ...          0.048824
# 4        3.058631e+08  5.102062e+08  ...          0.278254
#
#    percent_change_24h percent_change_7d percent_change_30d percent_change_60d  \
# 0           -0.926688          0.106648          -7.082616          19.364320
# 1            4.418427          9.381069           8.842583          42.228989
# 2            0.532742          6.970044          19.536541          50.378524
# 3           -0.068696          0.001183          -0.007706           0.043213
# 4            2.875130         -2.924229           2.469478          32.187557
#
#      market_cap  market_cap_dominance  fully_diluted_market_cap  \
# 0  1.075315e+12               40.7206              1.195577e+12
# 1  5.548467e+11               21.0112              5.548467e+11
# 2  1.048427e+11                3.9702              1.048427e+11
# 3  7.362294e+10                2.7880              7.639829e+10
# 4  6.465931e+10                2.4520              1.078573e+11
#
#              last_updated_y        date
# 0  2021-12-01T02:14:03.000Z  11-30-2021
# 1  2021-12-01T02:14:07.000Z  11-30-2021
# 2  2021-12-01T02:13:39.000Z  11-30-2021
# 3  2021-12-01T02:13:42.000Z  11-30-2021
# 4  2021-12-01T02:13:43.000Z  11-30-2021
#
# [5 rows x 28 columns]

# %%
df.dtypes
# Out:
# id                            int64
# name                         object
# symbol                       object
# slug                         object
# num_market_pairs              int64
# date_added                   object
# tags                         object
# max_supply                  float64
# circulating_supply          float64
# total_supply                float64
# platform                     object
# cmc_rank                      int64
# last_updated_x               object
# quote                        object
# tradable                     object
# price                       float64
# volume_24h                  float64
# volume_change_24h           float64
# percent_change_1h           float64
# percent_change_24h          float64
# percent_change_7d           float64
# percent_change_30d          float64
# percent_change_60d          float64
# market_cap                  float64
# market_cap_dominance        float64
# fully_diluted_market_cap    float64
# last_updated_y               object
# date                         object
# dtype: object

# %%
df.to_csv(f'coinmarketcap_{today}.csv', sep=',', index=False)

# %%
data?
