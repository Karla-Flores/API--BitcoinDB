# %%
# Dependencies and Setp up
import json
import requests
import pandas as pd
import numpy as np
import datetime as dt

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json


# API keys
from api_keys import YOUR_API_KEY_

# %%
# url = 'https://pro-api.coinmarketcap.com/'
url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'1000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': YOUR_API_KEY_,
}

# %%
session = Session()
session.headers.update(headers)


try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)

# %%
data['data'][999]
# Out:
# {'id': 8424,
#  'name': 'Deri Protocol',
#  'symbol': 'DERI',
#  'slug': 'deri-protocol',
#  'num_market_pairs': 13,
#  'date_added': '2021-02-11T00:00:00.000Z',
#  'tags': ['decentralized-exchange',
#   'defi',
#   'derivatives',
#   'binance-smart-chain',
#   'options',
#   'mvb'],
#  'max_supply': 400000000,
#  'circulating_supply': 47638409.30776003,
#  'total_supply': 412282435.592577,
#  'platform': {'id': 1027,
#   'name': 'Ethereum',
#   'symbol': 'ETH',
#   'slug': 'ethereum',
#   'token_address': '0xa487bf43cf3b10dffc97a9a744cbb7036965d3b9'},
#  'cmc_rank': 1000,
#  'last_updated': '2021-11-07T01:02:04.000Z',
#  'quote': {'USD': {'price': 0.31190035934428,
#    'volume_24h': 1138965.16851543,
#    'volume_change_24h': -31.6491,
#    'percent_change_1h': 0.17115515,
#    'percent_change_24h': -2.52120278,
#    'percent_change_7d': 2.32981971,
#    'percent_change_30d': 85.37519876,
#    'percent_change_60d': 272.54714131,
#    'percent_change_90d': 323.70149486,
#    'market_cap': 14858436.981680246,
#    'market_cap_dominance': 0.0005,
#    'fully_diluted_market_cap': 124760143.74,
#    'last_updated': '2021-11-07T01:02:04.000Z'}}}

# %%
len(data['data'])
# Out:
# 1000

# %%
type(data)
# Out:
# dict

# %%
c = data['data'][0]

# %%
df= pd.DataFrame (data['data'])
df
# Out:
#        id                 name symbol                 slug  num_market_pairs  \
# 0       1              Bitcoin    BTC              bitcoin              8291
# 1    1027             Ethereum    ETH             ethereum              4536
# 2    1839         Binance Coin    BNB         binance-coin               549
# 3    5426               Solana    SOL               solana               177
# 4     825               Tether   USDT               tether             18583
# ..    ...                  ...    ...                  ...               ...
# 995  8080  DeFi Yield Protocol    DYP  defi-yield-protocol                16
# 996  3667   Atomic Wallet Coin    AWC   atomic-wallet-coin                 3
# 997  1950   Hiveterminal Token    HVN   hiveterminal-token                 5
# 998  2034               Everex    EVX               everex                11
# 999  8424        Deri Protocol   DERI        deri-protocol                13
#
#                    date_added  \
# 0    2013-04-28T00:00:00.000Z
# 1    2015-08-07T00:00:00.000Z
# 2    2017-07-25T00:00:00.000Z
# 3    2020-04-10T00:00:00.000Z
# 4    2015-02-25T00:00:00.000Z
# ..                        ...
# 995  2020-12-23T00:00:00.000Z
# 996  2019-01-04T00:00:00.000Z
# 997  2017-09-10T00:00:00.000Z
# 998  2017-10-10T00:00:00.000Z
# 999  2021-02-11T00:00:00.000Z
#
#                                                   tags   max_supply  \
# 0    [mineable, pow, sha-256, store-of-value, state...   21000000.0
# 1    [mineable, pow, smart-contracts, ethereum, bin...          NaN
# 2    [marketplace, centralized-exchange, payments, ...  166801148.0
# 3    [pos, platform, solana-ecosystem, cms-holdings...          NaN
# 4    [payments, stablecoin, stablecoin-asset-backed...          NaN
# ..                                                 ...          ...
# 995   [defi, binance-smart-chain, avalanche-ecosystem]   25651531.0
# 996                                 [cosmos-ecosystem]          NaN
# 997                                                 []          NaN
# 998                        [services, smart-contracts]          NaN
# 999  [decentralized-exchange, defi, derivatives, bi...  400000000.0
#
#      circulating_supply  total_supply  \
# 0          1.886596e+07  1.886596e+07
# 1          1.182378e+08  1.182378e+08
# 2          1.668011e+08  1.668011e+08
# 3          3.012107e+08  5.083841e+08
# 4          7.185230e+10  7.335785e+10
# ..                  ...           ...
# 995        1.648152e+07  3.000000e+07
# 996        1.060366e+07  1.000000e+08
# 997        5.000000e+08  5.000000e+08
# 998        2.270000e+07  2.500000e+07
# 999        4.763841e+07  4.122824e+08
#
#                                               platform  cmc_rank  \
# 0                                                 None         1
# 1                                                 None         2
# 2                                                 None         3
# 3                                                 None         4
# 4    {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...         5
# ..                                                 ...       ...
# 995  {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...       996
# 996  {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...       997
# 997  {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...       998
# 998  {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...       999
# 999  {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...      1000
#
#                  last_updated  \
# 0    2021-11-07T01:02:02.000Z
# 1    2021-11-07T01:02:02.000Z
# 2    2021-11-07T01:02:08.000Z
# 3    2021-11-07T01:02:04.000Z
# 4    2021-11-07T01:01:09.000Z
# ..                        ...
# 995  2021-11-07T01:01:09.000Z
# 996  2021-11-07T01:02:07.000Z
# 997  2021-11-07T01:01:09.000Z
# 998  2021-11-07T01:01:10.000Z
# 999  2021-11-07T01:02:04.000Z
#
#                                                  quote
# 0    {'USD': {'price': 62156.53800448696, 'volume_2...
# 1    {'USD': {'price': 4557.63176866333, 'volume_24...
# 2    {'USD': {'price': 636.3341135039228, 'volume_2...
# 3    {'USD': {'price': 254.2157985978614, 'volume_2...
# 4    {'USD': {'price': 1.00130166726664, 'volume_24...
# ..                                                 ...
# 995  {'USD': {'price': 0.91254656841548, 'volume_24...
# 996  {'USD': {'price': 1.41741408519589, 'volume_24...
# 997  {'USD': {'price': 0.02999995444198, 'volume_24...
# 998  {'USD': {'price': 0.65508291902701, 'volume_24...
# 999  {'USD': {'price': 0.31190035934428, 'volume_24...
#
# [1000 rows x 14 columns]

# %%
df['tradable']=''
df
# Out:
#        id                 name symbol                 slug  num_market_pairs  \
# 0       1              Bitcoin    BTC              bitcoin              8291
# 1    1027             Ethereum    ETH             ethereum              4536
# 2    1839         Binance Coin    BNB         binance-coin               549
# 3    5426               Solana    SOL               solana               177
# 4     825               Tether   USDT               tether             18583
# ..    ...                  ...    ...                  ...               ...
# 995  8080  DeFi Yield Protocol    DYP  defi-yield-protocol                16
# 996  3667   Atomic Wallet Coin    AWC   atomic-wallet-coin                 3
# 997  1950   Hiveterminal Token    HVN   hiveterminal-token                 5
# 998  2034               Everex    EVX               everex                11
# 999  8424        Deri Protocol   DERI        deri-protocol                13
#
#                    date_added  \
# 0    2013-04-28T00:00:00.000Z
# 1    2015-08-07T00:00:00.000Z
# 2    2017-07-25T00:00:00.000Z
# 3    2020-04-10T00:00:00.000Z
# 4    2015-02-25T00:00:00.000Z
# ..                        ...
# 995  2020-12-23T00:00:00.000Z
# 996  2019-01-04T00:00:00.000Z
# 997  2017-09-10T00:00:00.000Z
# 998  2017-10-10T00:00:00.000Z
# 999  2021-02-11T00:00:00.000Z
#
#                                                   tags   max_supply  \
# 0    [mineable, pow, sha-256, store-of-value, state...   21000000.0
# 1    [mineable, pow, smart-contracts, ethereum, bin...          NaN
# 2    [marketplace, centralized-exchange, payments, ...  166801148.0
# 3    [pos, platform, solana-ecosystem, cms-holdings...          NaN
# 4    [payments, stablecoin, stablecoin-asset-backed...          NaN
# ..                                                 ...          ...
# 995   [defi, binance-smart-chain, avalanche-ecosystem]   25651531.0
# 996                                 [cosmos-ecosystem]          NaN
# 997                                                 []          NaN
# 998                        [services, smart-contracts]          NaN
# 999  [decentralized-exchange, defi, derivatives, bi...  400000000.0
#
#      circulating_supply  total_supply  \
# 0          1.886596e+07  1.886596e+07
# 1          1.182378e+08  1.182378e+08
# 2          1.668011e+08  1.668011e+08
# 3          3.012107e+08  5.083841e+08
# 4          7.185230e+10  7.335785e+10
# ..                  ...           ...
# 995        1.648152e+07  3.000000e+07
# 996        1.060366e+07  1.000000e+08
# 997        5.000000e+08  5.000000e+08
# 998        2.270000e+07  2.500000e+07
# 999        4.763841e+07  4.122824e+08
#
#                                               platform  cmc_rank  \
# 0                                                 None         1
# 1                                                 None         2
# 2                                                 None         3
# 3                                                 None         4
# 4    {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...         5
# ..                                                 ...       ...
# 995  {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...       996
# 996  {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...       997
# 997  {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...       998
# 998  {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...       999
# 999  {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...      1000
#
#                  last_updated  \
# 0    2021-11-07T01:02:02.000Z
# 1    2021-11-07T01:02:02.000Z
# 2    2021-11-07T01:02:08.000Z
# 3    2021-11-07T01:02:04.000Z
# 4    2021-11-07T01:01:09.000Z
# ..                        ...
# 995  2021-11-07T01:01:09.000Z
# 996  2021-11-07T01:02:07.000Z
# 997  2021-11-07T01:01:09.000Z
# 998  2021-11-07T01:01:10.000Z
# 999  2021-11-07T01:02:04.000Z
#
#                                                  quote tradable
# 0    {'USD': {'price': 62156.53800448696, 'volume_2...
# 1    {'USD': {'price': 4557.63176866333, 'volume_24...
# 2    {'USD': {'price': 636.3341135039228, 'volume_2...
# 3    {'USD': {'price': 254.2157985978614, 'volume_2...
# 4    {'USD': {'price': 1.00130166726664, 'volume_24...
# ..                                                 ...      ...
# 995  {'USD': {'price': 0.91254656841548, 'volume_24...
# 996  {'USD': {'price': 1.41741408519589, 'volume_24...
# 997  {'USD': {'price': 0.02999995444198, 'volume_24...
# 998  {'USD': {'price': 0.65508291902701, 'volume_24...
# 999  {'USD': {'price': 0.31190035934428, 'volume_24...
#
# [1000 rows x 15 columns]
