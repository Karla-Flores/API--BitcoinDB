# %%
# Dependencies and Setp up
import json
import requests
import pandas as pd
import numpy as np
import datetime as dt

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json
from pandas.io.json import json_normalize 
import datetime as dt


# API keys
from api_keys import YOUR_API_KEY_

# %%
# url = 'https://pro-api.coinmarketcap.com/'
url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'1000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': YOUR_API_KEY_,
}

# %%
session = Session()
session.headers.update(headers)


try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)

# %%
len(data['data'])
# Out:
# 1000

# %%
type(data)
# Out:
# dict

# %%
c = data['data'][0]
c
# Out:
# {'id': 1,
#  'name': 'Bitcoin',
#  'symbol': 'BTC',
#  'slug': 'bitcoin',
#  'num_market_pairs': 8156,
#  'date_added': '2013-04-28T00:00:00.000Z',
#  'tags': ['mineable',
#   'pow',
#   'sha-256',
#   'store-of-value',
#   'state-channel',
#   'coinbase-ventures-portfolio',
#   'three-arrows-capital-portfolio',
#   'polychain-capital-portfolio',
#   'binance-labs-portfolio',
#   'blockchain-capital-portfolio',
#   'boostvc-portfolio',
#   'cms-holdings-portfolio',
#   'dcg-portfolio',
#   'dragonfly-capital-portfolio',
#   'electric-capital-portfolio',
#   'fabric-ventures-portfolio',
#   'framework-ventures-portfolio',
#   'galaxy-digital-portfolio',
#   'huobi-capital-portfolio',
#   'alameda-research-portfolio',
#   'a16z-portfolio',
#   '1confirmation-portfolio',
#   'winklevoss-capital-portfolio',
#   'usv-portfolio',
#   'placeholder-ventures-portfolio',
#   'pantera-capital-portfolio',
#   'multicoin-capital-portfolio',
#   'paradigm-portfolio'],
#  'max_supply': 21000000,
#  'circulating_supply': 18902106,
#  'total_supply': 18902106,
#  'platform': None,
#  'cmc_rank': 1,
#  'last_updated': '2021-12-16T03:08:02.000Z',
#  'quote': {'USD': {'price': 49086.0821470536,
#    'volume_24h': 36572866473.37827,
#    'volume_change_24h': 7.1042,
#    'percent_change_1h': 0.06428459,
#    'percent_change_24h': 2.19312619,
#    'percent_change_7d': -1.66027154,
#    'percent_change_30d': -20.5730781,
#    'percent_change_60d': -19.82889305,
#    'percent_change_90d': 2.71085151,
#    'market_cap': 927830327868.3148,
#    'market_cap_dominance': 40.9948,
#    'fully_diluted_market_cap': 1030807725088.13,
#    'last_updated': '2021-12-16T03:08:02.000Z'}}}

# %%
df= pd.DataFrame (data['data'])
df['tradable']=''
df.head()
# Out:
#      id          name symbol          slug  num_market_pairs  \
# 0     1       Bitcoin    BTC       bitcoin              8156
# 1  1027      Ethereum    ETH      ethereum              4538
# 2  1839  Binance Coin    BNB  binance-coin               539
# 3   825        Tether   USDT        tether             19917
# 4  5426        Solana    SOL        solana               193
#
#                  date_added  \
# 0  2013-04-28T00:00:00.000Z
# 1  2015-08-07T00:00:00.000Z
# 2  2017-07-25T00:00:00.000Z
# 3  2015-02-25T00:00:00.000Z
# 4  2020-04-10T00:00:00.000Z
#
#                                                 tags   max_supply  \
# 0  [mineable, pow, sha-256, store-of-value, state...   21000000.0
# 1  [mineable, pow, smart-contracts, ethereum-ecos...          NaN
# 2  [marketplace, centralized-exchange, payments, ...  166801148.0
# 3  [payments, stablecoin, asset-backed-stablecoin...          NaN
# 4  [pos, platform, solana-ecosystem, cms-holdings...          NaN
#
#    circulating_supply  total_supply  \
# 0        1.890211e+07  1.890211e+07
# 1        1.187567e+08  1.187567e+08
# 2        1.668011e+08  1.668011e+08
# 3        7.669420e+10  8.036200e+10
# 4        3.077904e+08  5.112147e+08
#
#                                             platform  cmc_rank  \
# 0                                               None         1
# 1                                               None         2
# 2                                               None         3
# 3  {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...         4
# 4                                               None         5
#
#                last_updated  \
# 0  2021-12-16T03:08:02.000Z
# 1  2021-12-16T03:08:02.000Z
# 2  2021-12-16T03:07:11.000Z
# 3  2021-12-16T03:07:11.000Z
# 4  2021-12-16T03:08:05.000Z
#
#                                                quote tradable
# 0  {'USD': {'price': 49086.0821470536, 'volume_24...
# 1  {'USD': {'price': 4036.9179584531544, 'volume_...
# 2  {'USD': {'price': 537.2009413937542, 'volume_2...
# 3  {'USD': {'price': 1.001137158685441, 'volume_2...
# 4  {'USD': {'price': 177.51119284786594, 'volume_...

# %%
name = df['name']
name
# Out:
# 0           Bitcoin
# 1          Ethereum
# 2      Binance Coin
# 3            Tether
# 4            Solana
#            ...
# 995           FIBOS
# 996       ArtWallet
# 997         YF Link
# 998         RioDeFi
# 999      Tiger King
# Name: name, Length: 1000, dtype: object

# %%
c=df['quote']
type(c)
# Out:
# pandas.core.series.Series

# %%
c[0]['USD']
# Out:
# {'price': 49086.0821470536,
#  'volume_24h': 36572866473.37827,
#  'volume_change_24h': 7.1042,
#  'percent_change_1h': 0.06428459,
#  'percent_change_24h': 2.19312619,
#  'percent_change_7d': -1.66027154,
#  'percent_change_30d': -20.5730781,
#  'percent_change_60d': -19.82889305,
#  'percent_change_90d': 2.71085151,
#  'market_cap': 927830327868.3148,
#  'market_cap_dominance': 40.9948,
#  'fully_diluted_market_cap': 1030807725088.13,
#  'last_updated': '2021-12-16T03:08:02.000Z'}

# %%
df_ =pd.DataFrame(c[0])
df_
# Out:
#                                                USD
# fully_diluted_market_cap               1.03081e+12
# last_updated              2021-12-16T03:08:02.000Z
# market_cap                              9.2783e+11
# market_cap_dominance                       40.9948
# percent_change_1h                        0.0642846
# percent_change_24h                         2.19313
# percent_change_30d                        -20.5731
# percent_change_60d                        -19.8289
# percent_change_7d                         -1.66027
# percent_change_90d                         2.71085
# price                                      49086.1
# volume_24h                             3.65729e+10
# volume_change_24h                           7.1042

# %%
d=[]
for i in c:
    d.append(i['USD'])

# %%
df_c =pd.DataFrame(d)
df_c['name']=name
df_c = df_c[['name','price','volume_24h','volume_change_24h','percent_change_1h','percent_change_24h','percent_change_7d','percent_change_30d','percent_change_60d','market_cap','market_cap_dominance','fully_diluted_market_cap','last_updated']]
df_c.head()
# Out:
#            name         price    volume_24h  volume_change_24h  \
# 0       Bitcoin  49086.082147  3.657287e+10             7.1042
# 1      Ethereum   4036.917958  2.669586e+10            29.8644
# 2  Binance Coin    537.200941  2.088437e+09            -4.5639
# 3        Tether      1.001137  7.793438e+10           -75.7896
# 4        Solana    177.511193  3.769469e+09            61.0146
#
#    percent_change_1h  percent_change_24h  percent_change_7d  \
# 0           0.064285            2.193126          -1.660272
# 1          -0.196809            5.437581          -8.212798
# 2          -0.412192            2.338056         -11.130359
# 3           0.089395            0.034613           0.180263
# 4          -0.313311           10.636230          -6.953982
#
#    percent_change_30d  percent_change_60d    market_cap  market_cap_dominance  \
# 0          -20.573078          -19.828893  9.278303e+11               40.9948
# 1           -7.425176            4.702771  4.794109e+11               21.1914
# 2          -12.962236           15.617822  8.960573e+10                3.9608
# 3           -0.009409            0.111060  7.678142e+10                3.3912
# 4          -22.712295           11.035562  5.463623e+10                2.4136
#
#    fully_diluted_market_cap              last_updated
# 0              1.030808e+12  2021-12-16T03:08:02.000Z
# 1              4.794109e+11  2021-12-16T03:08:02.000Z
# 2              8.960573e+10  2021-12-16T03:07:11.000Z
# 3              8.045338e+10  2021-12-16T03:07:11.000Z
# 4              9.074634e+10  2021-12-16T03:08:05.000Z

# %%
df =df.merge(df_c, on='name', how='inner')
df.head()
# Out:
#      id          name symbol          slug  num_market_pairs  \
# 0     1       Bitcoin    BTC       bitcoin              8156
# 1  1027      Ethereum    ETH      ethereum              4538
# 2  1839  Binance Coin    BNB  binance-coin               539
# 3   825        Tether   USDT        tether             19917
# 4  5426        Solana    SOL        solana               193
#
#                  date_added  \
# 0  2013-04-28T00:00:00.000Z
# 1  2015-08-07T00:00:00.000Z
# 2  2017-07-25T00:00:00.000Z
# 3  2015-02-25T00:00:00.000Z
# 4  2020-04-10T00:00:00.000Z
#
#                                                 tags   max_supply  \
# 0  [mineable, pow, sha-256, store-of-value, state...   21000000.0
# 1  [mineable, pow, smart-contracts, ethereum-ecos...          NaN
# 2  [marketplace, centralized-exchange, payments, ...  166801148.0
# 3  [payments, stablecoin, asset-backed-stablecoin...          NaN
# 4  [pos, platform, solana-ecosystem, cms-holdings...          NaN
#
#    circulating_supply  total_supply  ... volume_change_24h  percent_change_1h  \
# 0        1.890211e+07  1.890211e+07  ...            7.1042           0.064285
# 1        1.187567e+08  1.187567e+08  ...           29.8644          -0.196809
# 2        1.668011e+08  1.668011e+08  ...           -4.5639          -0.412192
# 3        7.669420e+10  8.036200e+10  ...          -75.7896           0.089395
# 4        3.077904e+08  5.112147e+08  ...           61.0146          -0.313311
#
#   percent_change_24h percent_change_7d percent_change_30d  percent_change_60d  \
# 0           2.193126         -1.660272         -20.573078          -19.828893
# 1           5.437581         -8.212798          -7.425176            4.702771
# 2           2.338056        -11.130359         -12.962236           15.617822
# 3           0.034613          0.180263          -0.009409            0.111060
# 4          10.636230         -6.953982         -22.712295           11.035562
#
#      market_cap  market_cap_dominance  fully_diluted_market_cap  \
# 0  9.278303e+11               40.9948              1.030808e+12
# 1  4.794109e+11               21.1914              4.794109e+11
# 2  8.960573e+10                3.9608              8.960573e+10
# 3  7.678142e+10                3.3912              8.045338e+10
# 4  5.463623e+10                2.4136              9.074634e+10
#
#              last_updated_y
# 0  2021-12-16T03:08:02.000Z
# 1  2021-12-16T03:08:02.000Z
# 2  2021-12-16T03:07:11.000Z
# 3  2021-12-16T03:07:11.000Z
# 4  2021-12-16T03:08:05.000Z
#
# [5 rows x 27 columns]

# %%
df = df.drop_duplicates(['name'])
len(df)
# Out:
# 1000

# %%
df = df.dropna(subset=['name'])

# %%
df.reset_index(drop=True, inplace=True)

# %%
df =df.fillna(0)
df.head()
# Out:
#      id          name symbol          slug  num_market_pairs  \
# 0     1       Bitcoin    BTC       bitcoin              8156
# 1  1027      Ethereum    ETH      ethereum              4538
# 2  1839  Binance Coin    BNB  binance-coin               539
# 3   825        Tether   USDT        tether             19917
# 4  5426        Solana    SOL        solana               193
#
#                  date_added  \
# 0  2013-04-28T00:00:00.000Z
# 1  2015-08-07T00:00:00.000Z
# 2  2017-07-25T00:00:00.000Z
# 3  2015-02-25T00:00:00.000Z
# 4  2020-04-10T00:00:00.000Z
#
#                                                 tags   max_supply  \
# 0  [mineable, pow, sha-256, store-of-value, state...   21000000.0
# 1  [mineable, pow, smart-contracts, ethereum-ecos...          0.0
# 2  [marketplace, centralized-exchange, payments, ...  166801148.0
# 3  [payments, stablecoin, asset-backed-stablecoin...          0.0
# 4  [pos, platform, solana-ecosystem, cms-holdings...          0.0
#
#    circulating_supply  total_supply  ... volume_change_24h  percent_change_1h  \
# 0        1.890211e+07  1.890211e+07  ...            7.1042           0.064285
# 1        1.187567e+08  1.187567e+08  ...           29.8644          -0.196809
# 2        1.668011e+08  1.668011e+08  ...           -4.5639          -0.412192
# 3        7.669420e+10  8.036200e+10  ...          -75.7896           0.089395
# 4        3.077904e+08  5.112147e+08  ...           61.0146          -0.313311
#
#   percent_change_24h percent_change_7d percent_change_30d  percent_change_60d  \
# 0           2.193126         -1.660272         -20.573078          -19.828893
# 1           5.437581         -8.212798          -7.425176            4.702771
# 2           2.338056        -11.130359         -12.962236           15.617822
# 3           0.034613          0.180263          -0.009409            0.111060
# 4          10.636230         -6.953982         -22.712295           11.035562
#
#      market_cap  market_cap_dominance  fully_diluted_market_cap  \
# 0  9.278303e+11               40.9948              1.030808e+12
# 1  4.794109e+11               21.1914              4.794109e+11
# 2  8.960573e+10                3.9608              8.960573e+10
# 3  7.678142e+10                3.3912              8.045338e+10
# 4  5.463623e+10                2.4136              9.074634e+10
#
#              last_updated_y
# 0  2021-12-16T03:08:02.000Z
# 1  2021-12-16T03:08:02.000Z
# 2  2021-12-16T03:07:11.000Z
# 3  2021-12-16T03:07:11.000Z
# 4  2021-12-16T03:08:05.000Z
#
# [5 rows x 27 columns]

# %%
today= dt.datetime.today().strftime("%m-%d-%Y")
today
# Out:
# '12-15-2021'

# %%
df['date']=today
df.head()
# Out:
#      id          name symbol          slug  num_market_pairs  \
# 0     1       Bitcoin    BTC       bitcoin              8156
# 1  1027      Ethereum    ETH      ethereum              4538
# 2  1839  Binance Coin    BNB  binance-coin               539
# 3   825        Tether   USDT        tether             19917
# 4  5426        Solana    SOL        solana               193
#
#                  date_added  \
# 0  2013-04-28T00:00:00.000Z
# 1  2015-08-07T00:00:00.000Z
# 2  2017-07-25T00:00:00.000Z
# 3  2015-02-25T00:00:00.000Z
# 4  2020-04-10T00:00:00.000Z
#
#                                                 tags   max_supply  \
# 0  [mineable, pow, sha-256, store-of-value, state...   21000000.0
# 1  [mineable, pow, smart-contracts, ethereum-ecos...          0.0
# 2  [marketplace, centralized-exchange, payments, ...  166801148.0
# 3  [payments, stablecoin, asset-backed-stablecoin...          0.0
# 4  [pos, platform, solana-ecosystem, cms-holdings...          0.0
#
#    circulating_supply  total_supply  ... percent_change_1h  \
# 0        1.890211e+07  1.890211e+07  ...          0.064285
# 1        1.187567e+08  1.187567e+08  ...         -0.196809
# 2        1.668011e+08  1.668011e+08  ...         -0.412192
# 3        7.669420e+10  8.036200e+10  ...          0.089395
# 4        3.077904e+08  5.112147e+08  ...         -0.313311
#
#    percent_change_24h percent_change_7d percent_change_30d percent_change_60d  \
# 0            2.193126         -1.660272         -20.573078         -19.828893
# 1            5.437581         -8.212798          -7.425176           4.702771
# 2            2.338056        -11.130359         -12.962236          15.617822
# 3            0.034613          0.180263          -0.009409           0.111060
# 4           10.636230         -6.953982         -22.712295          11.035562
#
#      market_cap  market_cap_dominance  fully_diluted_market_cap  \
# 0  9.278303e+11               40.9948              1.030808e+12
# 1  4.794109e+11               21.1914              4.794109e+11
# 2  8.960573e+10                3.9608              8.960573e+10
# 3  7.678142e+10                3.3912              8.045338e+10
# 4  5.463623e+10                2.4136              9.074634e+10
#
#              last_updated_y        date
# 0  2021-12-16T03:08:02.000Z  12-15-2021
# 1  2021-12-16T03:08:02.000Z  12-15-2021
# 2  2021-12-16T03:07:11.000Z  12-15-2021
# 3  2021-12-16T03:07:11.000Z  12-15-2021
# 4  2021-12-16T03:08:05.000Z  12-15-2021
#
# [5 rows x 28 columns]

# %%
df.dtypes
# Out:
# id                            int64
# name                         object
# symbol                       object
# slug                         object
# num_market_pairs              int64
# date_added                   object
# tags                         object
# max_supply                  float64
# circulating_supply          float64
# total_supply                float64
# platform                     object
# cmc_rank                      int64
# last_updated_x               object
# quote                        object
# tradable                     object
# price                       float64
# volume_24h                  float64
# volume_change_24h           float64
# percent_change_1h           float64
# percent_change_24h          float64
# percent_change_7d           float64
# percent_change_30d          float64
# percent_change_60d          float64
# market_cap                  float64
# market_cap_dominance        float64
# fully_diluted_market_cap    float64
# last_updated_y               object
# date                         object
# dtype: object

# %%
df.to_csv(f'coinmarketcap_{today}.csv', sep=',', index=False)

# %%
data?
